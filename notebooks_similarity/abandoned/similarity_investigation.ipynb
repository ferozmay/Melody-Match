# %% [markdown]
# # Similarity Investigation

# %%
__import__('sys').path.append('../scripts/'); __import__('notebook_utils').table_of_contents('similarity_investigation.ipynb')
# Out:
# <h3>Table of contents</h3>
# [Similarity Investigation](#Similarity-Investigation)
# - [Setup](#Setup)
# - [How others compute similarity](#How-others-compute-similarity)
# - [Attempt 1. Check for common tracks in FMA & MSD](#Attempt-1.-Check-for-common-tracks-in-FMA-&-MSD)
# - [Attempt 2. Use UPF Essentia](#Attempt-2.-Use-UPF-Essentia)
# - [Attempt 3. Use another dataset: Music4All-Onion](#Attempt-3.-Use-another-dataset:-Music4All-Onion)
# - [Attempt ?. Replicate the similarity algorithm MSD used](#Attempt-?.-Replicate-the-similarity-algorithm-MSD-used)

# %% [markdown]
# ## Setup

# %%
# IMPORTS
import json
import os
import numpy
import pandas
import sys

from notebook_utils import md, h3, h4, h5
import FMA_code.utils

# %%
# PATHS
class paths():
    # General
    DATA_F = 'data/'

    # MSD files
    MSD_F = DATA_F + 'MSD/'
rr4
    LASTFM_SUBSET_F = MSD_F + 'lastfm_subset/'
    LASTFM_TRAIN_f = MSD_F + 'lastfm_train/'
    LASTFM_TEST_F = MSD_F + 'lastfm_test/'

    # FMA files
    FMA_F = DATA_F + 'FMA/'
    FMA_METADATA_F = FMA_F + 'fma_metadata/'
    FMA_SMALL_F = FMA_F + 'fma_small/'

# %% [markdown]
# ## How others compute similarity

# %% [markdown]
# **SPOTIFY**
#
#
# **[SPOTALIKE](https://spotalike.com/en)**<br>
# They use **lastFM dataset** to provide similar songs within the MSD dataset
#
#
# **[COSINE.CLUB](https://cosine.club/)**<br>
# For the machine learning heads: it's using a contrastive learning model from the Music Technology Group at [UPF](https://essentia.upf.edu/models.html#discogs-effnet) that has been trained on triplets of mel-spectrograms of tracks to learn associations between a positive pair with a negative sample. Then by creating vector embeddings of each track the cosine similarity between the vectors can be used to find the most similar in the index. [[ref](https://www.reddit.com/r/TheOverload/comments/1csqg0j/i_built_a_music_search_engine_to_help_you_find/)]
#
# **[Essentia - UPF](https://essentia.upf.edu/models.html#discogs-effnet):**

# %% [markdown]
# ## Attempt 1. Check for common tracks in FMA & MSD
# Idea: use MSD similarity as a gold standard to finetune FMA similarity.<br>
# <span style="color:red">**Failed attempt**: 0 pairs of similar MSD songs are present in FMA :')</span>

# %%
# SHOW METADATA FOR ONE EXAMPLE OF LASTFM SUBSET
lastfm_ex_path = paths.LASTFM_SUBSET_F + 'A/A/A/TRAAAAW128F429D538.json'
with open(lastfm_ex_path) as f:
    lastfm_ex = json.load(f)

for key in lastfm_ex.keys():
    print(f'{key:<15}', lastfm_ex[key][:2] + ['...'] if isinstance(lastfm_ex[key], list) else lastfm_ex[key])
# Out:
# artist          Casual
# timestamp       2011-08-02 20:13:25.674526
# similars        [['TRABACN128F425B784', 0.871737], ['TRIAINV12903CB4943', 0.751301], '...']
# tags            [['Bay Area', '100'], ['hieroglyiphics', '100'], '...']
# track_id        TRAAAAW128F429D538
# title           I Didn't Mean To

# %%
# GET TRACKS PRESENT IN FMA
# Get title & artist tuple set for FMA
tracks = FMA_code.utils.load(paths.FMA_METADATA_F + 'tracks.csv')
FMA_title_artist_set = set(zip(tracks[('track', 'title')], tracks[('artist', 'name')]))

# Get list of tracks with similar tracks
with open(paths.SIMILAR_TRACKS) as f:
    tracks_with_similar = f.read().splitlines()

# Get MSD tracks that match FMA & save it in similars_dict
notfound = 0
similars_dict = {}

for track_id in tracks_with_similar:
    rel_track_path = f'{track_id[2]}/{track_id[3]}/{track_id[4]}/{track_id}.json'

    # Check on the two possible folders the track can be in (train & test)
    for supfolder in [paths.LASTFM_TEST_F, paths.LASTFM_TRAIN_f]:
        track_path = supfolder + rel_track_path
        if not os.path.exists(track_path):
            continue
    
        # Get the similar tracks in the format [(track_id, score), ...]
        with open(track_path) as f:
            track_dict = json.load(f)

            # Get the title & artist tuple
            title = track_dict['title']
            artist = track_dict['artist']

            # Check if the title & artist match
            if (title, artist) in FMA_title_artist_set:
                similars_dict[track_id] = {
                    'similars': track_dict['similars'],
                    'artist': track_dict['artist'],
                    'title': track_dict['title']   
                }

print(f"FMA and MSD match in {len(similars_dict)} tracks where MSD has similar tracks")
# Out:
# The Durks Chandeliers
# Reggae War Zone Foot Village
# Sailin' On The Red Thread
# It Killed Mom Thee Oh Sees
# Roka Calexico
# When He Comes Holly Golightly & The Brokeoffs
# Two Silver Trees Calexico
# The Anvil Will Fall Harvey Milk
# Vernon Jackson The Brought Low
# Please Listen To My Demo EPMD
# Mango Tree Chandeliers
# OK Higgins
# Better Be Good The Real Kids
# Red F Dan Deacon
# Plug Me In The Unsacred Hearts
# Picking Scabs Thomas Function
# War Harvey Milk
# You Changed My Life Kevin Blechdom
# When My Ship Comes In Clockcleaner
# Victor Jara's Hands Calexico
# River Matteah Baim
# Forgotten Lovers Gary Wilson
# Address Book Misty Roses
# Feel Anymore Captain Ahab
# 1978 The Unsacred Hearts
# Motionless Sian Alice Group
# The Most Excruciating Vibe Larkin Grimm
# Canker Ut
# Wall of Dumb Higgins
# The Language Clan Destined
# There He Is Higgins
# Bound Feet & Feathered Mia Doi Todd
# Microcastle Deerhunter
# Want Me Ariel Pink's Haunted Graffiti
# Armour of the Shroud Bobb Trimble
# One Big Holiday My Morning Jacket
# Plan B Clan Destined
# All At Once Liechtenstein
# 266 Chippendale 140706 Justice Yeldham
# Trans Siberian Nest
# Cigarette State Robbie Fulks
# Crossover EPMD
# Roy G. Business Higgins
# There He Is Higgins
# Mexico Foot Village
# Landlord Oakley Hall
# Lost Time Blues Chrome Cranks
# Ophelia's Song Musetta
# A Stitch In Time The Long Ryders
# Grifted New Bomb Turks
# Buscuit Basket Justice Yeldham
# Balrog Boogie Diablo Swing Orchestra
# Crows Modey Lemon
# You're A Bigger Jerk Than Me Karl Hendricks Trio
# Black Light Dan Melchior's Broke Revue
# Pink Noise Waltz Diablo Swing Orchestra
# Loca Chico Trujillo
# Blackout Gorod
# Gonna Make It Through This Year Great Lake Swimmers
# Stick Up For Me Reigning Sound
# Stuck Inside a Mobile Home with the Mansion Blues Again The Unsacred Hearts
# All Kindsa Girls The Real Kids
# Onda Tocadisco Lucky Dragons
# LGNO El Jesus De Magico
# Not Asking For Much Thomas Function
# The Loose Brick The Red Thread
# 13 Monsters Lightning Bolt
# Don't Follow Me The Priscillas
# I Had A Dream The Long Ryders
# Dracula Mountain Lightning Bolt
# Third World Chandeliers
# Shelia Atlas Sound
# Not Living At All Mr. Airplane Man
# Crybaby Foot Village
# Flowers Jim Bryson
# The Guest Modey Lemon
# Yes I Know Higgins
# I Love A Lassie Harry Lauder
# Space Forklift Kurt Vile
# Criminals Atlas Sound
# Prove It The Cute Lepers
# Iran Foot Village
# Chocolate Makes You Happy Xiu Xiu
# Taste The Candy Samara Lubelski
# A More Perfect Union Titus Andronicus
# Rosalie Alejandro Escovedo
# Turn Around Kevin Blechdom
# If I Could Change Your Mind Sloan
# Morning Song Spires That in the Sunset Rise
# Little Bit More Zounds
# Grammar Of Misery The Barracudas
# Bad Luck Blues Blind Lemon Jefferson
# I Blame You Franklin Bruno
# Better Be Good The Real Kids
# I Love A Lassie Harry Lauder
# I Love A Lassie Harry Lauder
# Wood Frong Pond Volcano the Bear
# Perforated Sightings
# Kyoto Nest
# Sparky Marcus James William Hindle
# I Feel Fantastic Jonathan Coulton
# Let's rent bikes from 1942 Youth Pictures of Florence Henderson
# The Prime Four Blah Blah Blah
# Some Of These Days Sophie Tucker
# Poetic Pitbull Revolutions Diablo Swing Orchestra
# You Know That I Will Dan Melchior's Broke Revue
# Young Yellers Rye Coalition
# The Glass Castle Sir Lord Von Raven
# National Jamthum Foot Village
# Josie Tullycraft
# Back On Me Urge Overkill
# You're So Strange Reigning Sound
# All Kindsa Girls The Real Kids
# Melonhead Hank IV
# All In The Red Thread
# Porcelain Judas Diablo Swing Orchestra
# A Stitch In Time The Long Ryders
# Our door handles stopped moving years ago Youth Pictures of Florence Henderson
# Spread Thin The Red Thread
# I Can't Lose Obits
# Velvet Cave Silver Apples
# Digital Mia Doi Todd
# Requiem for Stateway Thaione Davis
# Inspiracion Calexico
# Listen to this Collision The Death Set
# Inside Out Man Dan Melchior's Broke Revue
# Walkman Minimum Chips
# Eine Symphonie Des Grauens The Monochrome Set
# Breathe Deep Primordial Undermind
# I Have Known Love Silver Apples
# Sucker Career Suicide
# I Want You Bad The Long Ryders
# Pretty People Low
# Warsaw Soundcheck 151005 Justice Yeldham
# Oscillations Silver Apples
# Oh! Mighty Engine Neil Halstead
# Everyone, But Everyone R. Stevie Moore
# Oceans of Sound White Hills
# Heavy Deeds Sun Araw
# Loch Na Fooey Fern Knight
# We Ask You To Ride Wooden Shjips
# Teenage Kicks The Unfinished Sympathy
# Shopping Bag Blah Blah Blah
# Scientists now think this city is overdue Youth Pictures of Florence Henderson
# The Last Say Career Suicide
# Yes I Know Higgins
# Bigger and Better The Fleshtones
# Klaagzang Het Gloren
# Richter Scale EPMD
# Surfers Are Back The Barracudas
# Caliente Queen Clockcleaner
# Not Too Soon Throwing Muses
# Waiting by the Gate Samara Lubelski
# Bottom Rung Nite Jewel
# Dirty Poncho Hank IV
# Wild Eyes Vivian Girls
# Moroccan Summer The Shining Path
# Ape Uprising Slough Feg
# Terminal Boredom The Cute Lepers
# Points of View Country Teasers
# Colour Me Your Colour Justice Yeldham
# (Masks) James William Hindle
# Story Of A Shell Gina V. D'Orio
# Holiday in Congo Rainbow Arabia
# Grease Thee Oh Sees
# Tropical Sheep Blah Blah Blah
# Bologna Soundcheck 031105 Justice Yeldham
# The Hotel Blah Blah Blah
# Messalina Inkubus Sukkubus
# I Remember Billy Childish
# Some Of These Days Sophie Tucker
# Godsstation Our Last Hope Lost Hope
# Timing The Priscillas
# Jayne Field Paik
# Nice Day Persephone's Bees
# Break It Reigning Sound
# A Pox On You Silver Apples
# Blue As I Can Be Mr. Airplane Man
# Titus Andronicus Titus Andronicus
# Don't Lie The Mantles
# Lodge Nest
# I Was Only Kidding Meanest Man Contest
# Morning Light Rivulets
# Lick 'n Leap Samara Lubelski
# Bad Luck Blues Blind Lemon Jefferson
# Borrow And Spend The Red Thread
# Helen Ariel Pink's Haunted Graffiti
# She Sang a Song of Norway Volcano the Bear
# Clutch The Pearls Rye Coalition
# Hand of God Fat Worm of Error
# By My Side The Dirtbombs
# Impossible The Clientele
# Fat Gut Strut The Mint Chicks
# No Fun No More The Real Kids
# Absence Bardo Pond
# Pharoah's Fury Chandeliers
# Attic Lights Atlas Sound
# Java Pop Spires That in the Sunset Rise
# The Ship Country Teasers
# Some Of These Days Sophie Tucker
# Cold Fish TV Ghost
# Old Glory Harvey Milk
# Baiting the Public Fucked Up
# 310 PORTO 170507 Justice Yeldham
# Scorpion Whip Sissy Spacek
# Get It Straight Hank IV
# Crystals Psychedelic Horseshit
# Seasick TV Ghost
# Jules Lost His Jewels Ariel Pink's Haunted Graffiti
# I Love A Lassie Harry Lauder
# Call Me Reigning Sound
# The Divine Invasion P.G. Six
# Monster Kevin Blechdom
# Black Tears Miss Derringer
# Equus Haar Spires That in the Sunset Rise
# Rather Dull Psychedelic Horseshit
# Never Stops Deerhunter
# Jet Set Junta The Monochrome Set
# All Kindsa Girls The Real Kids
# Fist Fulla Biscuits Eddie Meeks
# Subject To Change The Red Thread
# Better Be Good The Real Kids
# Silver Fox Fern Knight
# Mountain Mist Modey Lemon
# Let Me Go The Chapin Sisters
# White Sian Alice Group
# Open Melody Lucky Dragons
# He can't be dead, I got his autograph last week Youth Pictures of Florence Henderson
# Fallin' Wooden Shjips
# The End Vivian Girls
# Fafa Vieux Farka Touré
# Hobbies Galore R. Stevie Moore
# Hassle St. New Bomb Turks
# Baltihorse Dan Deacon
# Idol Manikin
# All Kindsa Girls The Real Kids
# Odessa Zola Jesus
# Happiness Is A Chemical Darren Hanlon
# 5 The Red Thread
# Always Fade Low
# Rumble With The Gang Debs Tullycraft
# Bird Song The Chapin Sisters
# Some Of These Days Sophie Tucker
# Shake Some Action Flamin' Groovies
# Letter To a Fanzine Great Plains
# Y.O.Y. The Priscillas
# Refried Dreams Cheater Slicks
# This Ain't No Game The Brought Low
# Everybody (Thunder Mountain) Higgins
# Debris Reigning Sound
# Tom & Jerry Hecuba
# Feeding Me Back Hank IV
# Sister Silver Samara Lubelski
# Bitter Heart Zee Avi
# One Mile From Heaven (short version) Bobb Trimble
# Family Adam Hank IV
# Axis Mundi Magik Markers
# The league will never let the albino kid win Youth Pictures of Florence Henderson
# Freeway Kurt Vile
# Young Hearts The Cute Lepers
# 038 Zwolle 090104 Justice Yeldham
# People Should Get More Aware Bird Names
# To Where Grass Widow
# Up in Flames Misty Roses
# Red Melting Plastic Box Fat Worm of Error
# Velvet Embracer Diablo Swing Orchestra
# We Could Walk Together The Clientele
# Sleepwalkers Modey Lemon
# Mothers Footsteps Naked on the Vague
# Fat Gut Strut The Mint Chicks
# Secret Dakota Ring / No Chance The Unsacred Hearts
# FM 91.1 Landed
# Cool City The Cute Lepers
# Frankie's Problem Blues Control
# Predator Modey Lemon
# New Moses El Jesus De Magico
# What I Found The Brought Low
# Little for a Lot Spires That in the Sunset Rise
# Love Eternal Inkubus Sukkubus
# Motorbike Wooden Shjips
# O'Connor's Last Air Loren MazzaCane Connors
# Sky Dreamer's Gold Steffen Basho-Junghans
# The Battle of Hampton Roads Titus Andronicus
# I'd rather listen to Weston Youth Pictures of Florence Henderson
# Predator Modey Lemon
# Special Bonus Thing Fat Worm of Error
# Everybody Loves Me Alejandro Escovedo
# Underscore Spires That in the Sunset Rise
# Dalliance The Wedding Present
# The Search Manikin
# Take it or Leave it Sir Lord Von Raven
# Solid Gold The Real Kids
# Love Comes Close Cold Cave
# Dirty Baby The Cute Lepers
# All I Ever Wanted Meg Baird
# 27 Jennifers Mike Doughty
# Ghost In The Trees Thee Oh Sees
# Oh Baby Bobb Trimble
# Get Older Dan Deacon
# Glorie 3 Het Gloren
# Summer Fun The Barracudas
# 304 MARSEILLE 070507 Justice Yeldham
# Crocodile Song Blah Blah Blah
# Lost My Sight Indian Jewelry
# Analog Cabin Chandeliers
# Glorie 2 Het Gloren
# I'm a Bug Urinals
# Japan Foot Village
# Sorry 'Bout the Boat Race Hank IV
# Like A Knife Mia Doi Todd
# Coaxing the Piano Zez Confrey
# Holiday in Congo Rainbow Arabia
# Tonight We Ride Hank IV
# Nervous Habits The Cute Lepers
# Miss Douglas County Tullycraft
# I'm Quitting Hank IV
# The Cranes Are Scared Of Sunwords Kiss the Anus of a Black Cat
# Caterpillar Girl Lou Barlow
# Taste Magik Markers
# Surfin' Away Vivian Girls
# Go On, Take It Further Comfort Fit
# Infralove Diablo Swing Orchestra
# Amnesia Mia Doi Todd
# Enemy Modey Lemon
# Where The Comet Falls Al Duvall
# When You Touch Me Reigning Sound
# Honey Money The Spectacular Fantastic
# Fly In My Drink The Priscillas
# Freeze Clan Destined
# Y.O.Y. The Priscillas
# Less Of Me James William Hindle
# Bad Vibrations Psychedelic Horseshit
# Security By Design Liechtenstein
# Failures Selected By God Meth Teeth
# For Kate I Wait Ariel Pink's Haunted Graffiti
# Telekinesis Chandeliers
# The Chameleon Glass Candy
# Some Of These Days Sophie Tucker
# Pink Frost The Chills
# Life After Sundown Glass Candy
# Before I was After'd Volcano the Bear
# Sex Urinals
# Modern Pests The Cute Lepers
# Radiate White Hills
# The Fly Out The Red Thread
# Zodiac Virtues Diablo Swing Orchestra
# Big League Chandeliers
# Canada Low
# Heart of the City The Unsacred Hearts
# Hungry Ghost Dan Melchior's Broke Revue
# Brooklyn Song James William Hindle
# Jamy Higgins
# You're My Wife Dan Melchior's Broke Revue
# Hold On Darren Hanlon
# Eine Symphonie Des Grauens The Monochrome Set
# Our Days In Kansas Tullycraft
# My Anger Hank IV
# Pine On Obits
# I Was Raised To Be Polite & Kind The Unsacred Hearts
# Rosalie Alejandro Escovedo
# We Ride Rye Coalition
# Heart Won't Start Nite Jewel
# Rummy Ut
# Woof Woof Dan Deacon
# Looking At The World From The Bottom Of A Well Mike Doughty
# Lysine Max Tundra
# Bad Luck Blues Blind Lemon Jefferson
# All Systems Red Calexico
# I'll Cry Reigning Sound
# Like A Knife Mia Doi Todd
# Marefjellet Nest
# Bottle Rocket Lushlife
# White Man Blah Blah Blah
# Always Something Higgins
# All Kindsa Girls The Real Kids
# Velvet Guitar Alejandro Escovedo
# Misty Mountain Silver Apples
# Code Monkey Jonathan Coulton
# We Repel Each Other Reigning Sound
# Celebrity Virgin Hank IV
# Synge's Chair Fern Knight
# Almost, Silver Kiss the Anus of a Black Cat
# Lovefingers Silver Apples
# The Lipstick Game Rye Coalition
# Wait and See Reigning Sound
# Glorie 1 Het Gloren
# You Are My Home Rivulets
# All Kindsa Girls The Real Kids
# Rampage EPMD
# Dr. No Ut
# Tyranny Fursaxa
# Production Bird Names
# Mary Mack Al Duvall
# Tyranny Fursaxa
# Drive the Whip Hank IV
# Young Yellers Rye Coalition
# Fall To Pieces The Cute Lepers
# Aquarian Time Wooden Shjips
# Gunpowder Chant Diablo Swing Orchestra
# There's Nothing Sexy About Time Kinski
# Fake French Le Tigre
# Light of My Love Oakley Hall
# Solid Gold The Real Kids
# Man Made Lake Calexico
# Indian Giver El Jesus De Magico
# Some Of These Days Sophie Tucker
# Sundew Fern Knight
# Tugboat Mia Doi Todd
# Red Blooms Calexico
# Can't Get Over You Vivian Girls
# Clouds Spires That in the Sunset Rise
# Prelude to a Charly Higgins
# Signals Career Suicide
# Write It Down Higgins
# I think E.T. is involved in my family Youth Pictures of Florence Henderson
# Welcome To The Party Har-You Percussion Group
# Agoraphobia Deerhunter
# Shooting Stars Elysian Fields
# Details The Red Thread
# Don't Love You The Chapin Sisters
# Knobranaut Justice Yeldham
# Don't Apologize Lou Barlow
# Oh Keiko The Priscillas
# Imaginary Skin Spires That in the Sunset Rise
# Re: Your Brains Jonathan Coulton
# Heroines Diablo Swing Orchestra
# I Have Known Love Silver Apples
# Porcelain The Clientele
# Taqasim DJ /rupture
# Shake Some Action Flamin' Groovies
# Take Me Home Vienna Bobb Trimble
# New India Kinski
# Visit Colonel Thee Oh Sees
# Digital Mia Doi Todd
# Roses In The Park Liechtenstein
# The Chameleon Glass Candy
# I Had A Dream Daniel Johnston
# Korea Foot Village
# Don't Be Afraid White Hills
# I Was Drunk Alejandro Escovedo
# La femme de mon patron Daouda
# Symptomatic Hank IV
# Mimehunter Hank IV
# Second Date Vivian Girls
# 267 Chippendale 220706 Justice Yeldham
# The Bells Reigning Sound
# Rag Doll Physics Diablo Swing Orchestra
# Of the Mountains Dan Deacon
# Slow Crash Chrome Cranks
# Body Double Chandeliers
# Here Die Your Gods Gorod
# We Were a Band The Unsacred Hearts
# Charlotte Nest

# %%
# CHECK IF SIMILAR TRACKS ARE IN FMA
# Get all MSD tracks similar to a track in FMA
fma_similar_tracks = {t[0] for v in similars_dict.values() for t in v['similars']}

# Get the subset of those similar tracks that are also in FMA
fma_similar_tracks = fma_similar_tracks.intersection(FMA_title_artist_set)
print(f"Similar tracks present in FMA: {len(fma_similar_tracks)}")
# Out:
# Similar tracks present in FMA: 0

# %% [markdown]
# **Info**
# Use the [Discogs-EffNet](https://essentia.upf.edu/models.html#discogs-effnet), used by the [cosine.club](https://cosine.club/) website
# Audio embedding models trained with classification and contrastive learning objectives using an in-house dataset annotated with Discogs metadata. The classification model was trained to predict music style labels. The contrastive learning models were trained to learn music similarity capable of grouping audio tracks coming from the same artist, label (record label), release (album), or **segments of the same track itself (self-supervised learning)**. Additionally, **multi was trained in multiple similarity targets simultaneously**.
#
# **Note:** cosine.club has [positive reviews on reddit](https://www.reddit.com/r/TheOverload/comments/1csqg0j/i_built_a_music_search_engine_to_help_you_find/) indicating it works well

# %% [markdown]
# ## Attempt 2. Use UPF Essentia
# <span>Idea: Use Essentia python library to get similarity between audio tracks.</span><br>
#
# <span style="color: orange">
# ABANDONED
# <ul>
#   <li>Works only with python<=3.10</li>
#   <li>Could not replicate what they do on the instructions</li>
#   <li>It would require us to understand how it works, convert mp3 to "wav" format, and then get similarity -> very computationally expensive (?)</li>
#   <li>Not sure if the "similarity" it is trained on is the type of similarity we are interested in</li>
# </ul>
# </span>

# %%
# INSTALL ESSENTIA
# Does not work on python 3.12. Installed in python 3.11:
# !conda create -n essentia_env python=3.10 -y
# !conda activate essentia_env
# !pip install essentia
# !pip install ipykernel 
# !pip install "numpy<2"  # Required for essentia
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/cdt_wsl/miniconda3/envs/essentia_env
#
#   added / updated specs:
#     - python=3.10
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.12.31-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.40-h12ee557_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-3.0.15-h5eee18b_0
#   pip                pkgs/main/linux-64::pip-25.0-py310h06a4308_0
#   python             pkgs/main/linux-64::python-3.10.16-he870216_1
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-75.8.0-py310h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   tzdata             pkgs/main/noarch::tzdata-2025a-h04d1e81_0
#   wheel              pkgs/main/linux-64::wheel-0.45.1-py310h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate essentia_env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CondaError: Run 'conda init' before 'conda activate'
#
# Collecting essentia
#   Using cached essentia-2.1b6.dev1110-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting numpy>=1.8.2 (from essentia)
#   Using cached numpy-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting six (from essentia)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting pyyaml (from essentia)
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Using cached essentia-2.1b6.dev1110-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
# Using cached numpy-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, pyyaml, numpy, essentia
# ^C
# ERROR: Operation cancelled by user
# Collecting ipykernel
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting comm>=0.1.1 (from ipykernel)
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Using cached debugpy-1.8.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting ipython>=7.23.1 (from ipykernel)
#   Using cached ipython-8.32.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting jupyter-client>=6.1.12 (from ipykernel)
#   Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel)
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel)
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting nest-asyncio (from ipykernel)
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting packaging (from ipykernel)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting psutil (from ipykernel)
#   Using cached psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyzmq>=24 (from ipykernel)
#   Using cached pyzmq-26.2.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.2 kB)
# Collecting tornado>=6.1 (from ipykernel)
#   Using cached tornado-6.4.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting traitlets>=5.4.0 (from ipykernel)
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting decorator (from ipython>=7.23.1->ipykernel)
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting exceptiongroup (from ipython>=7.23.1->ipykernel)
#   Using cached exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting pexpect>4.3 (from ipython>=7.23.1->ipykernel)
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel)
#   Using cached prompt_toolkit-3.0.50-py3-none-any.whl.metadata (6.6 kB)
# Collecting pygments>=2.4.0 (from ipython>=7.23.1->ipykernel)
#   Using cached pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython>=7.23.1->ipykernel)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: typing_extensions>=4.6 in /home/cdt_wsl/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.12.2)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=6.1.12->ipykernel)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel)
#   Using cached platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython>=7.23.1->ipykernel)
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=7.23.1->ipykernel)
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel)
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: six>=1.5 in /home/cdt_wsl/miniconda3/envs/essentia_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Collecting executing>=1.2.0 (from stack_data->ipython>=7.23.1->ipykernel)
#   Using cached executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython>=7.23.1->ipykernel)
#   Using cached asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython>=7.23.1->ipykernel)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Using cached ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Using cached debugpy-1.8.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Using cached ipython-8.32.0-py3-none-any.whl (825 kB)
# Using cached jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Using cached jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached pyzmq-26.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (874 kB)
# Using cached tornado-6.4.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (437 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Using cached pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Using cached platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Using cached prompt_toolkit-3.0.50-py3-none-any.whl (387 kB)
# Using cached pygments-2.19.1-py3-none-any.whl (1.2 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Using cached exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Using cached executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, traitlets, tornado, pyzmq, python-dateutil, pygments, psutil, prompt_toolkit, platformdirs, pexpect, parso, packaging, nest-asyncio, executing, exceptiongroup, decorator, debugpy, asttokens, stack_data, matplotlib-inline, jupyter-core, jedi, comm, jupyter-client, ipython, ipykernel
# Successfully installed asttokens-3.0.0 comm-0.2.2 debugpy-1.8.12 decorator-5.1.1 exceptiongroup-1.2.2 executing-2.2.0 ipykernel-6.29.5 ipython-8.32.0 jedi-0.19.2 jupyter-client-8.6.3 jupyter-core-5.7.2 matplotlib-inline-0.1.7 nest-asyncio-1.6.0 packaging-24.2 parso-0.8.4 pexpect-4.9.0 platformdirs-4.3.6 prompt_toolkit-3.0.50 psutil-6.1.1 ptyprocess-0.7.0 pure-eval-0.2.3 pygments-2.19.1 python-dateutil-2.9.0.post0 pyzmq-26.2.1 stack_data-0.6.3 tornado-6.4.2 traitlets-5.14.3 wcwidth-0.2.13
# Collecting numpy<2
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.2
#     Uninstalling numpy-2.2.2:
#       Successfully uninstalled numpy-2.2.2
# Successfully installed numpy-1.26.4

# %%
# !pip freeze | grep essentia
# Out:
# essentia==2.1b6.dev1110

# %%
import essentia

# %%
from essentia.standard import MonoLoader, TensorflowPredictEffnetDiscogs

audio = MonoLoader(filename="audio.wav", sampleRate=16000, resampleQuality=4)()
model = TensorflowPredictEffnetDiscogs(graphFilename="discogs_track_embeddings-effnet-bs64-1.pb", output="PartitionedCall:1")
embeddings = model(audio)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from essentia.standard import MonoLoader, TensorflowPredictEffnetDiscogs
#       3 audio = MonoLoader(filename="audio.wav", sampleRate=16000, resampleQuality=4)()
#       4 model = TensorflowPredictEffnetDiscogs(graphFilename="discogs_track_embeddings-effnet-bs64-1.pb", output="PartitionedCall:1")
#
# ModuleNotFoundError: No module named 'essentia.standard'

# %% [markdown]
# ## Attempt 3. Use data available in FMA

# %% [markdown]
# #### Possible idea:
# Train models on features & lyrics to predict genre.
#
#
# #### Works worth looking at:
# **Medium: [Content-Based Music Recommendatation System](https://medium.com/@dibyendu19034/content-based-music-recommendation-system-74f30bccc239)**<br>
# They combine FMA & MSD at different weights to get their final model. Steps:
# 1. Librosa is used to get the MFCC feature (including 7 features x 20 dimensions), using bagged random forest to convert MFCC to a level gendre feature vector
# 2. TF-IDF of lyrics
#
#
# **[GitHub Repo](https://github.com/MiningMyBusiness/ExploringFreeMusicArchiveDataset): ExploringFreeMusicArthiveDataset**<br>
# * **Motivation:** to make music recommendation fair to smaller or less reknowned artists and more useful to the consumer looking for music, we must see if the music itself (audio signal) can provide the necessary features for classification and categorization.
# * **Observations:**
#   * **Genre classification:** Some genres occur far more often than others in the dataset. There is a big gendre imbalance
#
# **Kaggle: [Unsupervised ML project: Music Clustering](https://www.kaggle.com/code/shabanamir/unsupervised-ml-project-music-clustering)**
#
#
# **Jupyter notebook: Ideas for [song similarity using the audio features](https://colab.research.google.com/github/jo-cho/genre_classification/blob/main/GTZAN/song_similarity.ipynb#scrollTo=5a912b81)**

# %% [markdown]
# ## Other investigations done:

# %% [markdown]
# Comments:
# * I saw this paper: [Music4All-Onion -- A Large-Scale Multi-faceted Content-Centric Music Recommendation Dataset](https://dl.acm.org/doi/10.1145/3511808.3557656)
# but it is based on MSD
# * [This blog post](http://millionsongdataset.com/blog/12-1-2-matching-errors-taste-profile-and-msd/) talks about matching errors between songs an tracks. [List of song-track pairs that shouldn't be trusted](http://millionsongdataset.com/blog/12-2-12-fixing-matching-errors/)
#
# **How is similarity computed for the MSD:**
# * Collaborative information: If user A&B like bands X & Y, they are likely to be similar
# * Although, Spotify uses algorithm which measure and maps song on the basis of tempo, progression and frequency
#
# **Similarity in Spotify:**
# The audio features data available through Spotify API consists of 12 metrics
#
# Yet, these audio features are just the first component of Spotify's audio analysis system. In addition to the audio feature extraction, a separate algorithm will also analyze the track's temporal structure and split the audio into different segments of varying granularity: from sections (defined by significant shifts in the song timbre or rhythm, that highlight transitions between key parts of the track such as verse, chorus, bridge, solo, etc.) down to tatums (representing the smallest cognitively meaningful subdivision of the main beat).
#
#
# Reference: [Inside Spotify’s Recommender System:](https://www.music-tomorrow.com/blog/how-spotify-recommendation-system-works-a-complete-guide-2022)

# %% [markdown]
# ****

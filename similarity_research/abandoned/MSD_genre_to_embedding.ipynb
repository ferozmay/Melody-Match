# %% [markdown]
# # Get LASTFM tracks similar to FMA tracks

# %% [markdown]
# `TODO` (doing between this & the jupyter `FMA_feature_to_genre_model.ipynb`)
#
# Steps:
# 1. Get the subset of LASTFM containing tags comparable to genres. Preprocess the genres, an one-hot encoded CSV for the genres (output)
# 2. Select, from the features, only those from this subset (so that the file to work with is smaller)
# 3. Select, from those features, a subset we will use for training. Aim for similar amount of features than FMA, and similar names
# 4. Use the same model used in FMA to train a model to predict genres based on the features, and extract the embeddings
# 5. Check the correlation between song embeddings & the song similarity dataset
# 6. Think on how to link that with FMA ;?

# %% [markdown]
# In `FMA_feature_to_genre_model.ipynb` we have trained a model capable to extract similarity song embeddings by using as input the features of the song, and as outputs the genres.
#
# We haven't been able to connect MSD and FMA in the level of features. Let's see how to connect them.
# Instead of using MSD, we will use its subset: LASTFM, which contains more information, including genres, similar tracks, etc.
#
# This dataset will:
# * Convert the LASTFM genres into genres equivalent to those in FMA
# * Convert the LASTFM features into those equivalent in FMA

# %%
__import__('sys').path.append('../scripts/'); __import__('notebook_utils').table_of_contents('MSD_genre_to_embedding.ipynb')
# Out:
# <h3>Table of contents</h3>
# [Get LASTFM tracks similar to FMA tracks](#Get-LASTFM-tracks-similar-to-FMA-tracks)
# - [Setup](#Setup)
# - [Compare genres between FMA & LASTFM](#Compare-genres-between-FMA-&-LASTFM)
# - [Compare low-level features between FMA & LASTFM](#Compare-low-level-features-between-FMA-&-LASTFM)

# %% [markdown]
# ## Setup

# %%
# IMPORTS
import re
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import ast
import h5py
from collections import Counter
import difflib

# import markdown
from IPython.display import Markdown

def md(text):
    print(Markdown(text))

# %%
# PATHS
class paths():
    DATA_D = '../data/' # path to the data folder
    MSD_D = '../data/MSD/' # path to the MSD dataset
    FMA_D = '../data/FMA/fma_metadata/' # path to the FMA metadata files
    TEMP_D = '../data/temp/'

    FMA_FEATURE = FMA_D + 'features.csv' # features for each track
    FMA_TRACKS = FMA_D + 'tracks.csv' # metadata for every track. We only use the genre column
    FMA_GENRE = FMA_D + 'genres.csv' # genre key from ID to string

    FMA_SMALL_D = '../data/FMA/fma_small/' # path to the FMA small dataset

    # MSD
    MSD_SUMMARY = MSD_D + 'msd_summary_file.h5'
    LASTFM_TRAIN_f = MSD_D + 'lastfm_train/'
    LASTFM_TEST_F = MSD_D + 'lastfm_test/'
    LASTFM_SIMILAR_TRACKS = MSD_D + 'tracks_with_similar.txt'

# %%
# LOAD FMA METADATA
def load_FMA(filepath):
    # Copied from FMA utils.py file

    filename = os.path.basename(filepath)

    if 'features' in filename:
        return pd.read_csv(filepath, index_col=0, header=[0, 1, 2])

    if 'echonest' in filename:
        return pd.read_csv(filepath, index_col=0, header=[0, 1, 2])

    if 'genres' in filename:
        return pd.read_csv(filepath, index_col=0)

    if 'tracks' in filename:
        tracks = pd.read_csv(filepath, index_col=0, header=[0, 1])

        COLUMNS = [('track', 'tags'), ('album', 'tags'), ('artist', 'tags'),
                   ('track', 'genres'), ('track', 'genres_all')]
        for column in COLUMNS:
            tracks[column] = tracks[column].map(ast.literal_eval)

        COLUMNS = [('track', 'date_created'), ('track', 'date_recorded'),
                   ('album', 'date_created'), ('album', 'date_released'),
                   ('artist', 'date_created'), ('artist', 'active_year_begin'),
                   ('artist', 'active_year_end')]
        for column in COLUMNS:
            tracks[column] = pd.to_datetime(tracks[column])

        SUBSETS = ('small', 'medium', 'large')

        # the categories and ordered arguments were removed in pandas 0.25
        tracks['set', 'subset'] = tracks['set', 'subset'].astype(
                    pd.CategoricalDtype(categories=SUBSETS, ordered=True))

        COLUMNS = [('track', 'genre_top'), ('track', 'license'),
                   ('album', 'type'), ('album', 'information'),
                   ('artist', 'bio')]
        for column in COLUMNS:
            tracks[column] = tracks[column].astype(pd.CategoricalDtype())

        return tracks
   
FMA_tracks = load_FMA(paths.FMA_TRACKS)
FMA_genres = load_FMA(paths.FMA_GENRE)
FMA_features = load_FMA(paths.FMA_FEATURE)

# %% [markdown]
# ## Get LASTFM genres matching with FMA

# %%
# DISPLAY DATA & GRAPHS ON FMA GENE HIERARCHY
# List parent terms
parent_terms = FMA_genres[FMA_genres['parent'] == 0]
print(f"There are {len(parent_terms)} parent genres in the FMA dataset")
print(f"{', '.join(parent_terms['title'])}")

import networkx as nx
def show_genes_hierarchy(FMA_genres):
    '''Show the hierarchy of genres in the FMA dataset using one directed graph per top-level genre.'''

    # Initialise the graph
    G = nx.DiGraph()

    # Add edges to the graph based on the parent-child relationships
    for genre_id, row in FMA_genres.iterrows():
        genre_name = row['title']
        parent_id = row['parent']
        
        # Determine the node level (subset) based on parent existence
        if parent_id != 0 and parent_id in FMA_genres.index:
            parent_name = FMA_genres.loc[parent_id, 'title']
            G.add_edge(parent_name, genre_name)
            G.nodes[genre_name]['subset'] = G.nodes[parent_name].get('subset', 0) + 1
        else:
            G.add_node(genre_name, subset=0)  # Top-level genres as subset 0
    # Identify the root nodes (nodes with no incoming edges)
    root_nodes = [node for node in G.nodes if G.in_degree(node) == 0]

    # Create a plot for each root and its corresponding tree
    num_roots = len(root_nodes)
    plt.figure(figsize=(15, 10))

    # Determine the grid layout for the subplots
    rows = cols = 4

    for i, root in enumerate(root_nodes):
        # Create a subgraph for each tree starting from the root
        nodes_in_tree = nx.descendants(G, root) | {root}
        tree = G.subgraph(nodes_in_tree)
        
        # Create a planar layout for the tree
        plt.subplot(rows, cols, i + 1)
        pos = nx.planar_layout(tree)
        nx.draw(tree, pos, with_labels=True, edge_color='gray', 
                node_size=500, font_size=8, arrows=True, node_color='lightblue')
        plt.title(root, fontsize=10)

    plt.tight_layout()
    md("Individual Trees for Each Top-Level Genre:")
    plt.show()

# Show graphs for the hierarchy of genres
show_genes_hierarchy(FMA_genres)
# Out:
# There are 16 parent genres in the FMA dataset
# International, Blues, Jazz, Classical, Old-Time / Historic, Country, Pop, Rock, Easy Listening, Soul-RnB, Electronic, Folk, Spoken, Hip-Hop, Experimental, Instrumental
# <IPython.core.display.Markdown object>

# %% [markdown]
# We will use the LASTFM dataset, instead of the whole MSD, as the LASTFM contains tags, features, and similar songs we can directly implement to MelodyMatch.

# %%
# GET ALL INFO FROM LASTFM
def get_LASTFM_all():
    '''Obtain all tags from the LASTFM dataset.
    First time, it creates a dictionary and saves it to temp/ folder.
    Second time, it loads the dictionary
    '''
    # Create the dictionary otherwise
    lastfm_dict = {}
    for path in [paths.LASTFM_TRAIN_f, paths.LASTFM_TEST_F]:
        for root, dirs, files in os.walk(path):
            if files:
                for file in files:
                    track_dict = json.load(open(os.path.join(root, file)))
                    track_id = track_dict['track_id'].strip("'")
                    lastfm_dict[track_id] = track_dict
    
    return lastfm_dict

lastfm_dict = get_LASTFM_all()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# GET TAGS FROM LASTFM
def get_LASTFM_tags_dict():
    '''Obtain all tags from the LASTFM dataset.
    First time, it creates a dictionary and saves it to temp/ folder.
    Second time, it loads the dictionary
    '''
    store_path = paths.DATA_D + 'temp/LASTFM_tags_dict.json'

    # Load the dictionary if it exists
    if os.path.exists(store_path):
        with open(store_path, 'r') as f:
            return json.load(f)

    # Create the dictionary otherwise
    tags_dict = {}
    for path in [paths.LASTFM_TRAIN_f, paths.LASTFM_TEST_F]:
        for root, dirs, files in os.walk(path):
            if files:
                for file in files:
                    track_dict = json.load(open(os.path.join(root, file)))
                    tags = track_dict['tags']
                    if tags:
                        track_id = track_dict['track_id'].strip("'")
                        tags_dict[track_id] = tags

    # Save the dictionary
    json.dump(tags_dict, open(store_path, 'w'))
    
    return tags_dict

LASTFM_tags_dict = get_LASTFM_tags_dict()

# %%
# PLOT SCORE DISTRIBUTION
def plot_tag_scores_distribution(LASTFM_tags_dict):
    scores = [int(score) for values in LASTFM_tags_dict.values() for t, score in values]

    plt.figure(figsize=(10, 5))
    plt.hist(scores, bins=50)
    plt.title('Tag score distribution')
    plt.xlabel('Score')
    plt.ylabel('Frequency')
    plt.show()

plot_tag_scores_distribution(LASTFM_tags_dict)

# %% [markdown]
# In some cases, LASTFM and FMA genres match, but have slightly different names. We have created a manual mapping for the most common LASTFM genres to FMA genres to increase the amount of LASTFM genres with matching genres with LASTFM. For that, we have manually checked the most common tags without mapping in LASTFM, and tried to match them with a genre in FMA.
#
# Mapping is inside `map_common_LASTFM_tags_to_genres`. To show the logic used, **uncomment the line using the function `show_most_common_LASTFM_tags`**
#
# For that, we use difflib to find the most similar FMA track to the most common 50 LASTFM non-matched tags, and manually create a mapping for those we consider to map

# %%
# LASTFM TAGS PREPROCESSING

def clean_LASTFM_tags(LASTFM_tags_dict):
    '''Only keep tags with a score above 50, convert to lowercase, and replace '-' with ' '.'''

    # Filter tags with score > 50
    LASTFM_tags_dict_50 = {track_id: [tag.lower().replace('-', ' ') # Convert to lowercase and replace '-'
                                    for tag, score in tags if int(score) > 50] # Keep only tags with score > 50
                                    for track_id, tags in LASTFM_tags_dict.items()}
    # Remove empty tags
    LASTFM_tags_dict_50 = {track_id: tags for track_id, tags in LASTFM_tags_dict_50.items() if tags}

    return LASTFM_tags_dict_50

def get_tags_genres_set(LASTFM_tags_dict_50, FMA_genres):
    # Get unique tags for LASTFM & FMA
    LASTFM_tags_set = set(t for tags in LASTFM_tags_dict_50.values() for t in tags)
    FMA_genres_set = set(g.lower().replace('-', ' ') for g in FMA_genres['title'])
    return LASTFM_tags_set, FMA_genres_set

def map_common_LASTFM_tags_to_genres(LASTFM_tags_dict_50, LASTFM_tags_set, FMA_genres_set):
    matching_tags = FMA_genres_set.intersection(LASTFM_tags_set)

    # Manually created mapping between LASTFM tags & FMA genres:
    MSD_FMA_genre_mapping = {
        'indie': 'indie rock',
        'classic': 'classical',
        'electronica': 'electronic',
        'electro': 'electronic',
        'soul': 'soul rnb',
        'rnb': 'soul rnb',
        'chillout': 'chill out',
        'chill': 'chill out',
        'minimal': 'minimalism',
        'reggae dancehall': 'dancehall',
        'synthpop': 'synth pop',
        **{tag: 'jazz' for tag in LASTFM_tags_set if 'jazz' in tag and tag not in matching_tags},  # All with the word jazz
        **{tag: 'rock' for tag in LASTFM_tags_set if 'rock' in tag and tag not in matching_tags},
        **{tag: 'metal' for tag in LASTFM_tags_set if 'metal' in tag and tag not in matching_tags},
    }

    # Apply the mapping
    LASTFM_tags_dict_50_mapped = {
        track_id: [MSD_FMA_genre_mapping[tag] if tag in MSD_FMA_genre_mapping else tag for tag in tags]
        for track_id, tags in LASTFM_tags_dict_50.items()
    }

    return LASTFM_tags_dict_50_mapped

def create_genre_parent_mapping(FMA_genres):
    """
    Map each genre name to a list of all its parent terms.
    Make it lowercase and replace '-' with ' '.
    """
    
    genre_mapping = {}  # Initialize the dictionary to hold genre-to-parent mappings
    
    for genre_id, row in FMA_genres.iterrows():
        genre_name = row['title'].lower().replace('-', ' ')
        parent_id = row['parent']
        parent_terms = []
        
        # Traverse up the parent hierarchy
        while parent_id != 0:
            parent_row = FMA_genres.loc[parent_id]
            parent_name = parent_row['title'].lower().replace('-', ' ')
            parent_terms.append(parent_name)
            parent_id = parent_row['parent']
        
        genre_mapping[genre_name] = parent_terms  # Store the parent terms list for the genre
    
    return genre_mapping

def expand_track_genres(LASTFM_genres_dict, genre_parent_mapping):
    """Expand each track's genres to include all parent genres."""
    expanded_genres_dict = {}
    
    for track_id, genres in LASTFM_genres_dict.items():
        all_genres = set()
        
        for genre in genres:
            genre = genre.lower().replace('-', ' ')
            all_genres.add(genre)  # Add the genre itself
            if genre in genre_parent_mapping:
                all_genres.update(genre_parent_mapping[genre])  # Add parent genres
        
        expanded_genres_dict[track_id] = list(all_genres)
    
    return expanded_genres_dict


# Prepare the data
LASTFM_tags_dict_50 = clean_LASTFM_tags(LASTFM_tags_dict)
LASTFM_tags_set, FMA_genres_set = get_tags_genres_set(LASTFM_tags_dict_50, FMA_genres)

# Map the common tags to FMA genres
LASTFM_tags_dict_50_mapped = map_common_LASTFM_tags_to_genres(LASTFM_tags_dict_50, LASTFM_tags_set, FMA_genres_set)

# Get the FMA genre-to-parent mapping
genre_parent_mapping = create_genre_parent_mapping(FMA_genres)

# GET LASTFM tracks with genres
LASTFM_genres_dict = {track_id: [t for t in tags if t in FMA_genres_set] # Keep only tags that map to genres
                      for track_id, tags in LASTFM_tags_dict_50_mapped.items() 
                      if set(tags).intersection(FMA_genres_set)} # Keep only tracks with genres

# Remove duplicates
LASTFM_genres_dict = {track_id: list(set(genres)) for track_id, genres in LASTFM_genres_dict.items()}

# Expand the genres to include all parent genres
LASTFM_all_genres_dict = expand_track_genres(LASTFM_genres_dict, genre_parent_mapping)

# Summary of the data obtained
def print_summary():
    print(f"We have {len(LASTFM_tags_dict_50)} tracks with tag scores above 50, with {len(LASTFM_tags_set)} unique tags")

    matching_tags = FMA_genres_set.intersection(LASTFM_tags_set)
    print(f"Of those, {len(matching_tags)} match with a FMA genre ({len(FMA_genres_set) - len(matching_tags)} FMA genres don't have a matching tag)")

    # Before mapping
    LASTFM_tracks_with_genres = {track_id: [t for t in tags if t in matching_tags] for track_id, tags in LASTFM_tags_dict_50.items() if set(tags).intersection(matching_tags)}
    print(f"Before mapping, there are {len(LASTFM_tracks_with_genres)} LASTFM tracks with matching genres in FMA")

    # After mapping
    tracks_with_genres = {track_id: [t for t in tags if t in matching_tags] for track_id, tags in LASTFM_tags_dict_50_mapped.items() if set(tags).intersection(matching_tags)}
    print(f"After mapping, there are {len(tracks_with_genres)} MSD tracks with matching genres in FMA")
print_summary()

# Function used to create the mapping between LASTFM & FMA
def show_most_common_LASTFM_tags(LASTFM_tags_dict_50, FMA_genres_set, num_similar=2, most_common_num=40):

    def get_most_similar_string(target, words, num_similar: int) -> list:
        return difflib.get_close_matches(target, words, n=num_similar, cutoff=0.0)

    # Get matching tags
    LASTFM_tags_set = set(t for tags in LASTFM_tags_dict_50.values() for t in tags)
    matching_tags = FMA_genres_set.intersection(LASTFM_tags_set)

    tags_without_genre = [t for tags in LASTFM_tags_dict_50.values() for t in tags if t not in matching_tags]

    print(f"{'LASTFM Tag':<20}{'Count':<10}Most similar FMA genres")
    for tag, count in Counter(tags_without_genre).most_common(most_common_num):
        most_similar_FMAs = get_most_similar_string(tag, FMA_genres_set, num_similar)
        print(f"{tag:<20}{count:<10}{most_similar_FMAs}")

print('\nUncomment code to display the most common LASTFM tags and their most similar FMA genres') 
# show_most_common_LASTFM_tags(LASTFM_tags_dict_50, matching_tags, num_similar=2) # Original tags
# print()
# show_most_common_LASTFM_tags(LASTFM_tags_dict_50_mapped, matching_tags) # Tags left after mapping
# Out:
# We have 505214 tracks with tag scores above 50, with 107856 unique tags
# Of those, 141 match with a FMA genre (22 FMA genres don't have a matching tag)
# Before mapping, there are 250587 LASTFM tracks with matching genres in FMA
# After mapping, there are 328933 MSD tracks with matching genres in FMA
#
# Uncomment code to display the most common LASTFM tags and their most similar FMA genres

# %%
# PLOT GENRE DISTRIBUTION
def show_genres_distribution(LASTFM_genres_dict, LASTFM_all_genres_dict, FMA_tracks):
    """Show the genre distribution for LASTFM and FMA datasets side by side."""
    
    # Calculate genre counts for LASTFM
    lastfm_original_counts = [len(genres) for genres in LASTFM_genres_dict.values()]
    lastfm_all_counts = [len(genres) for genres in LASTFM_all_genres_dict.values()]

    # Calculate genre counts for FMA
    fma_original_counts = [len(genres) for genres in FMA_tracks['track', 'genres']]
    fma_all_counts = [len(genres) for genres in FMA_tracks['track', 'genres_all']]

    # Define the bins to perfectly match each integer count (e.g., 0 to 30)
    max_genres = max(
        max(lastfm_original_counts, default=0), 
        max(lastfm_all_counts, default=0),
        max(fma_original_counts, default=0), 
        max(fma_all_counts, default=0)
    )
    bins = range(0, max(20, max_genres) + 2)  # +2 to include the last bin edge properly

    # Create side-by-side plots
    fig, axs = plt.subplots(1, 2, figsize=(10, 4), sharey=True)

    # LASTFM Plot
    axs[0].hist(lastfm_original_counts, bins=bins, alpha=0.5, label='Original genres', align='left')
    axs[0].hist(lastfm_all_counts, bins=bins, alpha=0.5, label='All genres (including parent genres)', align='left')
    axs[0].set_title('LASTFM Genre Distribution')
    axs[0].set_xlabel('Number of genres')
    axs[0].set_ylabel('Count')
    axs[0].set_xticks(bins)
    axs[0].set_xlim(0, 20)
    axs[0].legend()

    # FMA Plot
    axs[1].hist(fma_original_counts, bins=bins, alpha=0.5, label='Original genres', align='left')
    axs[1].hist(fma_all_counts, bins=bins, alpha=0.5, label='All genres (including parent genres)', align='left')
    axs[1].set_title('FMA Genre Distribution')
    axs[1].set_xlabel('Number of genres')
    axs[1].set_xticks(bins)
    axs[1].set_xlim(0, 20)
    axs[1].legend()

    plt.tight_layout()
    plt.suptitle('Genre Distribution in LASTFM and FMA Datasets', fontsize=16, y=1.02)
    plt.show()

show_genres_distribution(LASTFM_genres_dict, LASTFM_all_genres_dict, FMA_tracks)

# %%
# CONVERT TO ONE-HOT ENCODING & SAVE
# Convert to one-hot encoding
def one_hot_encode_LASTFM_genres(genres, genre_to_idx):
    '''One-hot encode all-genres for LASTFM dataset'''

    # Get number of genres
    num_genres = len(genre_to_idx) + 1 # 1 being the "no genre"

    # Initialise a one_hot vector
    one_hot = np.zeros(num_genres)
    
    # If no genres are present, return one-hot vector with 1 at the "no genre" index
    if len(genres) == 0:
        one_hot[num_genres-1] = 1
        return one_hot
    

    for genre in genres:
        one_hot[genre_to_idx[genre]] = 1

    return one_hot

# Create mapping from genre name to index
genre_to_idx = {genre: idx for idx, genre in enumerate(FMA_genres['title'].str.lower().str.replace('-', ' '))}

# Create one-hot encoding of genres from the LASTFM_all_genres_dict
one_hot_genres = {track_id: one_hot_encode_LASTFM_genres(genres, genre_to_idx) for track_id, genres in LASTFM_all_genres_dict.items()}
one_hot_genres = pd.DataFrame.from_dict(one_hot_genres, orient='index')

# Save
one_hot_genres.to_csv(paths.TEMP_D + 'LASTFM_one_hot_genres.tsv', sep='\t')

# %%
matching_tags = FMA_genres_set.intersection(LASTFM_tags_set)
show_most_common_LASTFM_tags(LASTFM_tags_dict_50, matching_tags, most_common_num=5000)
# Out:
# LASTFM Tag          Count     Most similar FMA genres
# indie               22218     ['indian', 'indie rock']
# female vocalists    16128     ['middle east', 'free folk']
# alternative         15296     ['alternative hip hop', 'international']
# soul                11978     ['soul rnb', 'surf']
# classic rock        9219      ['classical', 'space rock']
# 80s                 8947      ['surf', 'salsa']
# alternative rock    8038      ['alternative hip hop', 'noise rock']
# reggae              7284      ['shoegaze', 'breakbeat']
# hard rock           6883      ['loud rock', 'space rock']
# trance              6575      ['dance', 'tango']
# oldies              6552      ['noise', 'disco']
# progressive rock    5907      ['progressive', 'post rock']
# chillout            5850      ['chill out', 'country']
# 60s                 5274      ['surf', 'salsa']
# rnb                 4928      ['soul rnb', 'drone']
# electronica         4906      ['electronic', 'electro punk']
# punk rock           4810      ['post rock', 'loud rock']
# acoustic            4760      ['electroacoustic', 'choral music']
# 70s                 4509      ['surf', 'salsa']
# cover               4378      ['opera', 'poetry']
# 90s                 4316      ['surf', 'salsa']
# heavy metal         4136      ['death metal', 'black metal']
# electro             3830      ['electronic', 'electro punk']
# british             3508      ['british folk', 'turkish']
# psychedelic         3339      ['celtic', 'psych rock']
# indie pop           3321      ['indie rock', 'synth pop']
# piano               3199      ['tango', 'indian']
# metalcore           3187      ['metal', 'nerdcore']
# ska                 3088      ['salsa', 'polka']
# blues rock          3077      ['loud rock', 'blues']
# thrash metal        2855      ['death metal', 'thrash']
# love                2743      ['lounge', 'novelty']
# progressive metal   2688      ['progressive', 'death metal']
# german              2657      ['opera', 'americana']
# mellow              2618      ['metal', 'flamenco']
# guitar              2575      ['glitch', 'garage']
# christian           2550      ['christmas', 'chiptune']
# smooth jazz         2495      ['modern jazz', 'nu jazz']
# beautiful           2478      ['bigbeat', 'british folk']
# emo                 2343      ['downtempo', 'techno']
# 00s                 2315      ['surf', 'salsa']
# world               2234      ['spoken word', 'holiday']
# minimal             2221      ['minimalism', 'indian']
# power metal         2184      ['experimental', 'death metal']
# italian             2174      ['brazilian', 'indian']
# alt country         2141      ['country', 'sound poetry']
# title is a full sentence2121      ['british folk', 'minimal electronic']
# post hardcore       2059      ['hardcore', 'post rock']
# swedish             2022      ['spanish', 'disco']
# melodic death metal 1985      ['death metal', 'black metal']
# male vocalists      1984      ['middle east', 'christmas']
# 50s                 1960      ['surf', 'salsa']
# pop punk            1935      ['post punk', 'punk']
# finnish             1916      ['spanish', 'noise']
# 77davez all tracks  1894      ['soundtrack', 'indie rock']
# drjazzmrfunkmusic   1893      ['chamber music', 'choral music']
# dub                 1857      ['dubstep', 'cumbia']
# canadian            1809      ['indian', 'brazilian']
# chill               1754      ['chill out', 'rockabilly']
# dancehall           1749      ['dance', 'reggae   dancehall']
# synthpop            1747      ['synth pop', 'pop']
# favorites           1686      ['hardcore', 'fado']
# deutsch             1683      ['disco', 'techno']
# psychedelic rock    1653      ['psych rock', 'space rock']
# britpop             1647      ['trip hop', 'pop']
# gothic metal        1636      ['death metal', 'black metal']
# folk rock           1621      ['post rock', 'loud rock']
# christian rock      1614      ['post rock', 'christmas']
# ebm                 1606      ['klezmer', 'idm']
# gothic              1596      ['goth', 'north african']
# female vocalist     1558      ['middle east', 'free folk']
# doom metal          1529      ['metal', 'death metal']
# covers              1518      ['opera', 'poetry']
# brasil              1500      ['brazilian', 'radio']
# drum and bass       1495      ['drum & bass', 'sound art']
# pop rock            1455      ['post rock', 'loud rock']
# swing               1446      ['western swing', 'easy listening']
# grunge              1434      ['lounge', 'jungle']
# stoner rock         1400      ['post rock', 'space rock']
# garage rock         1395      ['garage', 'space rock']
# fusion              1345      ['funk', 'spoken']
# awesome             1343      ['spoken', 'skweee']
# motown              1335      ['compilation', 'symphony']
# acid jazz           1311      ['nu jazz', 'jazz']
# underground hip hop 1310      ['alternative hip hop', 'hip hop']
# progressive trance  1279      ['progressive', 'reggae   dancehall']
# psytrance           1264      ['dance', 'post rock']
# irish               1247      ['turkish', 'thrash']
# nu metal            1246      ['metal', 'instrumental']
# darkwave            1217      ['garage', 'no wave']
# cool                1214      ['folk', 'polka']
# hardcore punk       1201      ['hardcore', 'nerdcore']
# screamo             1159      ['radio', 'disco']
# industrial metal    1140      ['industrial', 'instrumental']
# rock n roll         1126      ['rockabilly', 'rock opera']
# gothic rock         1068      ['post rock', 'noise rock']
# neo soul            1063      ['soul rnb', 'free folk']
# chanson francaise   1056      ['sound collage', 'north african']
# rhythm and blues    1052      ['blues', 'drum & bass']
# sexy                1031      ['noise', 'house']
# classic country     1024      ['country', 'classical']
# deep house          1020      ['house', 'deep funk']
# minimal techno      1020      ['minimal electronic', 'techno']
# vocal trance        1019      ['soul rnb', 'dance']
# southern rock       996       ['post rock', 'loud rock']
# ballad              981       ['balkan', 'salsa']
# loved               963       ['lounge', 'comedy']
# guitar virtuoso     953       ['interview', 'british folk']
# bossa nova          937       ['post rock', 'post punk']
# mpb                 935       ['improv', 'cumbia']
# symphonic metal     928       ['symphony', 'death metal']
# dream pop           927       ['power pop', 'downtempo']
# soft rock           910       ['post rock', 'loud rock']
# australian          908       ['brazilian', 'industrial']
# sad                 906       ['fado', 'salsa']
# progressive house   896       ['progressive', 'house']
# electropop          887       ['electro punk', 'electronic']
# glam rock           887       ['loud rock', 'space rock']
# party               883       ['poetry', 'afrobeat']
# 2000s               862       ['surf', '20th century classical']
# american            857       ['americana', 'african']
# melancholy          856       ['flamenco', 'metal']
# folk metal          856       ['black metal', 'metal']
# funky               840       ['funk', 'punk']
# catchy              837       ['techno', 'glitch']
# dark ambient        828       ['ambient', 'black metal']
# worship             827       ['thrash', 'gospel']
# happy               794       ['rap', 'pop']
# fun                 794       ['funk', 'punk']
# psychobilly         792       ['psych folk', 'rockabilly']
# doo wop             790       ['power pop', 'downtempo']
# gangsta rap         789       ['industrial', 'garage']
# deathcore           785       ['death metal', 'nerdcore']
# favorite            782       ['hardcore', 'fado']
# norwegian           781       ['north african', 'indian']
# romantic            780       ['electronic', 'compilation']
# prda                761       ['opera', 'rap']
# eurodance           750       ['dance', 'europe']
# northern soul       750       ['international', 'western swing']
# live                748       ['noise', 'lo fi']
# brutal death metal  741       ['death metal', 'black metal']
# tech house          740       ['house', 'techno']
# lovedbybeyondwithin 730       ['western swing', 'easy listening']
# remix               719       ['radio', 'drone']
# alternative metal   709       ['alternative hip hop', 'death metal']
# friendsofthekingofrummelpop707       ['grindcore', 'field recordings']
# rock and roll       694       ['rockabilly', 'sound collage']
# oi                  692       ['noise', 'lo fi']
# political           683       ['polka', 'classical']
# female              683       ['metal', 'freak folk']
# japanese            681       ['spanish', 'noise']
# saxophone           676       ['symphony', 'spoken']
# jazz fusion         669       ['jazz', 'nu jazz']
# stream              666       ['thrash', 'soundtrack']
# relaxing            654       ['latin', 'brazilian']
# vocal               653       ['rockabilly', 'rock']
# melancholic         649       ['electronic', 'flamenco']
# rock en espanol     645       ['rockabilly', 'rock opera']
# 1990s               645       ['surf', 'salsa']
# twee                645       ['skweee', 'interview']
# samba               639       ['salsa', 'cumbia']
# atmospheric         635       ['americana', 'latin america']
# funny               633       ['funk', 'country']
# ska punk            625       ['post punk', 'punk']
# favourite           624       ['fado', 'sound art']
# roots reggae        621       ['shoegaze', 'rock opera']
# polish              620       ['spanish', 'polka']
# hiphop              618       ['hip hop', 'trip hop']
# male vocalist       616       ['middle east', 'easy listening']
# electroclash        615       ['electronic', 'electroacoustic']
# favourites          615       ['turkish', 'fado']
# jazz piano          614       ['jazz', 'brazilian']
# electro house       596       ['electro punk', 'electroacoustic']
# suomipop            591       ['pop', 'hip hop']
# sousaphonic aotm 201102587       ['sound art', 'sound poetry']
# francais            582       ['french', 'spanish']
# rock argentino      581       ['rockabilly', 'rock opera']
# hair metal          579       ['metal', 'death metal']
# love songs          577       ['lounge', 'field recordings']
# club                566       ['cumbia', 'chill out']
# chanson             560       ['techno', 'tango']
# crossover           557       ['progressive', 'rock opera']
# scottish            553       ['turkish', 'spanish']
# technical death metal552       ['death metal', 'musical theater']
# ethereal            552       ['metal', 'experimental']
# summer              549       ['surf', 'sludge']
# world music         546       ['choral music', 'chamber music']
# groovy              546       ['improv', 'novelty']
# relax               543       ['rap', 'free jazz']
# uplifting trance    543       ['latin america', 'soundtrack']
# good                541       ['goth', 'bollywood']
# big band            537       ['bigbeat', 'brazilian']
# 2009                536       ['20th century classical', 'wonky']
# old school          535       ['disco', 'sound collage']
# smooth              534       ['goth', 'sound poetry']
# spanish rock        531       ['spanish', 'space rock']
# female vocals       530       ['free folk', 'freak folk']
# heard on pandora    530       ['hardcore', 'rock opera']
# goa                 528       ['goth', 'tango']
# contemporary gospel tag523       ['contemporary classical', 'downtempo']
# viking metal        519       ['black metal', 'metal']
# dreamy              519       ['drone', 'death metal']
# metro downtempo     516       ['downtempo', 'electro punk']
# jazz vocal          512       ['jazz', 'nu jazz']
# epic                510       ['celtic', 'americana']
# 1980s               509       ['surf', 'salsa']
# latin pop           509       ['latin', 'trip hop']
# breaks              503       ['breakbeat', 'blues']
# bass                490       ['bluegrass', 'drum & bass']
# nice                482       ['noise', 'dance']
# somafm              481       ['shoegaze', 'surf']
# dark                479       ['rock', 'sound art']
# rapcore             479       ['nerdcore', 'hardcore']
# vocal jazz          475       ['nu jazz', 'modern jazz']
# under two minutes   469       ['singer songwriter', 'drone']
# dark electro        459       ['electronic', 'minimal electronic']
# indietronica        458       ['indie rock', 'minimal electronic']
# 2008                454       ['20th century classical', 'wonky']
# futurepop           450       ['trip hop', 'europe']
# breakcore           447       ['breakbeat', 'nerdcore']
# rb                  446       ['soul rnb', 'rap']
# amazing             445       ['ambient', 'tango']
# africa              444       ['african', 'americana']
# upbeat              439       ['bigbeat', 'afrobeat']
# industrial rock     436       ['industrial', 'indie rock']
# melodic hardcore    435       ['hardcore', 'nerdcore']
# ninja tune          434       ['chiptune', 'jungle']
# indie folk          432       ['indie rock', 'british folk']
# slow jams           430       ['sound art', 'salsa']
# czech               425       ['techno', 'french']
# deathrock           418       ['krautrock', 'indie rock']
# slow                414       ['salsa', 'lo fi']
# sweet               412       ['skweee', 'shoegaze']
# mathcore            411       ['hardcore', 'nerdcore']
# jazz funk           410       ['jazz', 'funk']
# dutch               408       ['techno', 'glitch']
# country rock        408       ['country', 'post rock']
# mod                 406       ['improv', 'comedy']
# reggaeton           405       ['breakbeat', 'electronic']
# rocksteady          402       ['rockabilly', 'rock opera']
# arabic              401       ['african', 'radio']
# best                401       ['blues', 'dubstep']
# female fronted metal399       ['experimental', 'free folk']
# drum n bass         396       ['drum & bass', 'cumbia']
# tag                 392       ['tango', 'metal']
# big beat            391       ['bigbeat', 'breakbeat']
# latin jazz          389       ['nu jazz', 'latin']
# contemporary christian386       ['contemporary classical', 'compilation']
# suomi               384       ['cumbia', 'surf']
# classic             381       ['classical', 'celtic']
# uk                  378       ['punk', 'funk']
# west coast          375       ['western swing', 'electroacoustic']
# jazzy               373       ['jazz', 'nu jazz']
# tantotempotaste     373       ['downtempo', 'afrobeat']
# dnb                 371       ['drone', 'dance']
# trumpet             368       ['instrumental', 'metal']
# neofolk             367       ['folk', 'free folk']
# favorite songs      365       ['field recordings', 'singer songwriter']
# allboutguitar       362       ['chill out', 'lounge']
# groove              362       ['drone', 'grindcore']
# delta blues         361       ['blues', 'metal']
# math rock           359       ['post rock', 'krautrock']
# soul and rnb classics357       ['soul rnb', 'sound collage']
# deutschrock         356       ['psych rock', 'krautrock']
# j rock              355       ['rock', 'post rock']
# basically bass      350       ['classical', 'musical theater']
# emocore             350       ['nerdcore', 'hardcore']
# urban               350       ['cumbia', 'balkan']
# hands up            350       ['thrash', 'spanish']
# schlager            348       ['sound collage', 'sludge']
# classic blues       339       ['classical', 'unclassifiable']
# great               338       ['bigbeat', 'afrobeat']
# symphonic black metal335       ['black metal', 'symphony']
# stand up            335       ['sound poetry', 'synth pop']
# 3 star              334       ['surf', 'sound art']
# usa                 333       ['salsa', 'house']
# iskelma             333       ['noise', 'christmas']
# powerpop            332       ['power pop', 'downtempo']
# italo disco         330       ['disco', 'radio']
# alternative  punk   329       ['alternative hip hop', 'international']
# grime               328       ['grindcore', 'garage']
# art rock            326       ['post rock', 'krautrock']
# 1960s               325       ['surf', 'salsa']
# jazz rock           325       ['space rock', 'rock']
# progressive death metal325       ['progressive', 'death metal']
# psychill            325       ['psych folk', 'chill out']
# melodic rock        324       ['loud rock', 'noise rock']
# good stuff          323       ['sound effects', 'surf']
# cuba                323       ['cumbia', 'drum & bass']
# chinese             322       ['chiptune', 'noise']
# 1970s               320       ['surf', 'salsa']
# love song           319       ['lounge', 'singer songwriter']
# brazil              318       ['brazilian', 'radio']
# love it             318       ['lo fi', 'novelty']
# piano rock          318       ['post rock', 'space rock']
# italiana            317       ['brazilian', 'americana']
# 4ad                 317       ['fado', 'radio']
# madchester          317       ['musical theater', 'middle east']
# dirty south         315       ['disco', 'chill out']
# uplifting           314       ['latin', 'easy listening']
# love at first listen313       ['easy listening', 'north african']
# contemporary jazz   313       ['contemporary classical', 'modern jazz']
# lovers rock         313       ['post rock', 'loud rock']
# 6070                310       ['20th century classical', 'wonky']
# favourite songs     309       ['field recordings', 'singer songwriter']
# new orleans         307       ['new age', 'new wave']
# melodic black metal 307       ['black metal', 'death metal']
# turntablism         306       ['minimalism', 'turkish']
# west coast rap      305       ['post rock', 'salsa']
# violin              304       ['latin', 'brazilian']
# icelandic           304       ['celtic', 'classical']
# vocalization        304       ['compilation', 'latin']
# portugal            302       ['experimental', 'post punk']
# proto punk          302       ['post punk', 'electro punk']
# avantgarde          302       ['avant garde', 'garage']
# liquid funk         302       ['deep funk', 'funk']
# fav                 301       ['fado', 'no wave']
# energetic           299       ['celtic', 'electronic']
# great song          299       ['western swing', 'singer songwriter']
# 2007                296       ['20th century classical', 'wonky']
# hard trance         295       ['hardcore', 'dance']
# favorite by this singer295       ['easy listening', 'western swing']
# latino              294       ['latin', 'compilation']
# mexico              293       ['flamenco', 'disco']
# argentina           291       ['latin', 'americana']
# soft                290       ['surf', 'goth']
# audioase            290       ['radio', 'hardcore']
# melodic metal       289       ['black metal', 'death metal']
# riot grrrl          289       ['british folk', 'post rock']
# italianigdchill     288       ['reggae   dancehall', 'chill out']
# 2010                287       ['20th century classical', 'wonky']
# r&b                 285       ['drum & bass', 'soul rnb']
# medieval            285       ['metal', 'americana']
# true hip hop        285       ['trip hop', 'hip hop']
# street punk         284       ['post punk', 'electro punk']
# digital hardcore    284       ['hardcore', 'grindcore']
# memories            284       ['nerdcore', 'interview']
# interesting         283       ['international', 'interview']
# meditation          283       ['compilation', 'international']
# psychedelic trance  281       ['psych rock', 'electronic']
# danish              280       ['spanish', 'noise']
# strictly for the undergound279       ['musical theater', 'abstract hip hop']
# portuguese          279       ['progressive', 'house']
# english             277       ['glitch', 'spanish']
# lovely              277       ['novelty', 'poetry']
# newbest             276       ['new age', 'new wave']
# my favorite         276       ['no wave', 'singer songwriter']
# texas               276       ['thrash', 'christmas']
# melodic             275       ['celtic', 'electronic']
# rock en español     274       ['rockabilly', 'rock opera']
# jam                 273       ['jazz', 'nu jazz']
# brilliant           272       ['brazilian', 'indian']
# male vocals         271       ['middle east', 'space rock']
# suomirock           269       ['noise rock', 'rock']
# feel good           268       ['free folk', 'free jazz']
# b side              267       ['sludge', 'bigbeat']
# animals             267       ['minimalism', 'spanish']
# cuban               266       ['cumbia', 'balkan']
# jazz guitar         266       ['jazz', 'avant garde']
# freedom             266       ['free folk', 'fado']
# france              265       ['dance', 'french']
# instrumental hip hop264       ['instrumental', 'abstract hip hop']
# 2006                262       ['20th century classical', 'wonky']
# stoner              262       ['sound poetry', 'opera']
# nederlandstalig     261       ['experimental', 'international']
# beats               260       ['bigbeat', 'afrobeat']
# 1live fiehe         260       ['lo fi', 'unclassifiable']
# heard on last fm    259       ['hardcore', 'easy listening']
# stoner metal        259       ['instrumental', 'death metal']
# calm                258       ['choral music', 'classical']
# latin rock          257       ['indie rock', 'latin america']
# my gang 09          257       ['tango', 'garage']
# native american     255       ['latin america', 'americana']
# goodbye             254       ['gospel', 'holiday']
# spanish pop         253       ['spanish', 'synth pop']
# solomusika loved    253       ['musical theater', 'choral music']
# world fusion        250       ['choral music', 'north african']
# roots               249       ['afrobeat', 'rock']
# 2005                248       ['20th century classical', 'wonky']
# pretty              248       ['poetry', 'novelty']
# brain2brain         247       ['brazilian', 'breakbeat']
# rave                247       ['garage', 'rap']
# 2003                245       ['20th century classical', 'wonky']
# acoustic guitar     245       ['electroacoustic', 'avant garde']
# slowcore            244       ['spoken word', 'nerdcore']
# detroit             243       ['electronic', 'drone']
# handclaps           241       ['hardcore', 'sound collage']
# ragga               241       ['garage', 'rap']
# greek               241       ['free folk', 'garage']
# merengue            239       ['americana', 'drone']
# deep                239       ['deep funk', 'dubstep']
# instrumental rock   238       ['instrumental', 'noise rock']
# romantica           236       ['electronic', 'electroacoustic']
# other               234       ['goth', 'opera']
# adrien wayne        234       ['no wave', 'african']
# just another folk singer232       ['western swing', 'psych folk']
# electro pop         231       ['electro punk', 'electronic']
# horror punk         231       ['electro punk', 'post punk']
# class struggle      230       ['classical', 'unclassifiable']
# cabaret             230       ['ambient', 'afrobeat']
# flute               229       ['blues', 'sludge']
# psy trance          229       ['dance', 'post rock']
# cantautor           228       ['musical theater', 'country']
# experimental rock   227       ['experimental pop', 'experimental']
# gypsy               227       ['psych rock', 'psych folk']
# humor               225       ['hardcore', 'surf']
# weird               224       ['idm', 'nerdcore']
# everbest            224       ['experimental', 'afrobeat']
# easy                223       ['bluegrass', 'opera']
# new zealand         222       ['new age', 'new wave']
# mystie chamberlin   221       ['latin america', 'chamber music']
# harmonica           221       ['african', 'americana']
# underrated          221       ['sound art', 'soundtrack']
# quirky              221       ['turkish', 'country']
# the merch grrls     220       ['death metal', 'latin america']
# throwaway grrls     220       ['thrash', 'progressive']
# rock nacional       220       ['international', 'rockabilly']
# belgian             220       ['brazilian', 'balkan']
# ethnic              220       ['celtic', 'electronic']
# irish folk          220       ['british folk', 'psych folk']
# groovesalad         220       ['salsa', 'rock opera']
# synth               219       ['synth pop', 'spanish']
# cute                219       ['dubstep', 'country']
# the devil and the deep blue sea218       ['hip hop beats', 'death metal']
# 3 stars             218       ['salsa', 'christmas']
# songs by bands with the suffix head218       ['sound effects', 'contemporary classical']
# bachata             218       ['black metal', 'christmas']
# haunting            218       ['latin', 'tango']
# post grunge         218       ['post punk', 'post rock']
# female vocal        217       ['free folk', 'freak folk']
# retro               217       ['krautrock', 'poetry']
# teh typos           217       ['synth pop', 'techno']
# freestyle           217       ['free folk', 'afrobeat']
# goregrind           216       ['grindcore', 'north african']
# 20th century        215       ['20th century classical', 'country']
# german hiphop       215       ['alternative hip hop', 'hip hop']
# surf rock           215       ['post rock', 'loud rock']
# chanson française   215       ['north african', 'noise']
# score               213       ['nerdcore', 'hardcore']
# christian metal     213       ['christmas', 'instrumental']
# goa trance          213       ['garage', 'dance']
# 2002                213       ['20th century classical', 'wonky']
# electro industrial  212       ['industrial', 'electroacoustic']
# scandinavian        211       ['indian', 'latin america']
# names               211       ['no wave', 'ambient']
# finland             210       ['indian', 'african']
# transym             210       ['thrash', 'tango']
# cantautori          210       ['industrial', 'musical theater']
# 2004                208       ['20th century classical', 'wonky']
# driving             208       ['drone', 'brazilian']
# hardstyle           207       ['hardcore', 'dubstep']
# sludge metal        207       ['death metal', 'sludge']
# acid                206       ['idm', 'fado']
# 2000                204       ['20th century classical', 'wonky']
# post metal          204       ['metal', 'death metal']
# speed               203       ['spoken', 'skweee']
# 80's                203       ['surf', 'salsa']
# bestone             203       ['dubstep', 'drone']
# xmas                201       ['christmas', 'metal']
# r and b             201       ['radio', 'african']
# jazz hop            200       ['jazz', 'nu jazz']
# pagan metal         199       ['death metal', 'black metal']
# old school soul     199       ['chill out', 'choral music']
# drums               199       ['drum & bass', 'idm']
# 2giveme5            198       ['progressive', 'klezmer']
# jazz instrumental   198       ['instrumental', 'international']
# over 5 minutes long 198       ['compilation', 'singer songwriter']
# singer              198       ['interview', 'singer songwriter']
# disney              197       ['noise', 'drone']
# crust               197       ['christmas', 'electroacoustic']
# 2001                196       ['20th century classical', 'wonky']
# new rave            196       ['new wave', 'new age']
# 4 stars             195       ['salsa', 'christmas']
# darklight           195       ['turkish', 'sound art']
# banjo               195       ['tango', 'balkan']
# musical             195       ['musical theater', 'classical']
# mexican             195       ['americana', 'african']
# huumoria            194       ['cumbia', 'holiday']
# nostalgia           194       ['salsa', 'north african']
# espanol             194       ['spanish', 'tango']
# blues harmonica greats193       ['bluegrass', 'musique concrete']
# glam metal          193       ['black metal', 'metal']
# michael jackson     191       ['minimal electronic', 'musical theater']
# mali                191       ['metal', 'minimalism']
# midbest             191       ['middle east', 'dubstep']
# new york            190       ['indie rock', 'new age']
# berlin              190       ['brazilian', 'latin']
# deutschrap          190       ['thrash', 'industrial']
# emotional           190       ['international', 'metal']
# vocal house         189       ['house', 'choral music']
# spanish indie pop   189       ['spanish', 'synth pop']
# speed metal         189       ['death metal', 'metal']
# east coast rap      188       ['death metal', 'latin america']
# bay area            188       ['black metal', 'avant garde']
# great lyrics        188       ['north african', 'latin america']
# die wahren perlen deutschsprachiger popmusik187       ['experimental pop', 'electroacoustic']
# metro electronica   187       ['ambient electronic', 'electronic']
# torquemada          187       ['instrumental', 'sound art']
# peaceful            187       ['deep funk', 'opera']
# genius              186       ['noise', 'spanish']
# sensual             186       ['instrumental', 'salsa']
# new romantic        184       ['noise rock', 'indie rock']
# finnish metal       183       ['instrumental', 'death metal']
# 40s                 183       ['surf', 'salsa']
# groove metal        183       ['death metal', 'metal']
# liedermacher        182       ['dance', 'glitch']
# 6am                 182       ['ambient', 'flamenco']
# emusic              180       ['chamber music', 'choral music']
# soundtracks         180       ['soundtrack', 'sound poetry']
# jam band            179       ['ambient', 'americana']
# folk punk           179       ['post punk', 'punk']
# good beat           179       ['bigbeat', 'afrobeat']
# acordes geniales    179       ['death metal', 'black metal']
# rockpop             179       ['rock', 'rock opera']
# french pop          179       ['french', 'synth pop']
# bebop               178       ['be bop', 'europe']
# da real underground new skool hip hop178       ['alternative hip hop', 'abstract hip hop']
# like                178       ['folk', 'polka']
# test                177       ['metal', 'blues']
# punk favorites      177       ['sound art', 'no wave']
# i feel good         177       ['free folk', 'free jazz']
# the way you look    177       ['british folk', 'free folk']
# psybient            176       ['ambient', 'bigbeat']
# california          176       ['unclassifiable', 'indian']
# 1995                175       ['wonky', 'western swing']
# fucking awesome     175       ['singer songwriter', 'latin america']
# detroit techno      174       ['techno', 'trip hop']
# tribal              174       ['industrial', 'metal']
# arguman loved tracks174       ['loud rock', 'soundtrack']
# happy hardcore      174       ['hardcore', 'nerdcore']
# alt rock            173       ['post rock', 'loud rock']
# tech trance         171       ['techno', 'electronic']
# bestallof           171       ['metal', 'black metal']
# rhythum and blues tag170       ['drum & bass', 'sound collage']
# sex                 168       ['noise', 'house']
# dark wave           168       ['no wave', 'new wave']
# aor                 167       ['fado', 'hardcore']
# de todo mio favoritos167       ['death metal', 'loud rock']
# tejano              167       ['tango', 'techno']
# underground         166       ['drone', 'indie rock']
# adult contemporary  166       ['contemporary classical', 'downtempo']
# suomirap            166       ['cumbia', 'rap']
# blackened death metal166       ['death metal', 'black metal']
# seattle             166       ['shoegaze', 'salsa']
# downbeat            165       ['afrobeat', 'drone']
# ranchera            165       ['dance', 'french']
# strings             165       ['western swing', 'turkish']
# tracking 2008       164       ['tango', 'soundtrack']
# ballads             164       ['balkan', 'salsa']
# italia              164       ['salsa', 'metal']
# melodic trance      163       ['electronic', 'dance']
# eurovision          163       ['europe', 'compilation']
# celeste nostalgia   163       ['instrumental', 'experimental']
# musicals            163       ['salsa', 'musical theater']
# streamable track wants163       ['americana', 'electroacoustic']
# texas country       163       ['country', 'sound poetry']
# visual kei          162       ['instrumental', 'soul rnb']
# martial industrial  162       ['industrial', 'instrumental']
# glam                162       ['flamenco', 'polka']
# lush                162       ['blues', 'turkish']
# new jack swing      162       ['new age', 'western swing']
# funk metal          161       ['metal', 'black metal']
# musica portuguesa   160       ['musical theater', 'chiptune']
# bittersweet         160       ['interview', 'breakbeat']
# obscure yet streamable tracks159       ['post rock', 'christmas']
# law                 159       ['polka', 'latin']
# soothing            159       ['goth', 'western swing']
# inspirational       159       ['international', 'industrial']
# seen live           159       ['skweee', 'no wave']
# rap francais        158       ['spanish', 'african']
# beat                158       ['bigbeat', 'afrobeat']
# hungarian           158       ['african', 'americana']
# funky jazz          158       ['nu jazz', 'free jazz']
# male                158       ['metal', 'salsa']
# love to death       158       ['middle east', 'hip hop beats']
# lacrimaindarkness   157       ['grindcore', 'christmas']
# damn                157       ['dance', 'idm']
# sweden              157       ['skweee', 'spoken']
# good shit           156       ['goth', 'sound art']
# stand up comedy     155       ['sound poetry', 'comedy']
# miscellaneous       155       ['sound collage', 'chill out']
# brc blues band karlsruhe155       ['sound art', 'breakbeat']
# stax                155       ['christmas', 'tango']
# discoverockult      154       ['space rock', 'noise rock']
# metro funky         154       ['electro punk', 'deep funk']
# attitude            154       ['chiptune', 'latin']
# sleaze rock         154       ['space rock', 'noise rock']
# 1                   154       ['wonky', 'western swing']
# singer songwritergdchill154       ['singer songwriter', 'musique concrete']
# brc blues band      152       ['blues', 'brazilian']
# new                 151       ['new age', 'new wave']
# northwest           151       ['novelty', 'no wave']
# 1997                151       ['wonky', 'western swing']
# quiet storm         151       ['middle east', 'instrumental']
# garage punk         150       ['garage', 'punk']
# alternative pop     149       ['alternative hip hop', 'abstract hip hop']
# chile               149       ['chiptune', 'chill out']
# the best            149       ['middle east', 'death metal']
# igorfree            149       ['grindcore', 'free jazz']
# brazilian rock      149       ['brazilian', 'indie rock']
# spotify             148       ['poetry', 'sound poetry']
# broadway            148       ['holiday', 'breakbeat']
# g funk              148       ['funk', 'deep funk']
# intense             148       ['interview', 'chiptune']
# electglitchdubhop   148       ['glitch', 'electro punk']
# over twenty minutes 147       ['singer songwriter', 'choral music']
# traditional         147       ['radio', 'international']
# boogie woogie       147       ['bollywood', 'noise rock']
# chicago blues       147       ['blues', 'hip hop beats']
# nederpop            146       ['power pop', 'europe']
# winter              146       ['interview', 'downtempo']
# soulful house       146       ['house', 'sound poetry']
# soulful             145       ['surf', 'soul rnb']
# cool jazz           145       ['nu jazz', 'jazz']
# rock francais       145       ['rock opera', 'rockabilly']
# real post hardcore  145       ['hardcore', 'nerdcore']
# 1991                145       ['wonky', 'western swing']
# spain               145       ['spanish', 'latin']
# dark metal          145       ['death metal', 'black metal']
# favouritestreamable 144       ['international', 'christmas']
# strings organs rubber wind144       ['western swing', 'latin america']
# avant garde metal   144       ['avant garde', 'death metal']
# jamaica             143       ['americana', 'african']
# radiohead           143       ['radio', 'afrobeat']
# rockin              143       ['rock', 'rockabilly']
# quiet               143       ['bigbeat', 'ambient']
# 4                   143       ['wonky', 'western swing']
# swiss               143       ['spanish', 'christmas']
# dance punk          143       ['dance', 'deep funk']
# my pop music        143       ['choral music', 'chamber music']
# shakira             143       ['salsa', 'thrash']
# heavy               142       ['holiday', 'shoegaze']
# emotive             142       ['noise', 'europe']
# baroque             142       ['hardcore', 'afrobeat']
# elektronischer b0lzen142       ['electronic', 'electro punk']
# blues guitar greats 142       ['bluegrass', 'musical theater']
# 1990                142       ['20th century classical', 'wonky']
# ragtime             142       ['garage', 'radio']
# cover songs         142       ['western swing', 'singer songwriter']
# under a minute      141       ['sound art', 'death metal']
# morning             141       ['western swing', 'americana']
# dancehall reggae    141       ['reggae   dancehall', 'dance']
# dream               141       ['drone', 'rap']
# fleetwood mac       141       ['loud rock', 'free jazz']
# dance pop           140       ['dance', 'synth pop']
# rock chileno        139       ['rockabilly', 'rock opera']
# chicago             139       ['tango', 'disco']
# late night          139       ['latin', 'easy listening']
# neoclassical        139       ['classical', 'unclassifiable']
# congo               139       ['tango', 'techno']
# perfect             139       ['experimental', 'sound effects']
# neurofunk           139       ['funk', 'electro punk']
# halloween           139       ['shoegaze', 'hardcore']
# hard dance          138       ['hardcore', 'dance']
# damned good         138       ['tango', 'dance']
# transitglambat      138       ['christmas', 'brazilian']
# folktronica         138       ['electronic', 'african']
# 1992                138       ['20th century classical', 'wonky']
# minimal house       137       ['minimalism', 'minimal electronic']
# nyhc                136       ['wonky', 'dance']
# sxsw 2009           136       ['salsa', 'western swing']
# feelgood            136       ['free folk', 'bollywood']
# exotica             136       ['celtic', 'north african']
# all the best        136       ['middle east', 'death metal']
# i like              135       ['folk', 'easy listening']
# karlsruhe           135       ['hardcore', 'salsa']
# espinol             135       ['experimental', 'polka']
# a cappella          135       ['sound collage', 'americana']
# rain                135       ['radio', 'latin']
# soca                135       ['shoegaze', 'rock']
# night               135       ['spanish', 'bigbeat']
# music               135       ['choral music', 'chamber music']
# hot                 135       ['goth', 'house']
# southern gospel     134       ['gospel', 'sound poetry']
# anarcho punk        134       ['electro punk', 'post punk']
# 60's                134       ['surf', 'salsa']
# classic soul        133       ['classical', 'unclassifiable']
# eminem              133       ['minimalism', 'klezmer']
# quebec              133       ['dubstep', 'sound effects']
# rumba               133       ['cumbia', 'drum & bass']
# atmosphere          133       ['opera', 'gospel']
# jangle pop          132       ['jungle', 'tango']
# laidback            132       ['holiday', 'latin america']
# morose deep dilate crimson132       ['compilation', 'musical theater']
# uk top 40           132       ['rock opera', 'europe']
# sleek               131       ['sludge', 'skweee']
# goth rock           131       ['post rock', 'loud rock']
# 21st century        131       ['20th century classical', 'country']
# check out           131       ['chill out', 'country']
# funky house         130       ['house', 'funk']
# hopuke42            130       ['house', 'punk']
# vocals              130       ['salsa', 'rockabilly']
# old skool           130       ['folk', 'sound collage']
# poprock             130       ['post rock', 'rock']
# finnish lyrics      129       ['noise rock', 'indie rock']
# gilles peterson     129       ['minimal electronic', 'electronic']
# deathgrind          129       ['latin', 'grindcore']
# russian             129       ['african', 'classical']
# svenskt             128       ['spoken', 'spanish']
# wood and string     128       ['western swing', 'easy listening']
# dansk               128       ['dance', 'indian']
# nu soul             128       ['soul rnb', 'industrial']
# one tree hill       127       ['free folk', 'reggae   dancehall']
# j pop               127       ['pop', 'synth pop']
# 1994                126       ['wonky', 'western swing']
# progressiv          126       ['progressive', 'improv']
# moody               126       ['comedy', 'holiday']
# symphonic rock      126       ['space rock', 'psych rock']
# yes                 126       ['blues', 'bluegrass']
# trippy              126       ['trip hop', 'poetry']
# congolese music rocks126       ['noise rock', 'choral music']
# ndw                 126       ['indian', 'no wave']
# my favorites        126       ['no wave', 'singer songwriter']
# download            126       ['downtempo', 'bollywood']
# 1996                125       ['wonky', 'western swing']
# midtempo            125       ['downtempo', 'improv']
# 80s pop             125       ['synth pop', 'pop']
# blues jazz singers  124       ['bluegrass', 'nu jazz']
# new weird america   124       ['latin america', 'new wave']
# sax                 124       ['salsa', 'spanish']
# zouk                123       ['rock', 'punk']
# real hip hop        123       ['hip hop', 'trip hop']
# trova               123       ['thrash', 'improv']
# strange             123       ['tango', 'garage']
# <3                  123       ['wonky', 'western swing']
# romantic tension    123       ['compilation', 'international']
# brems tagg radio    123       ['radio', 'post rock']
# 1950s               123       ['surf', 'salsa']
# 1982                123       ['20th century classical', 'wonky']
# nouvelle scene francaise123       ['electronic', 'electroacoustic']
# cpop                123       ['pop', 'hip hop']
# italiano            123       ['tango', 'brazilian']
# beyonce             123       ['drone', 'dance']
# lovedtrack          122       ['soundtrack', 'loud rock']
# kickstart beat happening122       ['easy listening', 'musical theater']
# folkrock            122       ['rock', 'folk']
# alternative country 122       ['alternative hip hop', 'international']
# bolero              122       ['opera', 'blues']
# hi nrg              121       ['hip hop', 'chiptune']
# faves               121       ['no wave', 'new wave']
# neue deutsche welle 121       ['death metal', 'reggae   dancehall']
# christmas tag       121       ['christmas', 'instrumental']
# blue eyed soul      121       ['blues', 'bluegrass']
# india               121       ['indian', 'industrial']
# mid                 121       ['idm', 'indian']
# out of our heads    121       ['rock opera', '20th century classical']
# deutschpunk         121       ['deep funk', 'punk']
# shim sham shimmy    121       ['hip hop beats', 'christmas']
# spiritual           120       ['experimental', 'industrial']
# i want back to the 80s120       ['abstract hip hop', 'black metal']
# crunk               120       ['punk', 'funk']
# 4 star              120       ['surf', 'sound art']
# all of my songs     120       ['easy listening', 'field recordings']
# weallgetold         120       ['electronic', 'death metal']
# san francisco       120       ['spanish', 'african']
# special             119       ['gospel', 'experimental']
# first person songs  119       ['western swing', 'field recordings']
# alternate rock      119       ['alternative hip hop', 'krautrock']
# cover version       119       ['choral music', 'chamber music']
# 1993                119       ['wonky', 'western swing']
# skate punk          119       ['post punk', 'punk']
# instrumental jazz tag118       ['instrumental', 'nu jazz']
# lyrics              118       ['glitch', 'electronic']
# humour              118       ['house', 'country']
# mariachi            118       ['african', 'abstract hip hop']
# subelamusica        117       ['classical', 'chamber music']
# children            117       ['hardcore', 'field recordings']
# sympathy68          117       ['symphony', 'spanish']
# lion                117       ['latin', 'lounge']
# space               117       ['space rock', 'dance']
# rihanna             117       ['americana', 'african']
# noisecore           116       ['noise', 'nerdcore']
# emd                 116       ['comedy', 'klezmer']
# energy              116       ['poetry', 'novelty']
# nujazz              116       ['nu jazz', 'jazz']
# c pop               116       ['pop', 'synth pop']
# gabber              116       ['garage', 'bigbeat']
# chilled             116       ['chill out', 'chiptune']
# acid house          116       ['house', 'hip hop']
# coldwave            115       ['no wave', 'holiday']
# baladas             115       ['balkan', 'salsa']
# hammond             115       ['holiday', 'ambient']
# sleep               115       ['sludge', 'skweee']
# beatles cover       115       ['blues', 'electronic']
# mind melting        115       ['indian', 'minimal electronic']
# german hip hop      115       ['hip hop', 'alternative hip hop']
# djmfmylovedmusic    115       ['chamber music', 'choral music']
# stonedbeat          114       ['sound art', 'afrobeat']
# electropunk         114       ['electro punk', 'electronic']
# hypnotic            114       ['north african', 'post rock']
# south african       114       ['north african', 'african']
# and carry me away   114       ['death metal', 'black metal']
# radiotsar approved  114       ['radio', 'improv']
# calypso             114       ['salsa', 'rockabilly']
# parody              114       ['space rock', 'poetry']
# joyful              114       ['jungle', 'soul rnb']
# greys anatomy       114       ['breakbeat', 'bigbeat']
# cover song          114       ['power pop', 'western swing']
# praise & worship    113       ['spoken word', 'progressive']
# rolling stones cover113       ['progressive', 'sound poetry']
# aussie              113       ['house', 'classical']
# spanish hip hop     113       ['alternative hip hop', 'abstract hip hop']
# rio de la plata favoritos113       ['compilation', 'latin america']
# the beatles         113       ['hip hop beats', 'breakbeat']
# feelings            113       ['field recordings', 'western swing']
# brit pop            113       ['trip hop', 'british folk']
# cello               113       ['chill out', 'celtic']
# brasileira          113       ['brazilian', 'balkan']
# orchestral          113       ['opera', 'metal']
# anti folk           112       ['british folk', 'freak folk']
# gitarrenunterricht  112       ['interview', 'ambient electronic']
# martial             112       ['metal', 'african']
# where is my bong    112       ['western swing', 'singer songwriter']
# lol                 112       ['folk', 'polka']
# loneliness after dusk112       ['electro punk', 'western swing']
# español             112       ['salsa', 'polka']
# religious           112       ['radio', 'house']
# coldplay            112       ['holiday', 'comedy']
# nyc                 112       ['wonky', 'dance']
# seebest             112       ['skweee', 'breakbeat']
# work                112       ['wonky', 'rock']
# old school death metal111       ['death metal', 'black metal']
# favorite by this group111       ['british folk', 'noise rock']
# sing along          111       ['singer songwriter', 'lounge']
# s y s l o v o       111       ['synth pop', 'loud rock']
# blues harp boogie   111       ['blues', 'be bop']
# wow                 111       ['wonky', 'no wave']
# 1989                110       ['wonky', 'western swing']
# underground rap     110       ['sound art', 'soundtrack']
# suomeksi            110       ['blues', 'spoken']
# robertitus global   110       ['british folk', 'international']
# jam bands           110       ['drum & bass', 'ambient']
# 10s                 109       ['surf', 'salsa']
# kids                109       ['idm', 'turkish']
# causation           109       ['compilation', 'latin']
# club house          109       ['house', 'lounge']
# allboutguitarcom    109       ['loud rock', 'krautrock']
# cross rhythms       109       ['synth pop', 'sound art']
# stonesoup           109       ['dubstep', 'downtempo']
# one word titles     109       ['spoken word', 'new age']
# queen               108       ['punk', 'funk']
# technical metal     108       ['death metal', 'black metal']
# prog                108       ['improv', 'pop']
# metro minimal       108       ['minimalism', 'metal']
# mariah carey        108       ['african', 'hardcore']
# cajun               108       ['jungle', 'country']
# mexico lindo y querido108       ['latin america', 'musical theater']
# memphis             107       ['minimalism', 'spanish']
# bhangra             107       ['tango', 'bluegrass']
# ...
# zaebis              19        ['spanish', 'ambient']
# new to me           19        ['new age', 'new wave']
# cigarettesnostalgia 19        ['international', 'classical']
# ladino              19        ['radio', 'latin']
# in spanish          19        ['spanish', 'minimalism']
# the word for        19        ['spoken word', 'nerdcore']
# jane birkin         19        ['space rock', 'noise rock']
# music to work by    19        ['musical theater', 'spoken word']
# annie lennox        19        ['ambient electronic', 'easy listening']
# kitarax             19        ['industrial', 'thrash']
# clapping            19        ['latin', 'classical']
# future fusion metal 19        ['free folk', 'freak folk']
# lila downs          19        ['compilation', 'field recordings']
# jazz house          19        ['house', 'jazz']
# i love his voice alot19        ['middle east', 'hip hop beats']
# folk blues          19        ['blues', 'folk']
# 1101rh              19        ['french', 'turkish']
# clever lyrics       19        ['celtic', 'chamber music']
# summer mix          19        ['chamber music', 'western swing']
# horror surf         19        ['surf', 'choral music']
# chill house         19        ['chill out', 'house']
# heulsusenindie      19        ['easy listening', 'western swing']
# en vivo             19        ['techno', 'be bop']
# ifpopdidntmeanbritneyspears19        ['instrumental', 'singer songwriter']
# hombres g           19        ['shoegaze', 'hardcore']
# liverpool           19        ['international', 'polka']
# psychotaze          19        ['shoegaze', 'psych rock']
# lisa stansfield     19        ['classical', 'black metal']
# girlish             19        ['glitch', 'turkish']
# songs with animals in title19        ['north african', 'minimal electronic']
# bob marley          19        ['comedy', 'no wave']
# ezra furman         19        ['african', 'north african']
# latin rap           19        ['latin', 'latin america']
# power rock          19        ['power pop', 'post rock']
# chinese female      19        ['christmas', 'new age']
# too high            19        ['lo fi', 'thrash']
# the word thing      19        ['field recordings', 'spoken word']
# chileno             19        ['chill out', 'techno']
# good pop            19        ['power pop', 'pop']
# electronic dub      19        ['electronic', 'electro punk']
# laura nyro          19        ['loud rock', 'african']
# storytelling        19        ['western swing', 'easy listening']
# 10                  19        ['20th century classical', 'wonky']
# electro do bom      19        ['electro punk', 'electronic']
# wondo radio         19        ['radio', 'sound art']
# babylon 5           19        ['balkan', 'brazilian']
# adam lambert        19        ['ambient', 'sound art']
# eric marienthal     19        ['experimental', 'americana']
# linke lieder        18        ['klezmer', 'latin america']
# experimental jazz   18        ['experimental', 'experimental pop']
# quarkzangsun        18        ['garage', 'balkan']
# elandal pl none     18        ['experimental pop', 'sound poetry']
# razor               18        ['radio', 'rap']
# metallic perfection 18        ['minimal electronic', 'electronic']
# ants                18        ['spanish', 'ambient']
# wcs                 18        ['classical', 'christmas']
# yellow              18        ['chill out', 'bollywood']
# woxy                18        ['wonky', 'poetry']
# englishness         18        ['noise', 'jungle']
# loooove             18        ['lounge', 'novelty']
# souljazz            18        ['nu jazz', 'jazz']
# 4jsjazz             18        ['jazz', 'nu jazz']
# my rock             18        ['rock', 'psych rock']
# pre and post punk   18        ['post punk', 'electro punk']
# a state of trance   18        ['reggae   dancehall', 'soundtrack']
# sundaymusic         18        ['soundtrack', 'choral music']
# finest tune         18        ['chiptune', 'instrumental']
# busted              18        ['dubstep', 'house']
# 2 tone              18        ['drone', 'lounge']
# damn good           18        ['tango', 'avant garde']
# marilyn manson      18        ['middle east', 'compilation']
# jalisco             18        ['disco', 'salsa']
# deep sea diver      18        ['new wave', 'deep funk']
# engelbert           18        ['jungle', 'novelty']
# punk christmas      18        ['christmas', 'sound effects']
# keane               18        ['dance', 'spoken']
# revolution          18        ['compilation', 'latin']
# sigh and swoon in equal measure18        ['singer songwriter', 'sound collage']
# vocalese            18        ['salsa', 'noise']
# secret garden       18        ['avant garde', 'musique concrete']
# dinner              18        ['drone', 'dance']
# dino                18        ['radio', 'disco']
# sic transit         18        ['musical theater', 'western swing']
# jump                18        ['jungle', 'improv']
# jingle jangle       18        ['new age', 'singer songwriter']
# xavier naidoo       18        ['international', 'americana']
# r n b               18        ['drum & bass', 'soul rnb']
# me likey            18        ['free folk', 'metal']
# oh yeah             18        ['opera', 'rock opera']
# richie sambora      18        ['chamber music', 'grindcore']
# you                 18        ['house', 'lounge']
# nu bluz             18        ['nu jazz', 'blues']
# corridos            18        ['christmas', 'radio']
# christian metalcore metal18        ['christmas', 'instrumental']
# playlist1           18        ['easy listening', 'spanish']
# supertramp          18        ['sound poetry', 'opera']
# robbie williams     18        ['rockabilly', 'afrobeat']
# greatest            18        ['breakbeat', 'bigbeat']
# mg cover collection 18        ['ambient electronic', 'electronic']
# stevenson           18        ['western swing', 'techno']
# all time favorite songs18        ['musical theater', 'singer songwriter']
# looooooooooooooooooooooooove this song18        ['alternative hip hop', 'western swing']
# wayne wonder        18        ['new wave', 'spoken word']
# saliva              18        ['salsa', 'brazilian']
# franz ferdinand     18        ['brazilian', 'americana']
# lowlands            18        ['polka', 'latin']
# angie stone         18        ['singer songwriter', 'tango']
# charly garcia       18        ['north african', 'chamber music']
# death country       18        ['country', 'death metal']
# nolans              18        ['polka', 'noise']
# massive             18        ['progressive', 'classical']
# across the universe 18        ['progressive', 'post punk']
# lofi                18        ['lo fi', 'noise']
# track correction submitted18        ['progressive', 'minimal electronic']
# crazymomma63        18        ['christmas', 'brazilian']
# pop jazz            18        ['nu jazz', 'jazz']
# rockpalast          18        ['rockabilly', 'rock opera']
# testing 1 2 3       18        ['western swing', 'easy listening']
# mj saxxxy zzzz      18        ['jazz', 'modern jazz']
# great pianists      18        ['spanish', 'north african']
# excessive progressive house18        ['progressive', 'experimental pop']
# electronica and dance18        ['electronic', 'electro punk']
# 70s revival         18        ['classical', 'freak folk']
# the desperate kingdom of love18        ['western swing', 'abstract hip hop']
# talk talk           18        ['balkan', 'freak folk']
# night time          18        ['noise', 'death metal']
# malian              18        ['brazilian', 'balkan']
# country loves       18        ['country', 'contemporary classical']
# sounds like theyre high18        ['sound poetry', 'sound effects']
# american female     18        ['americana', 'african']
# melancoholic        18        ['electronic', 'electroacoustic']
# jazz bass greats    18        ['bigbeat', 'afrobeat']
# cocktail            18        ['rockabilly', 'black metal']
# k playlist          18        ['easy listening', 'spanish']
# bulgarian           18        ['african', 'latin']
# miam                18        ['cumbia', 'idm']
# paaady              18        ['avant garde', 'fado']
# mexican rock        18        ['indie rock', 'americana']
# paul taylor         18        ['musical theater', 'death metal']
# chinese male        18        ['christmas', 'new age']
# common              18        ['compilation', 'comedy']
# onerepublic         18        ['celtic', 'choral music']
# mylounge            18        ['lounge', 'sludge']
# blandband           18        ['indian', 'breakbeat']
# lyrics to learn from18        ['musical theater', 'spoken word']
# los palominos       18        ['spanish', 'flamenco']
# wirround            18        ['sound art', 'wonky']
# sail away on the ocean waves18        ['musical theater', 'no wave']
# us                  18        ['house', 'blues']
# magnificent         18        ['ambient', 'african']
# neat                18        ['novelty', 'new age']
# oh how i love this song18        ['hip hop beats', 'compilation']
# chant               18        ['techno', 'country']
# lenas kapellen      18        ['easy listening', 'minimal electronic']
# :d                  18        ['idm', 'fado']
# oriental influence  18        ['experimental pop', 'experimental']
# short and sweet     18        ['sound effects', 'sound poetry']
# my life soundtrack  18        ['soundtrack', 'loud rock']
# kokomo arnold       18        ['spoken word', 'soul rnb']
# best songs of the 80s18        ['singer songwriter', 'western swing']
# anytime is house time18        ['alternative hip hop', 'minimalism']
# foxy brown          18        ['soul rnb', 'post rock']
# raul reiman         18        ['african', 'soul rnb']
# apocalyptic         18        ['celtic', 'rockabilly']
# ballermann          18        ['balkan', 'bluegrass']
# worldtour           18        ['loud rock', 'radio']
# danish female vocalist18        ['noise rock', 'minimalism']
# france live         18        ['new wave', 'free folk']
# s gainsbourg        18        ['grindcore', 'garage']
# jdutronc            18        ['drone', 'krautrock']
# pieces of a dream   18        ['hip hop beats', 'sound art']
# buju banton         18        ['be bop', 'bigbeat']
# delicious           18        ['celtic', 'electroacoustic']
# ed banger           18        ['dance', 'sound collage']
# billy talent        18        ['ambient', 'black metal']
# fusion jazz         18        ['nu jazz', 'modern jazz']
# nueva cancion       18        ['international', 'techno']
# play it again sam   18        ['latin america', 'latin']
# soullll music       18        ['choral music', 'soul rnb']
# us indie            18        ['indian', 'indie rock']
# chicano             18        ['techno', 'african']
# female fronted      18        ['free folk', 'electronic']
# the word want       18        ['spoken word', 'new wave']
# ef369               18        ['deep funk', 'surf']
# electlgitchdubhop   18        ['electro punk', 'electronic']
# booty bass          18        ['drum & bass', 'contemporary classical']
# koopa troopa        18        ['krautrock', 'opera']
# pirates in tight white pants18        ['singer songwriter', 'alternative hip hop']
# cazuza              18        ['jazz', 'cumbia']
# jorge drexler       18        ['jungle', 'progressive']
# ashlee simpson      18        ['alternative hip hop', 'symphony']
# doowop              18        ['power pop', 'downtempo']
# the sims            18        ['chamber music', 'thrash']
# roxette             18        ['afrobeat', 'drone']
# ruth notman         18        ['north african', 'techno']
# foreign             18        ['french', 'african']
# modest mouse        18        ['death metal', 'chamber music']
# funkdisco           18        ['disco', 'funk']
# skateboard          18        ['avant garde', 'sound art']
# current favs        18        ['no wave', 'country']
# dada                18        ['fado', 'salsa']
# calvin richardson   18        ['latin america', 'avant garde']
# ladies of country   18        ['country', 'sound poetry']
# pandora             18        ['fado', 'nerdcore']
# damebola            18        ['death metal', 'flamenco']
# amiable             18        ['unclassifiable', 'ambient']
# amusing             18        ['ambient', 'choral music']
# 6                   18        ['wonky', 'western swing']
# spanish pop rock    18        ['space rock', 'psych rock']
# chicago blues guitar18        ['chill out', 'musical theater']
# live songs          18        ['field recordings', 'singer songwriter']
# catchy like drug resistant tuberculosis18        ['20th century classical', 'field recordings']
# heart and soul      18        ['death metal', 'hardcore']
# british blues rock  18        ['british folk', 'noise rock']
# history             18        ['disco', 'christmas']
# enrique             18        ['noise', 'europe']
# some damn good music18        ['choral music', 'chamber music']
# peace music         18        ['chamber music', 'choral music']
# p0p                 18        ['pop', 'hip hop']
# jack off jill       18        ['rockabilly', 'freak folk']
# fucking great       18        ['bigbeat', 'afrobeat']
# trombone            18        ['drone', 'afrobeat']
# chris botti         18        ['christmas', 'chill out']
# antial              18        ['industrial', 'metal']
# gargulec            18        ['garage', 'jungle']
# shoegazers          18        ['shoegaze', 'klezmer']
# travelling          18        ['tango', 'brazilian']
# master sensei       18        ['western swing', 'singer songwriter']
# norteno             18        ['techno', 'nerdcore']
# colbie caillat      18        ['rockabilly', 'compilation']
# keri hilson         18        ['trip hop', 'alternative hip hop']
# keyshia cole        18        ['hardcore', 'sound collage']
# st jazz             18        ['jazz', 'nu jazz']
# charming            18        ['ambient', 'african']
# songs about love    18        ['sound art', 'no wave']
# pdormir             18        ['poetry', 'choral music']
# popet               18        ['pop', 'poetry']
# piano   relaxing    18        ['compilation', 'field recordings']
# sophisti pop        18        ['synth pop', 'hip hop']
# car songs           18        ['singer songwriter', 'western swing']
# phoebefencers       18        ['sound effects', 'hip hop beats']
# favorite albums     18        ['choral music', 'free jazz']
# dependent           18        ['experimental', 'experimental pop']
# rustycanuckjustplayin18        ['compilation', 'western swing']
# rated0              18        ['radio', 'garage']
# cafeand             18        ['african', 'fado']
# tantric             18        ['african', 'tango']
# visa                18        ['christmas', 'salsa']
# humor com           18        ['choral music', 'hardcore']
# alex ambiente       18        ['ambient', 'ambient electronic']
# hh                  18        ['thrash', 'hip hop']
# jazz skip           18        ['jazz', 'nu jazz']
# lies                18        ['blues', 'bluegrass']
# dream dance         18        ['dance', 'reggae   dancehall']
# serious dub         18        ['soul rnb', 'electro punk']
# kompakt             18        ['compilation', 'opera']
# mein quitschiger leiherkasten18        ['musical theater', 'easy listening']
# punk77              18        ['punk', 'funk']
# pure trance         18        ['opera', 'dance']
# ethno               18        ['techno', 'tango']
# favourite bands     18        ['african', 'free jazz']
# aggro berlin        18        ['afrobeat', 'brazilian']
# chicks on speed     18        ['rock opera', 'chiptune']
# classy              18        ['classical', 'bluegrass']
# lyfe jennings       18        ['field recordings', 'easy listening']
# brroadway           18        ['holiday', 'breakbeat']
# folklore argentino  18        ['flamenco', 'latin']
# samplingx           18        ['ambient', 'symphony']
# harmonies           18        ['hardcore', 'drone']
# stromgitarre according to stretchead18        ['musique concrete', 'field recordings']
# nice to hear        18        ['musical theater', 'noise rock']
# if this were a pokemon i would catch it18        ['spoken word', 'reggae   dancehall']
# missbluebean treasures18        ['bluegrass', 'middle east']
# emission universelle18        ['musique concrete', 'sound collage']
# songs seen live     18        ['progressive', 'new wave']

# %%
for k, v in lastfm_dict.items()
    print(k, v)
    break

# %%
def get_ids_w_tag(tag):
    ids = []
    for track_id, tags in LASTFM_tags_dict_50.items():
        if tag in tags:
            ids.append(track_id)
    
    return ids

get_ids_w_tag('melancholic')
# Out:
# ['TRJJENO128F422AD8F',
#  'TRJJNCN128E079225E',
#  'TRJJSME128F425B9AD',
#  'TRJPBLB12903CB73DC',
#  'TRJGMJG128F92E55EA',
#  'TRJVKAU12903CA839D',
#  'TRJVKNO128F42646BF',
#  'TRJLAUR128F429E0F5',
#  'TRJDYVC128F1463BD2',
#  'TRJAJMI128F92FE3B9',
#  'TRJOHCN128F92CD9A2',
#  'TRJOZYU128F1462C57',
#  'TRJTJQZ128F9327999',
#  'TRJTQJF128E0787D88',
#  'TRJFKJW128F42914A4',
#  'TRJYEGP12903CDEDB3',
#  'TRJXXGU128F932DBC6',
#  'TRJHRGY128F9327A83',
#  'TRJSDPA128F14588E7',
#  'TRJSINW128F42712BB',
#  'TRJZISQ12903CB4901',
#  'TRJZNJT12903CA839E',
#  'TRPJUMF128F92E3095',
#  'TRPJEUJ128F9328E53',
#  'TRPJEYC128F93294DF',
#  'TRPPTSN128F931C960',
#  'TRPGUYI128F931E95B',
#  'TRPGNVL128F423ED58',
#  'TRPLOYO128F931B3D0',
#  'TRPLNHN128F93040C3',
#  'TRPLZUU128F42460B5',
#  'TRPDEZW128F9343F0E',
#  'TRPDXAA128F42B93E4',
#  'TRPACUP128F92D6BC3',
#  'TRPODOZ12903CBFE7C',
#  'TRPOXUW128F932A335',
#  'TRPOZWR128F147200C',
#  'TRPUIVK12903D032A3',
#  'TRPUEPH128F4230D30',
#  'TRPIUTX12903CE750D',
#  'TRPIXTW128F149493D',
#  'TRPTNFQ128F42868F2',
#  'TRPCKNJ128F422953F',
#  'TRPROSB128F932A9E7',
#  'TRPRMVY12903CE8593',
#  'TRPRYFA128F148BDAE',
#  'TRPMEDP128F4241E77',
#  'TRPYRVR128F9311C06',
#  'TRPXXWO128F4266CFC',
#  'TRPXZSD12903CEA99F',
#  'TRPSUST12903CF5C0C',
#  'TRPSMPN12903CFACC2',
#  'TRPSZSV128F9303FF3',
#  'TRGGYRP128F930A311',
#  'TRGDJOE128E078A173',
#  'TRGDOZU128E0792C50',
#  'TRGDCAT12903D05D17',
#  'TRGQDTX128F42359E2',
#  'TRGTJWS128EF33DF67',
#  'TRGTKYM128F42800E5',
#  'TRGCACO128F425ACD3',
#  'TRGRLJT128F92E663F',
#  'TRGRRPY128F92DD84D',
#  'TRGRZZN12903CD9C18',
#  'TRGWOGK128F42AD134',
#  'TRGWUQE128F1485FC8',
#  'TRGWWZH128F42359FC',
#  'TRGNNSA128F427E905',
#  'TRGHKOI12903CA84BC',
#  'TRGSRIG128F932783D',
#  'TRGZAAR128E07993E8',
#  'TRVGGAG128F1490072',
#  'TRVLTBA128E07870CE',
#  'TRVBQSF128F426B22F',
#  'TRVBOFF128F932799F',
#  'TRVUOSZ128F92D378B',
#  'TRVTDZL128E0781C4D',
#  'TRVTXSP128F9311CD0',
#  'TRVCXNT128F931CFC8',
#  'TRVRJUF128F9302B9C',
#  'TRVFRDU128F9332CF1',
#  'TRVFHWD128F423A82D',
#  'TRVWIAR128F4285818',
#  'TRVNLMP128F931E95E',
#  'TRVNIIF128F931DB0B',
#  'TRVNWAP128F93434EB',
#  'TRVHLGY12903CD669D',
#  'TRVHWHI128F4261642',
#  'TRVHNIF12903CF20A0',
#  'TRVSPJK128F4249580',
#  'TRVSDOK128F9310C9A',
#  'TRVSQWD128F92CA9EE',
#  'TRLPNBA128F932114C',
#  'TRLVEGQ12903D0BCA0',
#  'TRLLOLL128F424005A',
#  'TRLBOBI12903CB167D',
#  'TRLDPRW128F427D790',
#  'TRLDGWR128F42637F3',
#  'TRLDBNB128F429C935',
#  'TRLDQZM12903CD2A1F',
#  'TRLDWAU128F930AB37',
#  'TRLOZKT128F932781F',
#  'TRLUPCQ128F42615B8',
#  'TRLUICJ12903D0EDF0',
#  'TRLTTEL12903CBEAE2',
#  'TRLCPGR128F9302586',
#  'TRLRIXV128F427E2C2',
#  'TRLRCLD128E0791D70',
#  'TRLMHAG128F4234A72',
#  'TRLFLPQ12903CCDE97',
#  'TRLFUIN128F14AD9A2',
#  'TRLFTZQ128F92F2E58',
#  'TRLYBWX128F4229DE4',
#  'TRLWOWB128F934308E',
#  'TRLWCZN128F147AA04',
#  'TRLEBNB128F4292A0D',
#  'TRLEBHM128F92FC049',
#  'TRLXLNU128F426163B',
#  'TRLHKUU128F933D648',
#  'TRLHHAD128F1457E83',
#  'TRLSADM128F92F14B2',
#  'TRLZNQF128F932E45B',
#  'TRBJZMO12903CF43A2',
#  'TRBGPMZ128F4255172',
#  'TRBGVGB12903CE44C9',
#  'TRBGFIY128F4283107',
#  'TRBGNCZ128F148F727',
#  'TRBVDGU128F14AAAF7',
#  'TRBLSCT12903CB9ED3',
#  'TRBBUDT128F92E1693',
#  'TRBBWDJ128F42595D5',
#  'TRBOYTA128F4266CE5',
#  'TRBTJZD128F147ECD7',
#  'TRBMRKO128EF3554F0',
#  'TRBFQTB12903CEB5F8',
#  'TRBWVOP128F92E837E',
#  'TRBWCAG128F4292338',
#  'TRBWHWW128F148026A',
#  'TRBNDZE128F42B93E9',
#  'TRDVRWC12903CEB5ED',
#  'TRDLAJF128F931A611',
#  'TRDALDH128F93277F9',
#  'TRDANUN128F427D792',
#  'TRDQIGI128F92D6BC6',
#  'TRDQFUN128F427EECA',
#  'TRDIZYS128F4280AF0',
#  'TRDCWYM128F147287A',
#  'TRDKERT128F92E8B52',
#  'TRDRPND12903CF0AE4',
#  'TRDYRAW128F1463BD4',
#  'TRDEGFP128F4286C19',
#  'TRDNMGO128F14789EF',
#  'TRDHGDN12903CB5598',
#  'TRDSWAZ128F42A6F10',
#  'TRAPWQD12903CB1976',
#  'TRAPEIN128E078892E',
#  'TRAGGGV128F9303219',
#  'TRAGUHI12903C9F729',
#  'TRAGCIK12903CC5CD8',
#  'TRAVGLK12903CB707A',
#  'TRADTGP128F1497D8C',
#  'TRAIWAT128F92FA234',
#  'TRAKIMN12903CCDE90',
#  'TRARGCD128F422DCA1',
#  'TRAMRZO12903CA82FB',
#  'TRAWULE128F4288161',
#  'TRAEAST128F42931B1',
#  'TRAEOGK128F4292B66',
#  'TRAERXQ128F4294114',
#  'TRAHBCW128F1463BD3',
#  'TRASSGQ128F9351BA1',
#  'TRAZJUB128F931E961',
#  'TRQJULP12903CBAD89',
#  'TRQPAYZ128F422B219',
#  'TRQPYHG128F4293089',
#  'TRQGNOR128F42684D0',
#  'TRQLTQM128F425C1A2',
#  'TRQBUUW128F427D380',
#  'TRQDSET128F9310FAC',
#  'TRQADKL128F426EF42',
#  'TRQQWIR128F423F089',
#  'TRQQEKN128F424B56B',
#  'TRQONIP128F148D6E6',
#  'TRQUCIN128F92FA112',
#  'TRQURVC128F93041A7',
#  'TRQIDAA128F9327AA9',
#  'TRQIQBJ128F9326181',
#  'TRQIITH128F932312E',
#  'TRQCBZO128F14A6D10',
#  'TRQRKHH128F9300895',
#  'TRQNUCN128F424F1C1',
#  'TRQNRIT12903CF9386',
#  'TRQSIKX128F424C704',
#  'TRQSKSM12903CF2063',
#  'TROPXTL128F933B024',
#  'TROGPGQ128F42515E9',
#  'TROLWVR128F92F20D9',
#  'TROBWLP128F92E2A29',
#  'TROAPNI128F426367D',
#  'TROQYRZ128F422306D',
#  'TRORLCG128EF3439DA',
#  'TROFJSP128F93294E2',
#  'TROEFIL128F9309C0F',
#  'TROXWUZ128F9327976',
#  'TROXSAF128F424F0DF',
#  'TROHAZZ128F4267B10',
#  'TROSAOJ128F933B297',
#  'TROZCMN128F92FAD6B',
#  'TRUJCCU128F9308C73',
#  'TRUJNXQ128F9347DFA',
#  'TRUGBOW128F4263824',
#  'TRUVODK128F92D6BC1',
#  'TRUDDQV128F9343040',
#  'TRUAZZD128F932A9EB',
#  'TRUQLCG12903CC5630',
#  'TRUOGSQ128F931E955',
#  'TRUOKEG128F423C03F',
#  'TRUUTNT128F423DB9E',
#  'TRUUCMH128F421A5BA',
#  'TRUIURR128F42AB665',
#  'TRUIEZE128F148848C',
#  'TRUCXMU128F93356D7',
#  'TRUCNEG128F14737A1',
#  'TRUKNSR128F9329FB3',
#  'TRUMVBR128F933B294',
#  'TRUMZCM12903CDBC23',
#  'TRUYVHW128F4281B43',
#  'TRUELWK128F426163D',
#  'TRUHCER128F147726D',
#  'TRUHXVL128F932A9F1',
#  'TRUSGKX128F42990F1',
#  'TRUSTQV128F423F256',
#  'TRUSNUN128F428BE36',
#  'TRIJRNE128F42A6EFE',
#  'TRIJFJD128F934B684',
#  'TRIGWII128F42ACC22',
#  'TRIDWDV128F4236FD7',
#  'TRIOJDU128F422ACCA',
#  'TRIIADW128F931E957',
#  'TRITIRC128F425B99D',
#  'TRIKDDI12903CD017D',
#  'TRIKMTV128F4243566',
#  'TRIKEWR128F9335226',
#  'TRIRMKK12903CC5223',
#  'TRIMDRD128F4226632',
#  'TRIFSXB128F9343B8E',
#  'TRIYUBH128F148D184',
#  'TRIYEYW128E0792C4B',
#  'TRIWERK128F42781B0',
#  'TRIESOY12903CEB227',
#  'TRIXMDJ128F428E977',
#  'TRIXYZB128F42622E6',
#  'TRIXXEU128F424C705',
#  'TRISGZM12903CCE6E5',
#  'TRIZBDH128F9334F87',
#  'TRTJUJL12903CA0808',
#  'TRTPZTB128F4292436',
#  'TRTGTJS128F4256F33',
#  'TRTGKFA128F423249B',
#  'TRTVGUP128F9333987',
#  'TRTBDPH128F92DFB83',
#  'TRTBWRZ128F426003F',
#  'TRTARYK128F933F087',
#  'TRTUPBT128F9327AB4',
#  'TRTTFBU128F9329059',
#  'TRTCZLO128F93278E2',
#  'TRTKOXQ128F9308695',
#  'TRTRUOP128F9314EC6',
#  'TRTRTOW128EF34861B',
#  'TRTRMYB128F4259F90',
#  'TRTYUNE128F4259F4A',
#  'TRTESPK128F149BAAE',
#  'TRTNKHQ128F92D6BC7',
#  'TRTHPQL128F4294AF5',
#  'TRTSLZA128F4292863',
#  'TRTSCLM128F92FD043',
#  'TRTSCLC128F932A866',
#  'TRTZPUX128F930F5CB',
#  'TRTZDUE128F9327811',
#  'TRCGVBZ128F428619A',
#  'TRCVUXT12903CC5804',
#  'TRCVFCX128F147E3BD',
#  'TRCBPOJ12903CA3BB7',
#  'TRCAEQL128EF3686D0',
#  'TRCAHMP128F93372BE',
#  'TRCOEHV128E0795630',
#  'TRCTADD128F9333BAC',
#  'TRCTKXL128F932A3C7',
#  'TRCTXFW128F428A8A1',
#  'TRCKMRZ128F4266314',
#  'TRCRHJD128F9329D58',
#  'TRCMKET12903CDDE3D',
#  'TRCYDZW128F4259602',
#  'TRCWWQY128F1453955',
#  'TRCXBGX128F93385C9',
#  'TRCNBJS128F42863CF',
#  'TRCNTDA128F4264FBD',
#  'TRCSNKA128F4298F10',
#  'TRCZCYJ128F932E519',
#  'TRCZWMR128F424C707',
#  'TRKGQEN128F42766B5',
#  'TRKLGCD128F9338B1D',
#  'TRKLQRE128F92D789F',
#  'TRKBHYG128F422ACA7',
#  'TRKDZNS128F9329B8B',
#  'TRKAJHR128F92EA4DA',
#  'TRKQZCQ12903CFEB27',
#  'TRKQZFT128F932EB02',
#  'TRKOFNV128F42B1455',
#  'TRKTDCS12903CB2F87',
#  'TRKKBWB128F933631A',
#  'TRKKEEF128F4280D1E',
#  'TRKKNBB12903CA83A4',
#  'TRKMGYZ128F92D7FA7',
#  'TRKMVTO128F1473362',
#  'TRKMNYZ128F42AC31C',
#  'TRKEIXY128F932EE53',
#  'TRKEWMS128F92D8440',
#  'TRKXMYL128F42A6F0D',
#  'TRKNGJG128F9316A67',
#  'TRKSPLF128F426325A',
#  'TRRVDHS12903CC37A2',
#  'TRRLFRU128F9327AB8',
#  'TRRLFFH128F427C469',
#  'TRRDXOM12903CC81E1',
#  'TRRUDLA128F92FA341',
#  'TRRIUZG128F42A944E',
#  'TRRKEHZ128F92F8EB8',
#  'TRRMZQA128F42A6EF8',
#  'TRRWGRM128F42B0067',
#  'TRRWKVX128F930DA86',
#  'TRRWWAW128F9338DF0',
#  'TRRXOBZ128F93279CC',
#  'TRRXRZK128F92E0982',
#  'TRRXZDE128F4292EFF',
#  'TRRHARM128F9327ADE',
#  'TRRHXXX128EF3600A3',
#  'TRRZXVN128F4260E91',
#  'TRMJFFQ128F4286CF3',
#  'TRMJEPW128F422A4AE',
#  'TRMPSNI128F1498DC2',
#  'TRMGZED128F423C035',
#  'TRMVUMO128F4268E06',
#  'TRMLTAS128F1473361',
#  'TRMBFBC128F427F8D9',
#  'TRMAIBP128F428FD40',
#  'TRMAMZW128F92D1FC3',
#  'TRMQPAE128E0792C51',
#  'TRMUHVE128F42569D4',
#  'TRMIDIV128F4293CF5',
#  'TRMTEUA128F426E3C7',
#  'TRMCJGU128E0791C67',
#  'TRMCQOM12903CE790F',
#  'TRMKGLI128F932B547',
#  'TRMMNDH12903CEC363',
#  'TRMYZIK128F93278EF',
#  'TRMXHCT128F14B12BA',
#  'TRMNXUT128F429BEFF',
#  'TRMHMJS128F9304CEF',
#  'TRMSAQE12903CA470E',
#  'TRMSQUZ128F4249575',
#  'TRMSTOY128F422AD74',
#  'TRFJHLE128F933B289',
#  'TRFVNMI128F92F5C21',
#  'TRFVZXI128F149354C',
#  'TRFLJAJ128F4289242',
#  'TRFLLXF128F4259F99',
#  'TRFLURI12903CAE9EE',
#  'TRFLEFL128F9359C03',
#  'TRFDGZG12903CE38F6',
#  'TRFDLAU128F42661C5',
#  'TRFDLOY128F932B559',
#  'TRFDIFU128F42849D5',
#  'TRFADKA128F42359E3',
#  'TRFUFVW128F423C03B',
#  'TRFTKCP128F933261D',
#  'TRFCHHU128F932E1D4',
#  'TRFKIZX128F92D6BC9',
#  'TRFRJVW128F9350068',
#  'TRFRGGQ128F4264562',
#  'TRFROGJ128F9343EF4',
#  'TRFRYXR128F933E793',
#  'TRFMFUA12903CE38D0',
#  'TRFFOZQ128E0789C8A',
#  'TRFFTHB12903CF0F62',
#  'TRFYMDI128EF35CB7C',
#  'TRFWHMJ128F9327919',
#  'TRFEVEG128F4298495',
#  'TRFEMHR128F9329C5E',
#  'TRFXUVC128F4290563',
#  'TRFXKZF128F9316804',
#  'TRFXWFT12903CC5CC3',
#  'TRYJHNC128F9328D51',
#  'TRYPTAY128F42A4C8F',
#  'TRYPKXM128F932A9EE',
#  'TRYGGXI128F9318017',
#  'TRYGEKJ128F92D6BCA',
#  'TRYVDJM128F932A204',
#  'TRYVRPU128F931E962',
#  'TRYBATQ12903CDD452',
#  'TRYBSAY128F932782C',
#  'TRYQTPV128F429AE1C',
#  'TRYQTIX128F92D3838',
#  'TRYQFVG12903CE956E',
#  'TRYOOKX128F147B41A',
#  'TRYUBCT128F149353D',
#  'TRYIDXY128E0787827',
#  'TRYTIBK128F146ED0F',
#  'TRYTKOQ128F14A92F0',
#  'TRYTRVH128F42AD919',
#  'TRYCYOV12903CB84B8',
#  'TRYKCDP128F930512F',
#  'TRYKSBC12903CB197C',
#  'TRYRWZD12903CC5628',
#  'TRYRZDD128F14A397F',
#  'TRYYCXP128F4284B8A',
#  'TRYYXJI128F9317502',
#  'TRYWAOD128F93122F9',
#  'TRYWOVR128F932B55E',
#  'TRYHEFT128F423C79E',
#  'TRYZYHW128F934EFFE',
#  'TRWPFRP128EF33FA7D',
#  'TRWGYLY128F932B16A',
#  'TRWVNGL128F42927F4',
#  'TRWLCKB128F42A6F02',
#  'TRWBHDA128F42AB42F',
#  'TRWQSIK128F933AE13',
#  'TRWTDCH128F932B54A',
#  'TRWTISR128F92D8D39',
#  'TRWTSFH128F1497E38',
#  'TRWCJBB12903CE431F',
#  'TRWKFGJ12903CCDE8D',
#  'TRWRGPB128F92E3BEE',
#  'TRWRVQC128F429255F',
#  'TRWMUZG128F933C7E2',
#  'TRWYUSI128F42657C8',
#  'TRWYTTB128F425AD75',
#  'TRWWCOT128F9327AF5',
#  'TRWZBYN128F9327936',
#  'TRWZNCV128F4277E44',
#  'TREJXBR128F422058C',
#  'TREGDKM128F92D9134',
#  'TREAEAE128F932CA24',
#  'TREQXXQ12903CAC998',
#  'TREIFWZ128E0781F3C',
#  'TREKUYX128F92E3402',
#  'TREKXEW128F4272280',
#  'TREMKJX128F427D2C3',
#  'TREFYIS128E0781F3A',
#  'TREFWCK12903CB492D',
#  'TREXIWC128F4298835',
#  'TREXNJU128E0781F37',
#  'TRENQZM128F4284B84',
#  'TREZKUE128F92D6120',
#  'TRXJKJH128F931D012',
#  'TRXPLAC128F9309606',
#  'TRXVHQV128F9338DEE',
#  'TRXLMAH128F933B07C',
#  'TRXLWQK128F932E450',
#  'TRXBUCC128F93279AB',
#  'TRXADEC128F9303BEB',
#  'TRXAMIR128F92F8967',
#  'TRXQTJZ128F42BC6EC',
#  'TRXQMUQ128F9314727',
#  'TRXIPQN128F9327846',
#  'TRXTXPQ12903CF8C0C',
#  'TRXCOBE128F425A3B0',
#  'TRXCCPX128F425D3BB',
#  'TRXCKSX128E0787388',
#  'TRXKWDS128F14589C0',
#  'TRXMYAR12903CB473C',
#  'TRXYJWB128F42A6F0C',
#  'TRXEFSQ128F92DC10C',
#  'TRXXPRA12903CF266B',
#  'TRXNQKU128F4259DAD',
#  'TRXNHIZ128F427F136',
#  'TRXSDBB128F1488A86',
#  'TRXSUYL128F14650CD',
#  'TRXSHOW128F423514D',
#  'TRXZWLD12903CF43A3',
#  'TRXZXGB128F4259F96',
#  'TRNJQYT128F92C44AD',
#  'TRNJZJL128F932A90C',
#  'TRNVQKC128F425A882',
#  'TRNLBTB128F428A59B',
#  'TRNDDQX128F92F4B75',
#  'TRNINKJ128F1491A07',
#  'TRNTARR128F428B5A2',
#  'TRNCFRS128F425DCB3',
#  'TRNMPJX128F421C819',
#  'TRNMKDD12903CAC591',
#  'TRNMWRK12903CDF2C3',
#  'TRNFWLE128F9327A95',
#  'TRNYPCX12903CD9C17',
#  'TRNWOYR128F4293FB2',
#  'TRNWIBN128F9309DBF',
#  'TRNETFO128F42877E7',
#  'TRNEZAQ128F92D59F9',
#  'TRNXJQI128F92D6BC4',
#  'TRNXLQZ128F93274FB',
#  'TRNNHZO12903CF6FE4',
#  'TRNHDSU128F427E9A8',
#  'TRNSUGM128F42A0396',
#  'TRHPEXN128F42849CD',
#  'TRHGICB128F9310FA0',
#  'TRHGFXB128F1496ACD',
#  'TRHVMFZ128F1463BCF',
#  'TRHLIUG128F42477C4',
#  'TRHAGCH128F42B840E',
#  'TRHQJDK128F4259F9D',
#  'TRHQXLL128F931B88B',
#  'TRHOFMF128F148930B',
#  'TRHOWAM12903CC14A3',
#  'TRHIPHX128F933700B',
#  'TRHILJF128F14895B9',
#  'TRHTKSX128F92EF07F',
#  'TRHCAQT128F933B286',
#  'TRHCYMH128F92CFE80',
#  'TRHKPPI128F9308691',
#  'TRHKRTQ128E079566E',
#  'TRHRBNL12903CB13A1',
#  'TRHRFXF12903CA5AC6',
#  'TRHMLKU128F42637E0',
#  'TRHFGMO128F9302B18',
#  'TRHEYAT12903D0195C',
#  'TRHXUSZ128F421C4F9',
#  'TRHXWVS128F42514C2',
#  'TRHXWWL12903CB475B',
#  'TRHNNLZ128F9340E9F',
#  'TRHSMPB128F92EB271',
#  'TRHSFCM128F9311151',
#  'TRHZFQH12903CBAD80',
#  'TRHZZOK128F92CA9EA',
#  'TRHZZLQ12903D09EE5',
#  'TRSPLXX128F93583B0',
#  'TRSPIEW128F4263802',
#  'TRSGEOK128F930D862',
#  'TRSVZUG128EF350B89',
#  'TRSBSTR128F92FC40C',
#  'TRSQDCE128F9343EFF',
#  'TRSOBKB128F9317165',
#  'TRSTUNZ128F92CB25E',
#  'TRSKVPT128F932792B',
#  'TRSKASM128F932D217',
#  'TRSRLAO128EF3672F6',
#  'TRSMQTJ128F42AB452',
#  'TRSMIXT12903CC5622',
#  'TRSMCMT12903CEEFC9',
#  'TRSYBPH128F4227728',
#  'TRSWGXH128F1463BD0',
#  'TRSENNS128F4215C83',
#  'TRSXIPA128F14737A0',
#  'TRSXCTH128F428B1AE',
#  'TRSHHJR128F93230E1',
#  'TRZJBQE128F427D794',
#  'TRZGGCB128F423EFE2',
#  'TRZGRYL12903CB28A0',
#  'TRZVACR128F421D006',
#  'TRZLQFX128F149B2A9',
#  'TRZLCET128F42A38A5',
#  'TRZLZQK128F425872C',
#  'TRZBFGI128F4213C1D',
#  'TRZAUYH128F427D2BD',
#  'TRZUPIQ128F42A6F07',
#  'TRZUQGK128F424C709',
#  'TRZCQSG12903D073A1',
#  'TRZKCBI128F9329C90',
#  'TRZRGSV128F42B97E3',
#  'TRZRDOZ128F149FAC9',
#  'TRZMDIF128F92ECBDE',
#  'TRZMETO128F427AB61',
#  'TRZFOIX128F9339D71',
#  'TRZFXWV128F14B06C9',
#  'TRZYROQ128F933A976',
#  'TRZSJMQ12903CBE2A3',
#  'TRZZFFC128F423EAD9',
#  'TRJONRR128F92E8D64',
#  'TRJTJME128F42A3C87',
#  'TRJKTGT128F9305578',
#  'TRJHMQY128E078CED2',
#  'TRJZWPR128F9329363',
#  'TRPFNQN12903CB0B2C',
#  'TRPNCOE128F147DBB3',
#  'TRGLHVX128F930135C',
#  'TRVQYTF128E078168A',
#  'TRVRIEA128F427F21E',
#  'TRVYVXJ128F426E3FB',
#  'TRVXWYL128F4271EEE',
#  'TRLLINC128F932CDCA',
#  'TRLIIZP128F1467656',
#  'TRBPGAP12903CE6E31',
#  'TRDORUT128F425738B',
#  'TRDCTEP128F93285BB',
#  'TRAVIMX12903CEB755',
#  'TRALHVH128EF35F5FA',
#  'TRADDQD128F931CE40',
#  'TRADKYE128F42A0798',
#  'TRAAVQX128F932299E',
#  'TRAANIZ128F9304894',
#  'TRATOEB128F1467652',
#  'TRATXCW128F92E0576',
#  'TRAFVAX128F42B3EFB',
#  'TRQDLYW128E078EA88',
#  'TRQRRSB128F92EC1FF',
#  'TROUBVX128F9324516',
#  'TROUOWP12903CA899A',
#  'TROKJJJ12903CDB242',
#  'TRORGTL128F932AA4A',
#  'TROMHMC12903CB73A9',
#  'TROWWLX128F9344C12',
#  'TROXTZO128F4285A25',
#  'TRUMULH128F9304890',
#  'TRIJBNP12903CDB240',
#  'TRIJAHL128F92E23C3',
#  'TRIPZAB128F92FC401',
#  'TRTBBEW128F42813F6',
#  'TRTCLIH128E0787DB6',
#  'TRTFZXE12903CAF40C',
#  'TRTEXEA128F92C4557',
#  'TRCPAJO128F427D735',
#  'TRCLVRU128F14A9363',
#  'TRCHYZB128F425ECE1',
#  'TRKMSBN128F93262C1',
#  'TRKFJEF128F146CC58',
#  'TRRJQCG128F932E326',
#  'TRRUCDF128F932CDD0',
#  'TRRXAAK128F92DFCFC',
#  'TRMOOWR128F92EFA7E',
#  'TRFWTSB128F93430F5',
#  'TRFNLAH128F9348E33',
#  'TRYQDFI128F14A91EA',
#  'TRYIPEN128F9329267',
#  'TRYSSIM128F42B3EF5',
#  'TRWLKFG128EF33DBD1',
#  'TREXRLN128E0781A48',
#  'TREHPFI128F92D1D09',
#  'TRXJFLN128F14968B0',
#  'TRXQAQY128F4281CE0',
#  'TRXSCTC128F14A9190',
#  'TRXSNJQ128F42321D4',
#  'TRXZTPY128F4292435',
#  'TRNGHDV128F92C4555',
#  'TRHKSKR12903CE60FB',
#  'TRHRSEM12903CC0344',
#  'TRHXLUQ12903CD3F74',
#  'TRSNKGJ128F14B11BF',
#  'TRZJTCX128F425DF8E',
#  'TRZVZMO128F425A386',
#  'TRZIHCT128F42943E1']

# %%
LASTFM_tags_dict_50
# Out:
# {'TRJJJIH128F92E1423': ['metal',
#   'visual kei',
#   'jrock',
#   'cover',
#   'dark',
#   'blood jrock metal visual key japanese rock'],
#  'TRJJJAI128F933B0F8': ['country', 'bluegrass', 'alt country', 'americana'],
#  'TRJJJHQ128F429E687': ['hip hop'],
#  'TRJJJMV128F4242917': ['gammarec'],
#  'TRJJJAM128F425C444': ['chanson francaise'],
#  'TRJJJCW128F42218C7': ['scream'],
#  'TRJJJQY128F4295342': ['rock', 'punk', 'chez nata san'],
#  'TRJJJCD128E079298A': ['hard rock', 'rock'],
#  'TRJJJWL128E0790E86': ['reggae'],
#  'TRJJJCI128F4265FF0': ['dub'],
#  'TRJJJAG12903CC7B84': ['synthpop'],
#  'TRJJJZV128F4221E2F': ['west coast rap'],
#  'TRJJJQM128EF35BFF1': ['rock', 'christian'],
#  'TRJJJWA128F92FE4E4': ['soul', 'disco'],
#  'TRJJJYF12903CBB80B': ['yean know'],
#  'TRJJJBN128F92F828B': ['indie'],
#  'TRJJJPE128F423B2A3': ['spiritual', 'shoshannah', 'the healing piano'],
#  'TRJJJDH128F421DD6D': ['blues', 'female vocals', 'blues jazz singers'],
#  'TRJJJDQ12903CD8415': ['rap', 'hip hop', 'experimental', 'idm', 'glitch'],
#  'TRJJJYO128F92D5F54': ['instrumental hip hop'],
#  'TRJJJDK128F425822F': ['political'],
#  'TRJJJVY128F9307F73': ['indie', 'handclaps', 'tap your foot'],
#  'TRJJPFC128F9307212': ['praise & worship',
#   'christian',
#   'clay crosse',
#   'arms of jesus'],
#  'TRJJPND128F4262576': ['trip hop', 'hip hop', 'hip hop'],
#  'TRJJPED128F92FDBBA': ['sexy', 'pop', 'dance', 'techno'],
#  'TRJJPRE128F9320B7E': ['leo ku'],
#  'TRJJPXC12903CE1B73': ['arabic'],
#  'TRJJPGV128F9326FE2': ['rock', 'sense of place'],
#  'TRJJPIV128F92C9D67': ['rock'],
#  'TRJJPCL128F427B641': ['oldies'],
#  'TRJJPSK128EF33EDB3': ['deathrock'],
#  'TRJJPHC12903CD4424': ['female vocalists'],
#  'TRJJPVM128F42924E6': ['folk', 'slowcore', 'sing', 'guitarr'],
#  'TRJJPLJ128F933D6F8': ['opera', 'swedish', 'pop', 'dance'],
#  'TRJJPHF128F42274DF': ['electronic',
#   'test',
#   'drum and bass',
#   'ninja tune',
#   'j4zz j4ngl3'],
#  'TRJJPDE128F4251F1C': ['salsa'],
#  'TRJJPMT12903CB4192': ['metal', 'metal blade records'],
#  'TRJJPZW128F932064F': ['african'],
#  'TRJJPZX12903D0FA8D': ['hip hop'],
#  'TRJJPOE12903CDBF35': ['emo'],
#  'TRJJPMV128F4230C9E': ['philosophy'],
#  'TRJJPGN128F92E7D03': ['my punk',
#   'under two minutes',
#   'title is a full sentence'],
#  'TRJJPTJ128F9331C61': ['reggae'],
#  'TRJJPGA128EF34FE5B': ['skinhead reggae', '77davez all tracks', 'funny'],
#  'TRJJPEU128F42A514B': ['ostrock'],
#  'TRJJPWO128F4296EB3': ['rock',
#   'italian',
#   'vasco',
#   '77davez all tracks',
#   'italiana',
#   'rock italiano'],
#  'TRJJPPM128F427D207': ['pop punk', 'houston calls   high rise', 'emo'],
#  'TRJJPMZ128F148C749': ['lks', 'friends2', 'soul tag'],
#  'TRJJPGO128F146651E': ['acid jazz', 'jazz flute'],
#  'TRJJPPI12903CED426': ['metal'],
#  'TRJJPFD128F930F99A': ['wcw'],
#  'TRJJPZF128F4235A24': ['post punk'],
#  'TRJJGXD128F1467FB5': ['rock',
#   'morningwood',
#   'indie rock',
#   'alternative',
#   'female vocalists'],
#  'TRJJGOF128F14560FB': ['hard rock', 'classic rock', 'rock'],
#  'TRJJGCX128F9341862': ['trance'],
#  'TRJJGKO128F42368C0': ['japanese'],
#  'TRJJGNV12903CD8395': ['unplayable'],
#  'TRJJGYW12903CE7193': ['basically bass'],
#  'TRJJGPD128F931A4C5': ['chillout',
#   'loved',
#   'electronic',
#   'downtempo',
#   'ambient'],
#  'TRJJGRJ128F4281246': ['trance',
#   'electronic',
#   'dance',
#   'club zone',
#   'morocco rocks',
#   'vocal house',
#   'club',
#   'pop'],
#  'TRJJGMC12903CC4157': ['reggaeton'],
#  'TRJJGOR128F4281065': ['renaissance', 'early music'],
#  'TRJJGGW12903CB12A7': ['gothic'],
#  'TRJJGVE12903CF943E': ['rad',
#   'live that guy was shaking the maracas and playing the drum so hard'],
#  'TRJJGGO128C7196CAC': ['soul', 'motown', '60s'],
#  'TRJJGHA128F9338DE4': ['sad'],
#  'TRJJGXU128F426A4B5': ['hip hop',
#   'male vocalists',
#   'leapsandbounds cdcollection'],
#  'TRJJGKW12903CC81B4': ['indie rock', 'indie', 'british'],
#  'TRJJGTF128F42484D9': ['hardcore'],
#  'TRJJGYZ128F92FBBB9': ['qawwali'],
#  'TRJJGKV12903CB62B7': ['rap'],
#  'TRJJGRB128F9315050': ['beres hammond'],
#  'TRJJGJE12903CDA9B2': ['salsa'],
#  'TRJJGKQ128F92E0946': ['cover'],
#  'TRJJGEV128F427EE68': ['double ender 4'],
#  'TRJJVNS128F92ECA1A': ['jazz', 'female vocal', 'jazz vocal', 'vocal jazz'],
#  'TRJJVIN12903CB5AC8': ['heavy',
#   'house',
#   'rnb',
#   'electronica',
#   'dubstep',
#   'dnb',
#   '00s',
#   'mos'],
#  'TRJJVFS128F4263704': ['country',
#   'folk',
#   'singer songwriter',
#   'mine',
#   '1989',
#   'one star',
#   'james mcmurtry'],
#  'TRJJVCQ128F931FB2E': ['shoebox project'],
#  'TRJJVUD128EF3681EE': ['jewish',
#   'klezmer',
#   'radical jewish culture',
#   'jewish tradition'],
#  'TRJJVTN128F426B19B': ['hardcore', 'nyhc', 'hardcore punk'],
#  'TRJJVNM128F92E2021': ['new wave', '80s', 'rock'],
#  'TRJJVIP12903CDD0A1': ['grindcore', 'under a minute'],
#  'TRJJVBE128F4283951': ['dub', 'reggae', 'radio'],
#  'TRJJVUU128F92DC67A': ['rock'],
#  'TRJJVBR128C7196DF6': ['female vocalists', 'alternative', 'alternative rock'],
#  'TRJJVGF128F427AD3E': ['fav',
#   'rock chileno',
#   'favoritas',
#   'rockchileno',
#   'folklatinoamericano',
#   'carlitis'],
#  'TRJJVOX128F9310D83': ['instrumental', 'screamo'],
#  'TRJJVLV12903CA1C3A': ['reggae'],
#  'TRJJVME128F4236B32': ['smooth jazz'],
#  'TRJJVKJ128F9306424': ['jazz'],
#  'TRJJVAU128F934190D': ['samba', 'paulinho da viola'],
#  'TRJJVSM128F9300E7D': ['black thrash metal'],
#  'TRJJVNX128F4243FE3': ['black metal', 'finnish metal'],
#  'TRJJVRU128F93236AF': ['house', 'electronic'],
#  'TRJJVCS12903CB5280': ['free jazz', 'electronic', 'post punk', 'titular'],
#  'TRJJVRX128F4272E24': ['antifa', 'arbeiterbewegung', 'linke lieder'],
#  'TRJJVFT128F92EF1D9': ['electro',
#   'remix',
#   'catchy',
#   'good shit',
#   'fantastique',
#   'maverick',
#   'fuck sarko',
#   'thriller remix',
#   'mj remix',
#   'club misfits'],
#  'TRJJVOL128F1465021': ['vocal trance',
#   'dance',
#   'milk inc   goodbye says it all'],
#  'TRJJVWI128F423F44A': ['piano',
#   'relax',
#   'film score',
#   'score',
#   'simon birch',
#   'the bucket list'],
#  'TRJJVDW128F4240D22': ['beres hammond'],
#  'TRJJVWO128F9365A9E': ['pop',
#   'electronic',
#   'synthpop',
#   'synth pop',
#   'bit pop',
#   'make you happy',
#   '3 and a half stars'],
#  'TRJJVBP128F423B388': ['metalcore', 'death metal'],
#  'TRJJVHN128F92F6E49': ['country', 'bluegrass'],
#  'TRJJVTQ128EF33EF77': ['darkwave', 'gothic', 'synth', 'synth gothic'],
#  'TRJJVIC128F1495A29': ['funk'],
#  'TRJJVEG128F92F33D1': ['new orleans',
#   'new orleans rhythm and blues',
#   'rock baladas',
#   'double ender 22'],
#  'TRJJVXE128F424DE70': ['60s', 'oldies', 'motown', 'soul and rnb classics'],
#  'TRJJVCH128F4275620': ['80s', 'new wave', 'post punk'],
#  'TRJJVWM12903CE821C': ['rock'],
#  'TRJJLFP128F425DD12': ['skid row'],
#  'TRJJLNK128F42596F8': ['tango'],
#  'TRJJLIX128F424D3D2': ['indie rock', 'indie', 'rock', 'alternative'],
#  'TRJJLIN128F425E812': ['rock', 'poland', 'naj naj naj'],
#  'TRJJLNM128F9335CC2': ['house',
#   'dance',
#   'female vocalists',
#   'vocal house',
#   'deep house',
#   'disco house'],
#  'TRJJLLV128F1474100': ['suomipop'],
#  'TRJJLZH128F14ADCA8': ['christian', 'indie'],
#  'TRJJLZH128F422B432': ['cumbia', 'alfredo gutierrez', 'vallenato'],
#  'TRJJLTK128F4298DD2': ['pop punk', 'emo', 'rock', 'alternative'],
#  'TRJJLLG128F4287990': ['extreme gothic metal'],
#  'TRJJLQQ128E078B755': ['metal', 'metalcore', 'rock'],
#  'TRJJLSQ128E0784E21': ['lucky boys confusion   broken',
#   'stumbled upon this good song'],
#  'TRJJLWC128F9353B11': ['2003'],
#  'TRJJLTC128F92DE731': ['drum and bass'],
#  'TRJJBLR128F9305AC8': ['ska', 'reggae'],
#  'TRJJBZH128F93217CF': ['latin',
#   'viernes',
#   'aterciopelados',
#   'dedicable',
#   'moviendo el bote',
#   'musica que me hace feliz',
#   'rock en rolas',
#   'malditosudacas'],
#  'TRJJBKS128F424BD2B': ['ska'],
#  'TRJJBUV12903CC90B0': ['dutch', 'eurodance'],
#  'TRJJBOQ128F146B475': ['rock argentino'],
#  'TRJJBHT12903D030D8': ['rock', 'alternative', 'indie rock', 'australian'],
#  'TRJJBGR128E0781107': ['female vocalists',
#   'alternative',
#   'rock',
#   'alternative rock'],
#  'TRJJBEY128F14731FB': ['pop', 'italy', '00s', 'pinoy bands', 'allegra'],
#  'TRJJBRX128E0792355': ['ska', 'rock', 'punk', 'alternative'],
#  'TRJJBEU128F4238C70': ['dancehall'],
#  'TRJJBEK128F92E3B7B': ['rock', 'jazz', 'underground'],
#  'TRJJBWE128E0786F69': ['synthpop', 'calm', 'czhit', 'cz5'],
#  'TRJJBDW128F92C794B': ['jazz',
#   'jazz vocal',
#   'ole   salsa   tango   spanisch   brasil'],
#  'TRJJBRG128F424B265': ['ambient'],
#  'TRJJBYY128F425371E': ['darkwave'],
#  'TRJJBSZ128F146048F': ['jazz', 'jazz piano', 'paindestre'],
#  'TRJJBUM128F934B02F': ['death metal', 'brutal death metal'],
#  'TRJJBGZ128F4282B72': ['pop',
#   'finnish',
#   'melankolia',
#   'suomipop',
#   'lacrimaindarkness'],
#  'TRJJBNO128F4299DEA': ['tango'],
#  'TRJJBGL128F424D850': ['songs i love',
#   'nerdcore',
#   '00s',
#   'duet',
#   'rap rock',
#   'new york',
#   'synth',
#   'pop rock',
#   'indie rock',
#   'alternative rock',
#   'alternative pop',
#   'indie pop',
#   'hip hop',
#   'alternative',
#   'dance',
#   'electronic',
#   'hip hop',
#   'rap',
#   'pop',
#   'funk',
#   'indie',
#   'rock'],
#  'TRJJBVU128F145888F': ['the word morning',
#   'the word gun',
#   'the word shotgun'],
#  'TRJJBOC128F42BC4CB': ['romantico', 'cantautores'],
#  'TRJJBKO128F426DE6B': ['vilma palma e vampiros   soy un loco'],
#  'TRJJBPG12903CF6067': ['pop'],
#  'TRJJBIA128F4275E8F': ['polish hip hop'],
#  'TRJJBHB128F14AE61F': ['christian rock', 'christian hard rock'],
#  'TRJJBZJ128F147C972': ['indie',
#   'alternative',
#   'indie rock',
#   'experimental rock',
#   'whoa'],
#  'TRJJBPQ128E0793998': ['post punk',
#   'instrumental',
#   'experimental',
#   'eerie',
#   'black'],
#  'TRJJDRA128F427E8DF': ['chillout',
#   'lounge',
#   'downtempo',
#   'nu jazz',
#   'jazz',
#   'chill'],
#  'TRJJDSC128F92F1776': ['90s', '1995'],
#  'TRJJDKA128F92EAF89': ['nu jazz', 'jazz', 'experimental jazz'],
#  'TRJJDEJ128F4289B4C': ['oldies'],
#  'TRJJDEZ128F4265DD7': ['rock',
#   'alternative',
#   'political',
#   'alternative rock',
#   'hard rock'],
#  'TRJJDQS128F427AF83': ['mexico'],
#  'TRJJDIP128F930CA69': ['spring music', 'may carol'],
#  'TRJJDFN12903CE984B': ['soul'],
#  'TRJJDZC128F9337143': ['instrumental jazz tag'],
#  'TRJJDTK128F931D1E0': ['oh my father', 'lds', 'lds hymns'],
#  'TRJJDOC128F9301306': ['indie', 'indie pop'],
#  'TRJJDJC128F42800FB': ['soul'],
#  'TRJJDSB128E0791E4A': ['77davez all tracks', 'easy listening', 'alternative'],
#  'TRJJDFG128F429EDBE': ['jazz',
#   'organ',
#   'smooth',
#   'orchestra',
#   'gioco digitale',
#   'the mar keys'],
#  'TRJJDNQ128F14933FA': ['soundtrack', 'babel'],
#  'TRJJDRT128F93308F2': ['rock',
#   'house',
#   'alternative',
#   'neo psychedelia',
#   'british',
#   '00s',
#   'uk rock',
#   '2000s',
#   'fm4',
#   'gruvin',
#   'weather songs',
#   '2009',
#   'ukbands noizemarket',
#   'quarkzangsun',
#   'quarkzangsun v1',
#   'quarkzangsun p9'],
#  'TRJJDYD128F426F39C': ['weather', 'sommer', 'neffets musik tip 2007'],
#  'TRJJDYX128F93030E4': ['joe lynn turner'],
#  'TRJJDWC128F149990E': ['world',
#   'chile',
#   'illapu',
#   'nueva cancion chilena',
#   'folclore',
#   'pablo neruda',
#   'indigenous music',
#   'ncch',
#   'illapu puerto rico',
#   'puerto pobre'],
#  'TRJJDAQ128F4268EE9': ['nice',
#   'rock',
#   'guitar',
#   'i see stars',
#   'under two minutes',
#   'been a fan'],
#  'TRJJDSY128F932CD33': ['312472'],
#  'TRJJDGQ12903CA4E2B': ['blues', 'harmonica blues', 'sonny terry'],
#  'TRJJDIZ128F92C9FDC': ['soundtrack'],
#  'TRJJAZQ128F14594DE': ['oldies', '70er'],
#  'TRJJAKW12903CA9512': ['rock', 'australian idol'],
#  'TRJJAQZ128F42659C9': ['country', 'classic country', 'vern gosdin'],
#  'TRJJAMK128F42747C6': ['female vocalist',
#   'singer songwriter',
#   'rock',
#   'acoustic'],
#  'TRJJAVZ12903CE03AE': ['77davez all tracks'],
#  'TRJJAHW12903CDDA75': ['country'],
#  'TRJJAXM128F934D205': ['indie rock'],
#  'TRJJAFD128F92EDCBF': ['rap',
#   'southern rap',
#   'underground rap',
#   'dirty south',
#   'ugk'],
#  'TRJJAPQ128F4216B17': ['indie',
#   'ambient',
#   'instrumental',
#   'post rock',
#   'mellow'],
#  'TRJJAUA128F42981E9': ['smoooth jazz'],
#  'TRJJAEM128F4250F41': ['instrumental'],
#  'TRJJAVU128F9340B1F': ['coldwave',
#   'psychedelic',
#   'industrial rock',
#   'grindy',
#   'i want back to the 80s',
#   'friendsofthekingofrummelpop'],
#  'TRJJATB128F428B567': ['likey'],
#  'TRJJAJR128F92F6C05': ['native american', 'first nation'],
#  'TRJJALD12903CCD236': ['indie pop', 'pop'],
#  'TRJJAJJ128F4288E76': ['italian', 'rap'],
#  'TRJJAME128F42667F4': ['brazil', 'reggae nordeste'],
#  'TRJJAQF12903D0ACA2': ['angelic music', 'harp relax'],
#  'TRJJAUG128F932A681': ['rock', 'rap', 'dominik', 'gila', 'yannik'],
#  'TRJJATI128F428A231': ['metal',
#   'punk',
#   'alternative rock',
#   'punk rock',
#   'irish',
#   'celtic punk',
#   'forever live'],
#  'TRJJQVZ128F14AA599': ['minimal'],
#  'TRJJQBU128F92EDE1F': ['80s', '1980s', 'good stuff'],
#  'TRJJQEG128F4233EF1': ['political'],
#  'TRJJQNY128F42817B9': ['mpb', '70s'],
#  'TRJJQHD128F933CE6D': ['ambient', 'chillout', 'psybient'],
#  'TRJJQXI128F1483216': ['pop',
#   'brazil',
#   'brasil',
#   'obscure yet streamable tracks',
#   'cocktails at sunset'],
#  'TRJJQXR128F428C4FF': ['svenska'],
#  'TRJJQED128F1495C18': ['jazz'],
#  'TRJJQXE128F429FC56': ['soul', 'funk', 'blaxploitation', 'soundtrack'],
#  'TRJJQHY128F92DFF01': ['electronic', 'dance', 'techno'],
#  'TRJJQBP128F42AE5EB': ['rock'],
#  'TRJJQNH128F92CEB62': ['soul', 'neo soul', 'india arie', 'rnb'],
#  'TRJJQUV128F14AE083': ['contemporary christian',
#   'christian',
#   'mes',
#   'greenbelt festival 2007'],
#  'TRJJQYF128F146B3B6': ['hip hop', 'german', 'deutsch', 'fettes brot'],
#  'TRJJQRG128F148B724': ['funk'],
#  'TRJJQHQ128F425E6D9': ['german'],
#  'TRJJQAD128F42A4F54': ['cover', 'female vocalists'],
#  'TRJJQVH128F92F9BC0': ['love'],
#  'TRJJQTU12903CE03CC': ['77davez all tracks'],
#  'TRJJQWE128F4263494': ['jazz'],
#  'TRJJQRH128F1486FCC': ['velha guarda'],
#  'TRJJQKZ128F4271995': ['slowcore'],
#  'TRJJQYZ128F9327896': ['indie pop',
#   'lo fi',
#   'genius',
#   'bass',
#   'anxious',
#   'fast paced',
#   'handclaps',
#   'indie collection of songs',
#   'twee as fuck',
#   'omg handclaps',
#   'title with punctuation',
#   'clap clap clap your hands',
#   'my frog is flowery',
#   'workforce1',
#   'fabulous titles'],
#  'TRJJQFN128F1478F67': ['indie pop',
#   'retro',
#   'indiepop',
#   'indie',
#   'psychedelic'],
#  'TRJJQQP128F428E22E': ['electronic', 'experimental', 'electronica'],
#  'TRJJQTM128F42A9A17': ['country'],
#  'TRJJQQT128F933F9E1': ['zouk'],
#  'TRJJQSI128F92D94D5': ['latin jazz'],
#  'TRJJQKT128F930A382': ['punk rock'],
#  'TRJJOJO128F92F714C': ['celtic', 'irish'],
#  'TRJJOSH128F42593B0': ['country',
#   '70s',
#   'country classic',
#   'international country boy mix',
#   'malesinger'],
#  'TRJJOUU128F92C49D2': ['singer songwriter',
#   'melancholy',
#   'folk',
#   'leonard cohen',
#   'chillout'],
#  'TRJJOQK128F1480CA6': ['indie', 'sleep core', 'alternative'],
#  'TRJJOIE128F4245092': ['rolling stones cover', 'stonedbeat'],
#  'TRJJOTH128F92FDD17': ['experimental',
#   'idm',
#   'awesome',
#   'epic',
#   'thotepfavourites'],
#  'TRJJOIC128F933C492': ['psychedelic',
#   'pop',
#   'cool',
#   'soundtrack',
#   'slow',
#   '1960s'],
#  'TRJJOSF128F4265F88': ['electro', 'electroclash'],
#  'TRJJOEW128F92DFBEF': ['sonido chido', 'frogprog'],
#  'TRJJOAG128F427F320': ['raster noton', 'electronic', 'experimental'],
#  'TRJJOUE128F423F6B8': ['80s',
#   'country',
#   'someone could lose a heart tonight   eddie rabbitt'],
#  'TRJJORR128F9303E8C': ['dubstep'],
#  'TRJJORQ128F429F0FD': ['soul'],
#  'TRJJOIT128F4273236': ['jazz', 'latin', 'cuban'],
#  'TRJJOZJ128F9327B55': ['misc'],
#  'TRJJONO128F93434C7': ['rock',
#   'finnish',
#   'finland',
#   'suomi',
#   'finnish lyrics',
#   'suomirock',
#   'suomeksi',
#   'juice leskinen',
#   'elandal pl none'],
#  'TRJJORJ12903CAD9AF': ['unlovable'],
#  'TRJJOUP128F934DB65': ['real hip hop'],
#  'TRJJOBI128F42AC40F': ['soul'],
#  'TRJJOJL128E078A34A': ['60s', 'flower power', 'california'],
#  'TRJJOQS128F92E5352': ['reggae'],
#  'TRJJURV128F92D1315': ['soul'],
#  'TRJJUSO128F92F06CB': ['industrial', 'gothic'],
#  'TRJJUFH128F14608C9': ['stand up comedy', 'jasper carrott'],
#  'TRJJUHC128F933F139': ['house'],
#  'TRJJUYE128F9335DB5': ['prda', 'vvvvv', 'tracking 2008'],
#  'TRJJUVR128F426EAE9': ['classic rock', 'rock'],
#  'TRJJUGU128F93480FC': ['punk', 'friendsofthekingofrummelpop'],
#  'TRJJUNK128F14AB141': ['deutsch', 'german'],
#  'TRJJUOJ128F427B905': ['heavy metal'],
#  'TRJJUBQ128F428CB4F': ['ostrock'],
#  'TRJJUPO128F92DCDDF': ['alt country', 'country', 'folk', 'female vocalists'],
#  'TRJJUEX12903CB0245': ['hardcore'],
#  'TRJJUSE128F92F9875': ['grindcore', 'sick'],
#  'TRJJULG12903CC7FF4': ['lisa fischer', 'vbest'],
#  'TRJJUGN128F9323899': ['hmm sodermanland', 'tapptapptapp'],
#  'TRJJUIM128F92FEA23': ['50s', 'romantic'],
#  'TRJJUIE128F42857CE': ['jazz', 'alex bugnon'],
#  'TRJJUWQ128F429DA7B': ['jazz'],
#  'TRJJUPA128F42933F1': ['rock',
#   'pop rock',
#   'butch walker',
#   'pretty rock boys',
#   'alesena',
#   'mystie chamberlin',
#   'just another folk singer',
#   'the merch grrls',
#   'throwaway grrls',
#   'teh typos',
#   'the devil and the deep blue sea'],
#  'TRJJULO128E0791CA3': ['hard rock'],
#  'TRJJUSC128F424FDC5': ['awesome',
#   'deep digital',
#   'powerful tune',
#   'that rich sound',
#   'tribally',
#   'sasha  james holden',
#   'masterful melodies'],
#  'TRJJUKQ12903CE858C': ['indie',
#   'south of nowhere',
#   'female vocalists',
#   'folk'],
#  'TRJJUEL128F4263657': ['latin jazz'],
#  'TRJJUTW12903CF8C1E': ['gothic metal'],
#  'TRJJIJT128F428DD08': ['rap', 'hip hop', 'female georgia'],
#  'TRJJIYW128F4266DF2': ['folk metal'],
#  'TRJJIPP128F4280134': ['blues', 'blues guitar'],
#  'TRJJIPH128F426E6E3': ['agnaldo timoteo', 'matriz y filial'],
#  'TRJJIWZ128F4261900': ['brasil', 'mangue beat'],
#  'TRJJIPV128F93368DC': ['jazz', 'pop'],
#  'TRJJIIY128F14A300C': ['best stand up comedy', 'steve harvey'],
#  'TRJJIQE12903CBB379': ['basically bass'],
#  'TRJJIPV128F4262DB7': ['rock', 'polish'],
#  'TRJJILX12903CDB4D7': ['progressive metal', 'nicht schlecht'],
#  'TRJJIXT128E078298C': ['alternative',
#   'rock',
#   'singer songwriter',
#   'nick cave'],
#  'TRJJIAD12903CB84F1': ['easy listening', 'country'],
#  'TRJJIPH12903CF1C02': ['my favourite songs',
#   'violent',
#   'beloved',
#   'progressive doom metal',
#   'female fronted metal',
#   'razor',
#   'metallic perfection'],
#  'TRJJINY128F4280C97': ['00s',
#   'indietronic',
#   'dancepunk',
#   'electropunk',
#   'disco punk',
#   'discopunk',
#   '10s'],
#  'TRJJIZH128F92F6250': ['soul', 'love it', 'searching for my love'],
#  'TRJJILS12903CDB279': ['viking metal'],
#  'TRJJIGM12903CF47ED': ['hard rock'],
#  'TRJJIUG128F4286EEE': ['cuban', 'cha cha cha', 'latin'],
#  'TRJJIOW128F92E4602': ['fusion'],
#  'TRJJIJT128F92E37D3': ['industrial', 'gothic rock'],
#  'TRJJTQK128F42581D9': ['electronic', 'n01s3 n k00l', 'chillout kh'],
#  'TRJJTMQ128F4276227': ['roots',
#   'roots reggae',
#   'roots reggae',
#   'steel pulse',
#   'roots rasta reggae'],
#  'TRJJTNU128F427AC2C': ['rock', 'indie rock', 'swedish'],
#  'TRJJTXD128F4226530': ['instrumental', 'post punk'],
#  'TRJJTEG128F423247E': ['reggae', '1980', 'micron'],
#  'TRJJTLO128F42B2223': ['hip hop'],
#  'TRJJTEM12903CCC648': ['evanescence'],
#  'TRJJTZZ128F147AAD9': ['musica portuguesa', 'portugal'],
#  'TRJJTSH128F93384D9': ['pop'],
#  'TRJJTEQ128F428CA56': ['played at cyberia'],
#  'TRJJTGL128F42705EE': ['clifford brown a night in tunisia',
#   'dsj loved tracks',
#   'a night in tunisia',
#   'c brown'],
#  'TRJJTAH128F149985D': ['sunny day'],
#  'TRJJTYS128F9349C48': ['female jazz vocalist'],
#  'TRJJTTH12903CBF78C': ['hardcore'],
#  'TRJJTFM128F92D0AEC': ['hip hop'],
#  'TRJJTPI128F4276759': ['emo', 'punk', 'screamo'],
#  'TRJJTHP128F1482F4D': ['fey', 'fey  como un angel'],
#  'TRJJTVF128F9317971': ['country'],
#  'TRJJTNB12903CF20F5': ['gothic metal'],
#  'TRJJTSH12903CFBDA3': ['rap', 'underground hip hop', 'jay dee', 'j dilla'],
#  'TRJJTYM128F1470EDE': ['new wave'],
#  'TRJJCWF128F145B8D2': ['60s', 'oldies'],
#  'TRJJCGJ128F429803D': ['westlife', 'boybands', 'ballads', 'irish'],
#  'TRJJCXA12903CDBEDF': ['indie', 'emo', 'rock', 'alternative', 'indie rock'],
#  'TRJJCJL128F426F20C': ['lugntv', 'lx '],
#  'TRJJCQV128F425ACDC': ['czech and slovak good music'],
#  'TRJJCEW128F930FFE9': ['rock', 'blues', 'pligaa'],
#  'TRJJCEM12903CFA85F': ['salsa'],
#  'TRJJCDF128F932A34E': ['instrumental'],
#  'TRJJCGJ12903CABD4B': ['rock'],
#  'TRJJCRA128F92F0F35': ['favorite', 'female'],
#  'TRJJCPW128F93049E8': ['cover',
#   'punk rock',
#   'best covers of all time',
#   'punk'],
#  'TRJJCSL128F42964BE': ['downtempo', 'europejska'],
#  'TRJJCSO128F424504B': ['death metal', 'old school death metal'],
#  'TRJJCDX128F92E6772': ['trance'],
#  'TRJJCKA128F428AEAC': ['elephant 6', 'tulevia'],
#  'TRJJCMI128F428E652': ['rock', 'pop'],
#  'TRJJCFM128F42B8324': ['stoner rock', 'rock'],
#  'TRJJCRJ128F14A4221': ['jazz'],
#  'TRJJCAE128F931559C': ['swing'],
#  'TRJJCRJ128F42746E8': ['adasko1314'],
#  'TRJJCAW128F935323F': ['rap',
#   'rap francais',
#   'eurocrunk',
#   'electro hip hop',
#   'rap electro',
#   'french crunk',
#   'french dirty south'],
#  'TRJJCXO128F425B515': ['love',
#   'electropop',
#   'electronic',
#   'nu rave',
#   'dance',
#   'awesome',
#   'magic'],
#  'TRJJCKW128F429476B': ['german', 'hiphop', 'hip hop', 'deutsch hip hop'],
#  'TRJJKTO128F42362B2': ['french', 'hip hop', 'french rap'],
#  'TRJJKTE12903CE8228': ['jazz'],
#  'TRJJKTV128F4277668': ['b side'],
#  'TRJJKUC128F9335766': ['socjalism'],
#  'TRJJKAM128F147556A': ['disney', 'kids'],
#  'TRJJKJQ12903D061D3': ['pop', 'dance', 'christina aguilera', 'electronic'],
#  'TRJJKLR128F92F537B': ['guitar', 'blues'],
#  'TRJJKAI128F427EDA2': ['2006'],
#  'TRJJKNR128F428BBDE': ['swedish', 'nikola sarcevic', 'head up'],
#  'TRJJKDW128F426655A': ['tracking 2008'],
#  'TRJJKJI128F92F6116': ['drjazzmrfunkmusic'],
#  'TRJJKCJ12903CAEB3E': ['romantic', 'skipping in the rain'],
#  'TRJJKVQ12903CF264A': ['metal'],
#  'TRJJKDF128F423655D': ['worldfolkz', 'merecumbeat'],
#  'TRJJKQR128F42A2028': ['causation'],
#  'TRJJKYV128F92DBA27': ['ambient',
#   'nice elevator music',
#   'gotanygoodmusic',
#   'hi fidelity',
#   'halftoned singles club',
#   'pm stuff'],
#  'TRJJKRU128F4265E1D': ['heavy metal', 'hard rock'],
#  'TRJJKWR128F4293AE3': ['rock',
#   'folk',
#   'indie',
#   'singer songwriter',
#   'electronic',
#   'alternative',
#   'indie pop',
#   'indie rock',
#   'minnesota',
#   'colours'],
#  'TRJJKQL12903CDAE7A': ['electronic',
#   'electro pop',
#   'tech house',
#   'minimal electro',
#   'minimal house',
#   'club house',
#   'electrorock',
#   'house music',
#   'ambient trance',
#   'ambient house',
#   'melodic trance',
#   'dream trance',
#   'heavy beat',
#   'minimal techno',
#   'progressive electronica',
#   'electro minimal',
#   'minimal tech house',
#   'progressive vocal trance',
#   'deep beat',
#   'club house techno',
#   'heavy electro house mix',
#   'electronica   drum  bass',
#   'electro beat dance',
#   'heavy beat rock',
#   'ambient',
#   'electropop',
#   'house',
#   'cool',
#   'dance',
#   'techno',
#   'progressive rock',
#   'electronica',
#   'downtempo',
#   'electro',
#   'party',
#   'awesome',
#   'club',
#   'minimal',
#   'drum and bass',
#   'progressive trance',
#   'dance rock',
#   'electronic music',
#   'dance party',
#   'minimal techno',
#   'electro house',
#   'drum n bass',
#   'deep house'],
#  'TRJJKEL12903CB0FA1': ['christian'],
#  'TRJJKPQ128F422BED3': ['afro peruvian'],
#  'TRJJKNH128F933667B': ['reggae',
#   'marijuana',
#   'roots reggae',
#   'jah',
#   'every morning the black sun rise',
#   'pitar',
#   '2giveme5'],
#  'TRJJKJO128F423DC9C': ['last fm mistake'],
#  'TRJJKSP128F92E6C37': ['soundtrack'],
#  'TRJJKIQ128F148BCDA': ['new wave',
#   'punk rock',
#   'the marvellous vacilations of oddfellaboo'],
#  'TRJJKOD128F42B8042': ['jazz', 'nat king cole', 'jazz vocal'],
#  'TRJJRAB128F933044D': ['alternative easy'],
#  'TRJJRNO12903CEC169': ['the really loved'],
#  'TRJJRYQ128F42A3881': ['rock',
#   'female vocalists',
#   'metal',
#   'heavy metal',
#   'female fronted metal'],
#  'TRJJRKQ12903CE8454': ['spanish'],
#  'TRJJRCM128F42BC223': ['rock'],
#  'TRJJRQK12903CB6AC0': ['eurovision winner', 'eurovision'],
#  'TRJJROR128F1496B77': ['nice',
#   'ska',
#   'good',
#   'summer',
#   'cool stuff',
#   'fusion',
#   'good song',
#   'gute laune',
#   'nochmal',
#   'schoen',
#   'immer wieder gern',
#   'batalla de belchite'],
#  'TRJJRQO128F42868C8': ['screamolicious', 'totally epic'],
#  'TRJJRVT12903CD77BD': ['60s', 'oldies'],
#  'TRJJRSK128F92DDF85': ['rock', 'cool'],
#  'TRJJRJB128F4286928': ['sludge', 'experimental'],
#  'TRJJRXA128F92EF008': ['best song ever'],
#  'TRJJRCJ128F42598B3': ['funk', 'acid jazz'],
#  'TRJJRMH128F92DFB99': ['electropop', 'indie', 'electronic'],
#  'TRJJRKH12903CBF076': ['hard trance'],
#  'TRJJRSJ128F426BEE1': ['soul', 'classic soul', 'patti austin'],
#  'TRJJRWY128F428248F': ['60s', 'oldies'],
#  'TRJJRJI128F1474062': ['metalcore', 'hardcore', 'screamo'],
#  'TRJJRZY128F92F3754': ['street punk'],
#  'TRJJRHS128F423F2C3': ['indie',
#   'pop',
#   'finnish',
#   'summer',
#   'kauneimmat laulut',
#   'and summer will never end'],
#  'TRJJRBD128F42AD283': ['hip hop', 'rap', 'hip hop', 'b boy stance'],
#  'TRJJRBV128F4257D5B': ['cover', 'iron maiden cover'],
#  'TRJJRAF128F93150CE': ['02'],
#  'TRJJRPT128F1485055': ['indie', 'minimal', 'slowcore'],
#  'TRJJMRG128E0789BA5': ['indie', 'indie rock'],
#  'TRJJMHD128F4276FF9': ['indie', 'anti folk', 'kimya dawson', 'fuck yes'],
#  'TRJJMYM12903CFBD3A': ['dutch', 'nederpop', 'indietronic'],
#  'TRJJMGV128F421E63E': ['country', 'newbest', 'topbest'],
#  'TRJJMVX128F92EDE31': ['techno'],
#  'TRJJMCW128F147A6C3': ['afrobeat'],
#  'TRJJMPS128E0787238': ['julian lennon'],
#  'TRJJMTC128F423626F': ['spanish guitar'],
#  'TRJJMTT128F42819F8': ['folk', 'female vocalists', 'celtic'],
#  'TRJJMFO128F92E145F': ['french', 'ska', 'instrumental', 'francais'],
#  'TRJJMCL128F92DE97F': ['idm', 'electronic'],
#  'TRJJMQU128F932A727': ['metro downtempo', 'metro reggae', 'lizvelrene2009'],
#  'TRJJMGC128F42B77BA': ['2005', 'electro pop', 'my inner emo lesbian'],
#  'TRJJMMG128F931DF4A': ['bobby fuller four cover',
#   'sousaphonic aotm january 2011'],
#  'TRJJMCJ12903CC9F94': ['electronic',
#   'world',
#   'music to dance to',
#   'personal favourites',
#   'happy bouncy',
#   'the strombo show',
#   'sxsw 2010'],
#  'TRJJMGA12903CEEFD3': ['choir', 'hand claps'],
#  'TRJJMSD128F4218B1E': ['hardcore', 'hardcore punk', 'punk'],
#  'TRJJMFD12903CBC2EB': ['noise pop', 'wtf is a tag i dont know'],
#  'TRJJMOA12903CD42D2': ['punk', 'sexy', 'female vocals'],
#  'TRJJMAQ128F4292E63': ['oldies'],
#  'TRJJMZM128F149FA6E': ['downtempo', 'trip hop', 'lounge', 'electronic'],
#  'TRJJMFM128F428CD63': ['swedish', 'schlager', 'svenskt'],
#  'TRJJMJI128F428509C': ['country',
#   'good song',
#   'male country',
#   'american country'],
#  'TRJJFFS128F425C78F': ['jewish', 'hebrew'],
#  'TRJJFFK128F4244769': ['blues rock', 'fusion'],
#  'TRJJFDF128F934AB3E': ['rock'],
#  'TRJJFDZ128F92C9C32': ['czech'],
#  'TRJJFGX128F9319A62': ['hip hop', 'hip hop'],
#  'TRJJFEJ128E0794429': ['instrumental', 'cirque'],
#  'TRJJFWZ128F42B2ADE': ['instrumental',
#   'alternative',
#   'the redneck  manifesto'],
#  'TRJJFPK128F92C2943': ['death metal'],
#  'TRJJFTY128F92FFC43': ['djembe',
#   'african',
#   'etno',
#   'african drums',
#   'mamady',
#   'krin'],
#  'TRJJFNX128F9307348': ['rapcore'],
#  'TRJJFER128F147A333': ['electronic', 'electro', 'instrumental'],
#  'TRJJFEA128F932BBCD': ['industrial'],
#  'TRJJFLZ128F422A78A': ['symphonic metal'],
#  'TRJJFQV128F4287AD2': ['acceptable ladies', 'salon'],
#  'TRJJFRX12903CD0B10': ['oldies'],
#  'TRJJFKG128F92F2281': ['gasoline', 'serotonine', 'pinza'],
#  'TRJJFPZ128EF36578A': ['3 stars', 'post rock'],
#  'TRJJFQF128F426665B': ['rock', 'songs about animals'],
#  'TRJJFUN12903D0CA94': ['lounge', 'flute', 'psych', 'sweet', 'jazzoul'],
#  'TRJJFEK128F92EBFFE': ['oi'],
#  'TRJJFHL12903CC73E4': ['jazz rock', 'jazz fusion', 'psychedelic jazz'],
#  'TRJJFQT128F428229E': ['chillout'],
#  'TRJJFWF128F427FFE0': ['melodic trance'],
#  'TRJJYEM128E07893F9': ['power pop'],
#  'TRJJYSK128F9333E37': ['rock', 'heavy metal'],
#  'TRJJYNW128F934D959': ['interesting',
#   'autumnal',
#   'glastonbury 2007',
#   'fxxking',
#   'slordig'],
#  'TRJJYXI128F4237D5D': ['indie', 'swedish', 'love at first listen'],
#  'TRJJYCR128F4273ECC': ['for seb', 'sebworld'],
#  'TRJJYAH128F9327C5A': ['rhythm and blues'],
#  'TRJJYEI128E0791261': ['indie', 'singer songwriter', 'acoustic', 'mellow'],
#  'TRJJYIK12903CBB887': ['trance'],
#  'TRJJYVG128F92E242A': ['rap', 'wicked', 'hip hop and rap'],
#  'TRJJYPK128F92E896A': ['heavy metal'],
#  'TRJJYXL128F4242DC9': ['under two minutes'],
#  'TRJJYMY128F92FB05F': ['states', 'hot right now', 'synthy phantasy', 'joeco'],
#  'TRJJYYD128F931FAC4': ['female vocalists',
#   'alternative',
#   'singer songwriter'],
#  'TRJJYOA128F421A651': ['stoner rock',
#   'heavy metal',
#   'only to be listened to while smoking a cigarette'],
#  'TRJJYLO128F429C6CD': ['ambient', 'hypnotic'],
#  'TRJJYOO128F428D132': ['country'],
#  'TRJJYZU128F92FF152': ['doom metal', 'death doom metal'],
#  'TRJJYGB12903CB6F44': ['jazz', 'big band', 'high trumpet jazz'],
#  'TRJJYHB128F145ABA9': ['rock',
#   'sad',
#   'folk rock',
#   'you too',
#   'female vocalists'],
#  'TRJJYZA12903CA180A': ['rock', 'pop', 'slow', 'loved'],
#  'TRJJYQM128F423FD41': ['death metal', 'melodic death metal'],
#  'TRJJYZO128F4285D99': ['ebm'],
#  'TRJJWNF128F92DD992': ['samba'],
#  'TRJJWGD128F428A587': ['acoustic', 'wenn', 'meine privat cd sammlung'],
#  'TRJJWXB128F92E6D27': ['death metal',
#   'brutal death metal',
#   'northern hyperblast'],
#  'TRJJWKE128F4259800': ['indie', 'alternative', 'rock'],
#  'TRJJWIO128F92C9912': ['soul', 'soul and rnb classics'],
#  'TRJJWZV12903D0047D': ['hardcore', 'cover', 'hardcore metal', '3 star'],
#  'TRJJWNG128F92F8895': ['black metal', 'folk metal'],
#  'TRJJWSX128F145B3B1': ['guitar',
#   'classic rock',
#   '70s',
#   'progressive rock',
#   'british',
#   'heartfelt'],
#  'TRJJWBW128F92FB135': ['ska', 'mod'],
#  'TRJJWJS128F42A1F44': ['baladas'],
#  'TRJJWQF12903CD4E25': ['50s', '1958', 'rock n roll'],
#  'TRJJWEM128F42727C8': ['tango argentino'],
#  'TRJJWWV128F1464806': ['violin', 'instrumental', 'classical'],
#  'TRJJWHD128F42272DE': ['80s', 'australian', 'new wave'],
#  'TRJJWZQ12903CE39F4': ['folk'],
#  'TRJJWPD128F42B7714': ['female vocalists', 'chillout', 'beautiful', 'sad'],
#  'TRJJWGX128F92DCF18': ['skank'],
#  'TRJJWVO128F4237812': ['punk rock',
#   'hardcore punk',
#   'darby crash could kick your ass'],
#  'TRJJWPQ128F4262F92': ['american country'],
#  'TRJJWJK128F932545B': ['uplifting trance'],
#  'TRJJWAN128F145B038': ['rock',
#   'world',
#   'world music',
#   'african',
#   'south african',
#   'number songs'],
#  'TRJJWRD128F426D7A4': ['indigo girls'],
#  'TRJJWNT128F42BC23B': ['pop', 'female vocalists', 'love'],
#  'TRJJWGK128F426A879': ['arbeitsmusik', 'daryl hall john oates'],
#  'TRJJWEJ128F149CB51': ['tennessee',
#   'need to download',
#   'the pink spiders',
#   'weekday songs',
#   'songs of day and night',
#   'the word night',
#   'the word riot'],
#  'TRJJWLJ128F428AD88': ['country'],
#  'TRJJWHC128F931F6F4': ['alternative rock'],
#  'TRJJWVS128F9340ACA': ['el vrother', 'sabrosura'],
#  'TRJJWFG128F92ECFE3': ['house', 'electro house'],
#  'TRJJWYI128F4237146': ['portuguesa', 'festa portuguesa'],
#  'TRJJWBQ128F422C551': ['jazz'],
#  'TRJJWJW128F149EF24': ['jazz',
#   '70s',
#   'free jazz',
#   '20th century',
#   'avant garde',
#   'saxophone',
#   'vocal jazz',
#   'legends',
#   'jazz instrumental',
#   'blue note'],
#  'TRJJWMS128E07963D2': ['comedy',
#   'vaudeville',
#   'demenziale',
#   'celeste nostalgia',
#   'impagabile',
#   'grotesqe'],
#  'TRJJWCV128F934AA5B': ['simon and garfunkel cover', 'the sound of silence'],
#  'TRJJEXL12903CDEF0B': ['american', 'sxsw 2010'],
#  'TRJJEIV128F425C2E5': ['soul', 'sade', 'jazz', 'female vocalists'],
#  'TRJJEZS128F934AD76': ['death metal'],
#  'TRJJEHE128F426A1D0': ['power metal'],
#  'TRJJEQF128F427D284': ['indie',
#   'mysteries of the universe unraveled',
#   'experimental',
#   'i like',
#   'i rock i roll'],
#  'TRJJEKY128F428698B': ['post punk'],
#  'TRJJEVV128EF35447A': ['hip hop'],
#  'TRJJERL128F4260B76': ['italianigdchill'],
#  'TRJJEND128F92F366B': ['hardcore', 'nyhc'],
#  'TRJJEXE128E079116E': ['o holy night'],
#  'TRJJELX128F932012F': ['rock',
#   'country',
#   'indie',
#   'americana',
#   'singer songwriter',
#   'indie rock',
#   'awesome',
#   'folk rock',
#   'tom pettyesque'],
#  'TRJJEUS128F423BCE4': ['indie'],
#  'TRJJEZJ128F92E68D2': ['black metal'],
#  'TRJJEDN128F424CB56': ['blues', 'rhythm and blues', 'dasr selected radio'],
#  'TRJJEXX128F93145C3': ['instrumental', 'indie'],
#  'TRJJEMG128F427D214': ['rock', 'punk', 'indie', 'pop punk'],
#  'TRJJENO128F422AD8F': ['doom metal', 'melancholic'],
#  'TRJJEXU128F9321B7E': ['rap', 'hip hop', 'gangster   rap   hip hop'],
#  'TRJJEZG128F932DC02': ['vocal trance'],
#  'TRJJESO128F92D75F3': ['quality', 'smokin hot', 'guitarthic', 'legal sounds'],
#  'TRJJEJI128E079392F': ['classic rock'],
#  'TRJJELA128F428B9D1': ['over 5 minutes long'],
#  'TRJJEUX128F4251C3A': ['country', 'classic country'],
#  'TRJJELX128F9309DCF': ['dreamy',
#   'mellow',
#   'indie pop',
#   'female vocalists',
#   'melancholy',
#   'indie',
#   'sadness'],
#  'TRJJESL128F932CB6E': ['salsa'],
#  'TRJJEUK12903D08930': ['trance', 'best'],
#  'TRJJEIC128F92FF776': ['steady'],
#  'TRJJEJD128F9320B35': ['country'],
#  'TRJJENU12903CD9297': ['ska', 'neophyte'],
#  'TRJJXKP12903CC24A7': ['blues'],
#  'TRJJXVC128F9355E08': ['post punk'],
#  'TRJJXWC12903CCD0A7': ['pop latino', '2009'],
#  'TRJJXIZ128F930DD97': ['alternative',
#   'our 2010',
#   'songs about us',
#   'all american rejects',
#   'rock'],
#  'TRJJXRD128F425D596': ['ants', 'compilado nacional'],
#  'TRJJXFH128F1469550': ['metal', 'rock', 'french', 'francais', 'false lyrics'],
#  'TRJJXBV128F428B706': ['dancehall', 'reggae'],
#  'TRJJXHP128E07898C1': ['1996', 'dj shadow', 'electronic', 'f50 1996'],
#  'TRJJXDQ128F425D9CA': ['80s',
#   'pop',
#   'electronic',
#   'synthpop',
#   'new wave',
#   'new romantic',
#   'new discovery'],
#  'TRJJXGE128F4289E69': ['industrial'],
#  'TRJJXFS128F92CADBC': ['reggaeton'],
#  'TRJJXML128F426499F': ['rock', 'female vocalists'],
#  'TRJJXMA128F427F943': ['french', 'francais'],
#  'TRJJXXC128F4238C9B': ['1994'],
#  'TRJJXWI128F426BD83': ['pop', '70s', 'abba'],
#  'TRJJXSY128F9310344': ['house', 'funky house'],
#  'TRJJXTC12903CE70A8': ['smooth jazz', 'fattburger'],
#  'TRJJXDR128F423D2B5': ['classical',
#   'cover',
#   'iron maiden cover',
#   'group of people who are',
#   'the string quartet greatness'],
#  'TRJJXZK128F423A317': ['jazz'],
#  'TRJJXQR128F148B3C3': ['alternative'],
#  'TRJJNTZ12903CC2503': ['good', 'heartcore', 'the best', 'gang vocals'],
#  'TRJJNOZ128F93020FB': ['rock en español'],
#  'TRJJNMI128F932006E': ['punk', 'cover'],
#  'TRJJNGA128F92D548D': ['folk metal'],
#  'TRJJNDP128F92E5C13': ['jazz bot'],
#  'TRJJNOJ12903CE3646': ['hip hop'],
#  'TRJJNXR12903CA6CEF': ['80s', 'new wave'],
#  'TRJJNLV128F92DF509': ['pop', 'rnb'],
#  'TRJJNZF128F92FC727': ['country titles'],
#  'TRJJNCN128E079225E': ['easy listening',
#   'soft rock',
#   'love',
#   'sad',
#   'beautiful',
#   'melancholic',
#   'adult contemporary',
#   'low rock'],
#  'TRJJNWJ128F934D99E': ['electronic', 'techno', 'tech house'],
#  'TRJJNPU128F9333154': ['electro'],
#  'TRJJNIK128F932F923': ['experimental rock'],
#  'TRJJNLF128F145BB71': ['mellow 70s',
#   'average person pipes of peace for kids mebbe'],
#  'TRJJNAO128F4240940': ['metal'],
#  'TRJJNDZ12903CB13A5': ['darkwave'],
#  'TRJJNPG128F425F0A3': ['ska', 'the planet smashers', 'best songs'],
#  'TRJJNSH128F42B65A7': ['berlin', 'indie rock', 'fox   richtung musik'],
#  'TRJJHFE128EF3518FD': ['rock', 'alternative'],
#  'TRJJHUT128F9358B94': ['guitar', 'instrumental'],
#  'TRJJHTX128F1472057': ['dance', 'trance', 'bouncy'],
#  'TRJJHGE128F14692AB': ['west coast rap', 'westcoast'],
#  'TRJJHNB128F93256CA': ['rock', 'punk', 'irish'],
#  'TRJJHBZ128F42906C5': ['progressive rock'],
#  'TRJJHRL128F92F76A8': ['covers', 'ebm'],
#  'TRJJHJV128E0783764': ['covers', 'cover', 'rock', 'alternative'],
#  'TRJJHIH128F92D35BA': ['rock',
#   'rock en espanol',
#   'uruguay',
#   'rock en castellano',
#   'rock uruguayo',
#   'esa lo pibe',
#   'resassi1',
#   'latin rock favoritas'],
#  'TRJJHOW128F92F8FDD': ['indie', 'pop', 'english'],
#  'TRJJHUY128F14B1060': ['rock'],
#  'TRJJHUJ128F4262FDA': ['pop', 'depeche mode', 'cheesy lounge version'],
#  'TRJJHWE128F42482B0': ['psychedelic', 'non existent place'],
#  'TRJJHZY12903CCEA63': ['rap', 'eminem', 'hip hop'],
#  'TRJJHGG128F42645C3': ['progressive rock', 'classic rock'],
#  'TRJJHUN128F14805B5': ['80s', '80', 'pop'],
#  'TRJJHFD128F9365CB6': ['good stuff'],
#  'TRJJHVA128F93010D1': ['bluescruiser'],
#  'TRJJHXN128F4217D03': ['chillout',
#   'lounge',
#   'electronic',
#   'electronica',
#   'downtempo',
#   'nu jazz',
#   'trip hop',
#   'metro downtempo'],
#  'TRJJHTK128F4231746': ['female vocalists',
#   'portuguesa',
#   'dona maria',
#   'regedor likes it',
#   'test sample 1'],
#  'TRJJHGR128F4271A59': ['rock', 'indie rock', 'alternative rock', 'indie'],
#  'TRJJHTZ12903CD2E60': ['heavy metal'],
#  'TRJJHJC128F14AFD5B': ['perlen deutschsprachiger popmusik',
#   'hier gehts um drogen',
#   'die wahren perlen deutschsprachiger popmusik'],
#  'TRJJHZL128F92E7D0F': ['cashpixpnk'],
#  'TRJJHGG128F930DBB3': ['eurodance'],
#  'TRJJHKH128F93011C6': ['spanish', 'indie', 'pop'],
#  'TRJJHBS128F146604D': ['jazz funky'],
#  'TRJJSRM128F42AB1F2': ['house',
#   'electronic',
#   'dance',
#   'techno',
#   '1989',
#   'orange label house arrest'],
#  'TRJJSME128F425B9AD': ['folk', 'melancholic'],
#  'TRJJSWA128F42AB507': ['post rock'],
#  'TRJJSLX128F14697F6': ['wcs', 'west coast swing'],
#  'TRJJSKK128F423A5F8': ['alternative'],
#  'TRJJSOZ128F9319B2C': ['country', 'good old country tunes'],
#  'TRJJSGH128F92DF00B': ['365 days'],
#  'TRJJSAF12903CD436F': ['psybient'],
#  'TRJJSFA12903CCA753': ['ween'],
#  'TRJJSJL128F932E997': ['funk', 'alternative  punk'],
#  'TRJJSOD128F92EB93E': ['anger'],
#  'TRJJSAD128F4256B0D': ['indie', 'britpop', 'the charlatans'],
#  'TRJJSVJ128F92E20F2': ['chillout', 'drjazzmrfunkmusic'],
#  'TRJJSFG128F4292CCD': ['try not to sing along'],
#  'TRJJSEP12903CE38CA': ['progressive rock'],
#  'TRJJSDC128F428E791': ['1981'],
#  'TRJJSWZ128F4291F20': ['emo', 'favoriter', 'aspirational', 'ride your bike'],
#  'TRJJSWN128F4281F15': ['ambient',
#   'jazz fusion',
#   'chill out',
#   'contemporary jazz',
#   'instrumental jazz'],
#  'TRJJSVX128F423B0C9': ['dub'],
#  'TRJJSKN128F931459C': ['rock n roll',
#   'yolala indie fav',
#   'songs to get over a crush',
#   'playful indie yolala'],
#  'TRJJSJP128F9349DBB': ['sexy'],
#  'TRJJSPJ128F92FC5F3': ['bluegrass'],
#  'TRJJSGT128F4229D8F': ['rhytim'],
#  'TRJJSJW128F423720F': ['reggae'],
#  'TRJJZRA128F4290469': ['skeun'],
#  'TRJJZLT128F426DA07': ['retro'],
#  'TRJJZJH128F931AE6A': ['alternative'],
#  'TRJJZME128F428B83E': ['post hardcore', 'punk rock', 'melodic punk'],
#  'TRJJZNK12903CF680B': ['ambient', 'psychedelic', 'lang sang'],
#  'TRJJZON128F14538A2': ['reggae'],
#  'TRJJZIP128F934B280': ['melodic death metal', 'viking metal', 'death metal'],
#  'TRJJZWI128F428A566': ['rock', 'alternative'],
#  'TRJJZTY12903CC5BBF': ['detroit', 'michigan', 'mmfwcl'],
#  'TRJJZVN128F93112C7': ['experimental', 'indie'],
#  'TRJJZHF128F9318AB8': ['dance'],
#  'TRJJZMW128F428B83E': ['punk', 'hardcore', 'hardcore punk', 'my favorite'],
#  'TRJJZMY128F92ED0A3': ['television'],
#  'TRJJZRD128F9329ABE': ['pop'],
#  'TRJJZEZ128F421BDCC': ['post hardcore', 'secondsmile'],
#  'TRJJZGH12903CF85D5': ['trance', 'vocal trance'],
#  'TRJJZIO128F42828DD': ['indie'],
#  'TRJJZPY128F92E9737': ['minimal', 'electronic'],
#  'TRJJZAH128EF35EF1F': ['alternative'],
#  'TRJJZWQ12903CDBC02': ['50s'],
#  'TRJJZKQ128F423BE23': ['spanish rock'],
#  'TRJJZPE128F92D1375': ['soul'],
#  'TRJPJNS128F149850B': ['blues'],
#  'TRJPJTA128F931BCAC': ['schoenemusik'],
#  'TRJPJXP128F42759AC': ['no milk today'],
#  'TRJPJSJ128F424BE08': ['blues',
#   'car',
#   'male vocals',
#   'yellow',
#   'cars',
#   'colors',
#   'color',
#   'vehicles'],
#  'TRJPJEI12903CD5662': ['oi', 'punk rock', 'uk82', 'slade cover'],
#  'TRJPJHF128F4243063': ['folk', 'singer songwriter'],
#  'TRJPJWI128F930646F': ['cover', 'best covers of all time'],
#  'TRJPJIG128F429287F': ['strangeromanticdeadrockcave', '221119912'],
#  'TRJPJZK128F428A3DB': ['country'],
#  'TRJPJWD12903CC1F41': ['trancecore', 'drum and bass'],
#  'TRJPJXS128F14AE785': ['metalcore', 'instrumental'],
#  'TRJPJXP128F92F9507': ['industrial', 'experimental'],
#  'TRJPJFH128F930EFE4': ['mellow', 'guitar', 'chillout', 'country'],
#  'TRJPJVQ128F9308445': ['soul', 'funk', 'happy', 'rehive'],
#  'TRJPJCO128F14AD3C7': ['soundtrack'],
#  'TRJPJOP128F429B204': ['mae west'],
#  'TRJPJFB128F426779F': ['pop'],
#  'TRJPJPX12903CFF552': ['salsa'],
#  'TRJPJYD12903CFB7FE': ['70s',
#   'acoustic',
#   'soft rock',
#   'beautiful',
#   'british',
#   'beatles'],
#  'TRJPJNB128F42B9990': ['indie', 'new wave', 'electronic'],
#  'TRJPJSH128F42B92E1': ['piano', '77davez all tracks'],
#  'TRJPJNT128F4229042': ['jazz', 'oregon', 'jazz new york'],
#  'TRJPJHZ128F148505E': ['low', 'dream of me'],
#  'TRJPJFD128F4229566': ['rock', 'indie rock'],
#  'TRJPJGY128F92E40F6': ['pop',
#   'vocal',
#   'american',
#   'oldies',
#   '50s',
#   'harmony',
#   'girl band',
#   'doo wop'],
#  'TRJPJMO128F1481CFE': ['christian rock'],
#  'TRJPJRH128F934ADDB': ['progressive rock'],
#  'TRJPPXK128F931B0A6': ['heavy metal', 'classic rock', 'hard rock', 'rock'],
#  'TRJPPRS128F42627FD': ['adult alternative',
#   '1989',
#   'good song',
#   'tumbleweeds',
#   'not dark'],
#  'TRJPPCF128E0789761': ['indie', 'indie rock'],
#  'TRJPPHF128F4273C1B': ['hi nrg', 'dance'],
#  'TRJPPRD128F4281AC4': ['indie', 'mix', 'sweet', 'loves', 'their way'],
#  'TRJPPIL128F93328BA': ['rock', 'indie', 'alternative', 'chaser i'],
#  'TRJPPJY12903CB645D': ['acoustic',
#   'indie pop',
#   'music for a rainy summer day',
#   'sugarsweet plinkelplankel'],
#  'TRJPPYT128F4293087': ['folk', 'singer songwriter'],
#  'TRJPPKI128F425D9A1': ['country',
#   'uplifting',
#   'fun',
#   'upbeat',
#   'catchy',
#   'pop country',
#   'in my little sundress i rock 4 u'],
#  'TRJPPUU128F9313934': ['rock',
#   'pop',
#   'indie pop',
#   'alternative rock',
#   'sad',
#   '00s',
#   'rock nacional',
#   'violencia',
#   'alternative music'],
#  'TRJPPEZ12903CEC3A1': ['rockin summer'],
#  'TRJPPRS128F932D6C1': ['pop'],
#  'TRJPPNL128F42140CA': ['symphonic metal', 'instrumental'],
#  'TRJPPMD12903CF0A90': ['melodic death metal', 'death metal'],
#  'TRJPPRB128F427694E': ['black metal', 'symphonic black metal'],
#  'TRJPPRG128F4297FAB': ['alternative', 'punk rock'],
#  'TRJPPUB128F933BEDD': ['heavy metal baladas'],
#  'TRJPPZX128F93359BB': ['alt country', 'singer songwriter', 'loooove it'],
#  'TRJPPBP128F42725CC': ['alt country',
#   'stooges cover',
#   'cover',
#   'covers',
#   'alt country'],
#  'TRJPPND128F4298B33': ['reggae'],
#  'TRJPGFB128F4261359': ['minimal techno'],
#  'TRJPGTH128F42645A5': ['country'],
#  'TRJPGVT12903CDEF06': ['american', 'woxy'],
#  'TRJPGHR128F1477B80': ['classic rock'],
#  'TRJPGPZ128F428B7DA': ['punk'],
#  'TRJPGDH128F930CC26': ['pop', 'miley cyrus'],
#  'TRJPGYV128F42368E7': ['hardblues'],
#  'TRJPGUF128F93464A3': ['colorscolours', 'best live aussi act'],
#  'TRJPGQJ128F92E5119': ['progressive rock'],
#  'TRJPGWP128F1463E6B': ['country', 'country rock'],
#  'TRJPGPP128F933B957': ['80s', 'pop', 'dance', 'extras'],
#  'TRJPGIQ128F425CDAC': ['nena daconte'],
#  'TRJPGDM128F42B7AF9': ['hip hop'],
#  'TRJPGWY128F4277935': ['salsa'],
#  'TRJPGRM128F42B7B95': ['rock', 'guitar', 'santana', 'latin rock', 'latin'],
#  'TRJPGGU128F14AA714': ['minimal', 'electro'],
#  'TRJPGET128F148C465': ['indie', 'alternative rock', 'espe'],
#  'TRJPGRS128F42889E5': ['chillout', 'electronic', 'indie'],
#  'TRJPGVD128F14A92EF': ['mellow',
#   'alt country',
#   'lounge',
#   'indie',
#   'americana',
#   'storytellers',
#   'dk',
#   'ahhhhhhh',
#   'mms',
#   'jennitobuy',
#   'jennichecks',
#   'jennislo',
#   'interesting: i should check this out'],
#  'TRJPVEW128F1481497': ['30 strand grass'],
#  'TRJPVPD128F14871DF': ['electronic'],
#  'TRJPVCL12903CAED6D': ['clap your hands', 'tech house'],
#  'TRJPVBO128F145C4EB': ['indie', 'british', 'lo fi'],
#  'TRJPVZW128F932DED8': ['celtic'],
#  'TRJPVNH128F426030C': ['soul'],
#  'TRJPVTO12903CCE2F7': ['black metal',
#   'viking metal',
#   'progressive black metal',
#   'i had to change my pants after this song',
#   'nice song by enslaved'],
#  'TRJPVYT12903CE8639': ['hardcore', 'go vegan'],
#  'TRJPVIW128F9316C7E': ['world', 'sweet', 'african', 'stella', 'abiancool'],
#  'TRJPVIL128E0785A2A': ['interesting'],
#  'TRJPVTG128F9352485': ['dub'],
#  'TRJPVUW128F9306A47': ['love',
#   'jazzy',
#   'jazz instrumental',
#   'smooth n fused',
#   'heard on last fm'],
#  'TRJPVEU128E07882AA': ['blues'],
#  'TRJPVFK128F149058A': ['world', 'africa', 'african'],
#  'TRJPVUJ128F146CAE3': ['catchy as hell'],
#  'TRJPVRS128F4287703': ['motown', 'motown detroit'],
#  'TRJPVMM128F146AFFE': ['progressive rock',
#   'pink floyd and members solo',
#   'instrumental'],
#  'TRJPVLU128F42554FB': ['rock', 'classic rock'],
#  'TRJPVHB128F4267BB2': ['chinese', 'hocc'],
#  'TRJPVZR128F92E7198': ['bluegrass'],
#  'TRJPVDF128F4229026': ['contemporary classical', 'contemporary jazz'],
#  'TRJPVLI128EF343F70': ['rap',
#   'creutzfeld und jakob',
#   'deutschrap',
#   'german hiphop',
#   'hip hop',
#   'hip hop'],
#  'TRJPVFS12903CB72A0': ['lovely', 'eclectonia'],
#  'TRJPVJD12903CCB12E': ['electronic', 'experimental'],
#  'TRJPLGU128F92CA99C': ['hard rock', 'rock'],
#  'TRJPLSH128F4239BE3': ['reggae'],
#  'TRJPLCU128F9318A32': ['gedeon'],
#  'TRJPLYJ128F425ADF1': ['rock', 'turkish', 'turkish rock', 'turk rock'],
#  'TRJPLBV128F930ABD0': ['jam band', 'progressive rock'],
#  'TRJPLHR128F1474BBE': ['female vocalist'],
#  'TRJPLZF128EF33FD89': ['80s', 'instrumental', 'spg'],
#  'TRJPLUB128F934F32C': ['classic rock', 'blues', 'singer songwriter'],
#  'TRJPLRG128F4299D1B': ['bjm radio', 'all around the world'],
#  'TRJPLTC128F1488490': ['indie', 'alternative'],
#  'TRJPLGK128F428517B': ['post punk'],
#  'TRJPLCD128F42653BC': ['gangsta rap', 'memphis', 'in da beginning'],
#  'TRJPLQL128F428D5D2': ['canadian',
#   'female vocalist',
#   'pop',
#   'toronto',
#   'electronic',
#   'dance',
#   'electronica',
#   '2003',
#   'euro pop',
#   'gay icon',
#   'homosexual',
#   '2 stars',
#   'gay music',
#   'homo',
#   'tyler adam'],
#  'TRJPLWC12903CEB12E': ['new zealand'],
#  'TRJPLKO12903CB0294': ['love'],
#  'TRJPLBJ128F93362E6': ['space rock', 'psychedelic', 'shoegaze'],
#  'TRJPLSS128F146DDFF': ['hip hop', 'crunk', 'dirty south', 'rap'],
#  'TRJPLMR128F92E66F8': ['thrash metal', 'crust punk', 'hardcore punk'],
#  'TRJPLIB128E0789D28': ['post punk'],
#  'TRJPLNF128F1457430': ['french'],
#  'TRJPLTH128F427E47A': ['french'],
#  'TRJPLDE128F4290131': ['singer songwriter',
#   'indie',
#   'rufus wainwright',
#   'alternative'],
#  'TRJPLCI128F932BB1F': ['classic rock'],
#  'TRJPLCW128F931C25B': ['avant prog'],
#  'TRJPLGK128F427E2EE': ['alternative metal', 'metal', 'system of a down'],
#  'TRJPLTG128F149FCF3': ['boehse onkelz',
#   'deutschrock',
#   'best of onkelz',
#   'rock',
#   'german',
#   'alternative rock',
#   'onkelz',
#   'frankfurt'],
#  'TRJPLDW128F429A21B': ['christian rock', 'rickyx29   top 10'],
#  'TRJPLBS128F92DCD5F': ['blues'],
#  'TRJPLJY128F42476BC': ['rock', 'stoner rock', 'stoner', 'desert rock'],
#  'TRJPLBX12903D075D6': ['post hardcore', 'metalcore'],
#  'TRJPBXE128F92D69BB': ['skull fuck incredible'],
#  'TRJPBRL12903CEA2FB': ['indie pop', 'alternative rock', 'indie rock'],
#  'TRJPBVB12903CDBA5B': ['80s', 'rock', 'alternative', 'brilliant', 'belew'],
#  'TRJPBRQ128F9354A78': ['lounge', 'chillout', 'downtempo'],
#  'TRJPBUD128F4262645': ['noise', 'electronic', 'experimental'],
#  'TRJPBPE128F428280B': ['house'],
#  'TRJPBQG128F428EF98': ['new wave'],
#  'TRJPBGX12903CA5C70': ['pillboxx time to dance'],
#  'TRJPBET128F9314C47': ['michael jackson', 'pop'],
#  'TRJPBLC128F428D5D1': ['canadian',
#   'pop',
#   'toronto',
#   'electronic',
#   'electronica',
#   '2003',
#   'gay club',
#   'gay anthem',
#   'tyler adam'],
#  'TRJPBHU128F42A3C53': ['singer songwriter',
#   'alternative',
#   'rescue me',
#   'soft rock',
#   'alternative rock',
#   'british'],
#  'TRJPBFD128F427EA58': ['latin rock',
#   'rock argentino',
#   'rock en espanol',
#   'carismatico'],
#  'TRJPBQF12903CDCACE': ['metalcore'],
#  'TRJPBKG128F429A279': ['chanson francaise', 'easy nice sound'],
#  'TRJPBLB12903CB73DC': ['melancholic', 'guitar', 'female vocalist', 'ballad'],
#  'TRJPBZX128F1489C06': ['doris troy'],
#  'TRJPBGE128F930A98C': ['instrumental', 'black metal', 'france'],
#  'TRJPBKB128F4277CB6': ['country', 'female vocalists', 'pop love'],
#  'TRJPBXP12903CDB31F': ['rock',
#   'symphonic prog',
#   'rock alternativo',
#   'progressiv',
#   'need to hear more',
#   'classic rock mujeres',
#   'jos4',
#   'natt og dag',
#   'topfemale'],
#  'TRJPBWV128F428D821': ['ostrock'],
#  'TRJPDIC12903CC82E7': ['tweeden', 'club misfits', 'gentle touch'],
#  'TRJPDBZ128EF367728': ['rock', 'fergie', 'cover'],
#  'TRJPDTZ128F92FB84A': ['jazz'],
#  'TRJPDHI128F426997A': ['hip hop', 'underground rap', 'hip hop'],
#  'TRJPDSY128F9318315': ['americana'],
#  'TRJPDVI128F4275E28': ['blues'],
#  'TRJPDAG128F424359C': ['80s', 'rock en espanol'],
#  'TRJPDWS128F422FC2A': ['soul'],
#  'TRJPDMF128F4265DC5': ['country'],
#  'TRJPDOV128F930BCCF': ['rock', 'classic rock', '70s'],
#  'TRJPDPD12903CF5559': ['street punk', 'noplay'],
#  'TRJPDXR128F932B191': ['nice',
#   'real hip hop',
#   'shams 9 i',
#   'club background music'],
#  'TRJPDAV128F92FAE0C': ['smooth jazz'],
#  'TRJPDSF12903CDFCA7': ['soul', 'funk', '70s'],
#  'TRJPDDN12903D061C8': ['rock', 'f50 1983'],
#  'TRJPDEL128F93547C5': ['hard rock', 'rock'],
#  'TRJPDFH128F9318C77': ['singer'],
#  'TRJPDEC12903C9D5F6': ['folk', 'shearwater 2010 the golden archipelago'],
#  'TRJPAXR128F92E26EF': ['bellissima'],
#  'TRJPAYX128F933901B': ['acoustic', 'tentar de novo'],
#  'TRJPAZK128F9354BC6': ['electronic'],
#  'TRJPAYT128F933B284': ['80s'],
#  'TRJPAVF128F92FBEA8': ['underground hip hop'],
#  'TRJPAGG128F425B262': ['ska', 'ska punk'],
#  'TRJPABB12903CF0C88': ['folk metal', 'melodic death metal'],
#  'TRJPARU128E0782068': ['indie pop',
#   'darkwave',
#   'wry',
#   'brighton rock',
#   'luke haines',
#   'playful indie yolala',
#   'salon',
#   'englishness',
#   'driwe driwe',
#   'was eine scatullae my heart',
#   'and one for the chamber',
#   'very noir ish',
#   'synth you been gone',
#   'chambre meublee'],
#  'TRJPAUL128F933B504': ['friendsofthekingofrummelpop',
#   'hannah robinson',
#   'feeling fine in 09',
#   'favorite by this group',
#   'richard x',
#   'infinite loop',
#   'sleek',
#   'single',
#   'my favourites',
#   'faves',
#   'perfect pop',
#   'expressive',
#   'love song',
#   'intelligent',
#   'pretty',
#   'female',
#   'summer',
#   'dance',
#   'pop',
#   'indie'],
#  'TRJPAZS128E0787D81': ['electronic', 'techno', '90s', '1999'],
#  'TRJPAZM128F149F027': ['boys night out', 'emo'],
#  'TRJPAGZ128F149F049': ['metalcore', 'hardcore'],
#  'TRJPALZ128F9307DEE': ['progressive rock'],
#  'TRJPAED128F932540F': ['ambient', 'chillout'],
#  'TRJPASQ128F92DD2F0': ['af', 'mexicofavorit', 'vozromantica'],
#  'TRJPAOT128F145BA87': ['guitar virtuoso'],
#  'TRJPARF128F428EE13': ['reggae', 'dub'],
#  'TRJPAXC128F429F8EB': ['rnb', 'hip hop', 'hip hop'],
#  'TRJPAVP128F92EF2E1': ['psychobilly', 'laura'],
#  'TRJPAIH128F9341740': ['grindcore'],
#  'TRJPQFA128F4287426': ['singer songwriter',
#   'piano',
#   'ed harcourt',
#   'best tracks'],
#  'TRJPQOI128F932CC43': ['west coast rap'],
#  'TRJPQAI128E0793F7B': ['post punk', 'new wave'],
#  'TRJPQZB128F42A4D8F': ['suomirap'],
#  'TRJPQBM128F428DFA5': ['punk', 'punk rock', 'speedy'],
#  'TRJPQDM128F14653EA': ['ambient'],
#  'TRJPQSN12903CA4936': ['power metal', 'heavy metal'],
#  'TRJPQXL128F92FE8C1': ['electronic', 'industrial'],
#  'TRJPQYS128F4293C3E': ['salsa'],
#  'TRJPQHE12903CAF3F5': ['rock'],
#  'TRJPQSL128E0784D6B': ['new edition radio', '90s'],
#  'TRJPQKX12903CC4048': ['60s', 'soul'],
#  'TRJPQZV128F423F2F4': ['se habla espanol ocam',
#   'female pop rock ocam',
#   'ya nada queda',
#   'pop'],
#  'TRJPQWU128F4269B97': ['psychedelic', 'electronic', 'acid jazz'],
#  'TRJPQLR12903CFFB38': ['progressive trance'],
#  'TRJPQTL128E078543D': ['new age', 'folk', 'celtic'],
#  'TRJPQKG128F42760F3': ['flamenco'],
#  'TRJPQZP128F9336654': ['jazz'],
#  'TRJPQES12903D01969': ['reggae',
#   'english',
#   'roots',
#   'rude boys',
#   'rastafari',
#   'rancido roots'],
#  'TRJPQCB128F930CADC': ['rock', 'punk', 'rapcore', 'punk rock'],
#  'TRJPQEZ128F92F3F1D': ['country taggradio', 'tammy wynette taggradio'],
#  'TRJPQRH128F4229D4F': ['electronic'],
#  'TRJPQSW128F92F4CA1': ['rap'],
#  'TRJPQVX12903CE540E': ['favorite songs', 'dreamy', 'magic', 'loooove'],
#  'TRJPQOM128F9322D7F': ['punk', 'punk rock'],
#  'TRJPQSO128F422B182': ['cover'],
#  'TRJPQML12903CDFF83': ['stoner rock'],
#  'TRJPQXG128F421C5A9': ['screamo', 'post hardcore'],
#  'TRJPQZK128F14991F8': ['afrobeat', 'african', 'kenya'],
#  'TRJPOGU128F428B630': ['indie', 'beautiful sound'],
#  'TRJPOIH12903CC81DE': ['hardcore'],
#  'TRJPOZX128F92F5372': ['progressive rock'],
#  'TRJPOJI128F42423F6': ['aflamencado', 'subelamusica'],
#  'TRJPOLK12903CA77DB': ['electronic'],
#  'TRJPOLG12903CFD398': ['post punk', 'industrial'],
#  'TRJPOQQ128F92FFABE': ['mali', 'world', 'africa', 'african'],
#  'TRJPOQN128F4218DDB': ['singer songwriter',
#   'matt nathanson',
#   'riffage',
#   'loves'],
#  'TRJPOQU128F93251C1': ['spanish rock'],
#  'TRJPOVN128F92E1093': ['rhythm and blues'],
#  'TRJPOEB128F933E322': ['indie g funk'],
#  'TRJPOAY128F92F696A': ['oi'],
#  'TRJPOET128F429A9AE': ['live', 'pink'],
#  'TRJPOLM128F93031A0': ['romanticas'],
#  'TRJPOAH128F4271CF5': ['jazz', 'hammond', 'souljazz'],
#  'TRJPOOX12903CC9F8A': ['gypsy', 'bordertown'],
#  'TRJPOAA12903D01296': ['soul', 'classic soul'],
#  'TRJPOZW128F42668B0': ['hardcore', 'metal', 'crossover', 'thrash metal'],
#  'TRJPOCX128F4298702': ['ska', 'punk'],
#  'TRJPOLF128F148D28A': ['freak out for'],
#  'TRJPOJJ128F427F05E': ['ska', 'reggae', 'catala'],
#  'TRJPOHQ12903CF5E6C': ['melodic death metal',
#   'death metal',
#   'technical death metal'],
#  'TRJPOGU12903CEEDFF': ['soul', 'soul and rnb classics'],
#  'TRJPOGY128F1485715': ['awesome', 'love it', 'falling up'],
#  'TRJPOJT128F93148EB': ['hip hop',
#   'my favorite artists',
#   'old school',
#   'golden age',
#   'underground',
#   'hieroglyphics',
#   'radio test',
#   'souls of mischief'],
#  'TRJPOEG128F92CD3CD': ['rock'],
#  'TRJPOOP128F1456F8A': ['80s'],
#  'TRJPOSH128F933018B': ['ambient'],
#  'TRJPOBO128F4262230': ['ska', 'cover'],
#  'TRJPOXS128F42912E6': ['melodic death metal'],
#  'TRJPONA128F93223BF': ['c bo'],
#  'TRJPUVM128F932C768': ['smooth jazz'],
#  'TRJPUPU12903CF061B': ['africa', 'mozambique', 'marrabenta'],
#  'TRJPUKI12903CFC02A': ['pop', 'female vocalists', 'singer songwriter'],
#  'TRJPUFA128F9359E9E': ['doo wop'],
#  'TRJPUUC128F92F3F72': ['contemporary gospel tag'],
#  'TRJPUAZ128F4222C48': ['jazz',
#   'instrumental',
#   'big band',
#   'special',
#   'instrumental jazz'],
#  'TRJPUHR128F92EAB27': ['sail camp song'],
#  'TRJPUSL128F423EA7E': ['new wave'],
#  'TRJPULD128EF34648B': ['rock',
#   'guitar',
#   'chillout',
#   'calm',
#   'ae',
#   'build up',
#   'indie acoustic',
#   'kipoda',
#   'shy vocals',
#   'sonne mond und sterne'],
#  'TRJPUGX128F930B52D': ['under two minutes'],
#  'TRJPUIM128F421AB3B': ['country', 'jo', 'gittis'],
#  'TRJPUUE128F9307083': ['progressive house'],
#  'TRJPUGV128F930CB06': ['folk'],
#  'TRJPUWQ128F4278989': ['noise'],
#  'TRJPULA128F147BD32': ['americana', 'pop', 'exit'],
#  'TRJPUEF12903CDAA59': ['band', 'trova', 'norteas'],
#  'TRJPUAJ128F9300B65': ['jazz', 'female vocalists', 'vocal jazz'],
#  'TRJPUML128F9342C63': ['alternative rock',
#   'brasil',
#   'party',
#   'brazilian',
#   'preferidas',
#   'cassioso',
#   'operario',
#   'patrao'],
#  'TRJPUJZ128E0780BDE': ['luv it'],
#  'TRJPUQZ128F93492BE': ['rock'],
#  'TRJPUCO128F429EC74': ['jazz', 'smoothjazz'],
#  'TRJPUDR128F1495676': ['hip hop'],
#  'TRJPUDN128F147C48B': ['our band could be yr life'],
#  'TRJPUDZ128F9338146': ['soul'],
#  'TRJPUCT128F92FF400': ['indie pop', 'soft'],
#  'TRJPUST128F42881AE': ['title is a full sentence'],
#  'TRJPUCZ128F92F192E': ['oi', 'street punk'],
#  'TRJPUVB128F4255648': ['hard rock', 'metal', 'melodic metal', 'gay metal'],
#  'TRJPUXN12903CB635F': ['you and i',
#   'the word you',
#   'the word think',
#   'first person songs',
#   'the word were',
#   'the word spy'],
#  'TRJPUHR128F932C712': ['salsa', 'tantotempotaste'],
#  'TRJPUPQ128F932AC94': ['blues'],
#  'TRJPUKK128F42A7FC0': ['dutch', 'sex'],
#  'TRJPUFM128F4263AB0': ['blues', 'blues rock', 'roy buchanan'],
#  'TRJPUFA128F428E1BD': ['pop', 'dance', 'kylie minogue'],
#  'TRJPIMF128EF355116': ['ambient', 'electronic', 'of dreams and shadows'],
#  'TRJPIGM128F9333A5F': ['discoverockult',
#   'check them out style varies',
#   'view from everest',
#   'christmas mix 2009'],
#  'TRJPIHZ128F4284E5D': ['rock', 'proto punk', '70s'],
#  'TRJPITF12903CF3072': ['melancholy', 'alternative'],
#  'TRJPIWE128F4280E86': ['hebrew'],
#  'TRJPIBL128F145C6DA': ['80s'],
#  'TRJPIXO128F9316840': ['folk',
#   'acoustic',
#   'indie',
#   'singer songwriter',
#   'accordion'],
#  'TRJPIWC128F4286D08': ['guitar',
#   'blues',
#   'allboutguitar',
#   'allboutguitarcom',
#   'blues rockclub'],
#  'TRJPIEE128F42BC240': ['pop', 'dance'],
#  'TRJPIIN128F4281BEF': ['indie', 'experimental'],
#  'TRJPIXF128F1490487': ['singer songwriter',
#   'ben harper',
#   'folk',
#   'acoustic',
#   'blues'],
#  'TRJPITL128F931F3D0': ['modern country'],
#  'TRJPIKB128F4269F8F': ['alt country',
#   'stooges cover',
#   'cover',
#   'covers',
#   'alt country'],
#  'TRJPIHQ128F931CF80': ['folk', 'female vocalists', 'acoustic'],
#  'TRJPITY128F93218E9': ['metal', 'guitar virtuoso', 'i have this album'],
#  'TRJPIQT128F92CBF28': ['rnb', 'pop', 'dance'],
#  'TRJPIMT128E0782DA4': ['1994', 'group3', 'group2', 'group1', 'group4'],
#  'TRJPIIG128F1457FEC': ['rhythum and blues tag'],
#  'TRJPIFB12903CD7D30': ['pop', 'oldies', 'musicals'],
#  'TRJPIPR128F92E2A87': ['dance'],
#  'TRJPIVE128F4281C3E': ['indie', 'british', 'indie rock'],
#  'TRJPIOA128F424BA8B': ['folk', 'blues'],
#  'TRJPINX128F9309601': ['4jsjazz',
#   '::annayana',
#   'jazz',
#   'contemporary jazz',
#   'q4jslfm'],
#  'TRJPIKK128F429604F': ['hard rock'],
#  'TRJPINN12903CC5CCA': ['moody', 'lent'],
#  'TRJPILL12903CB8A6C': ['rock'],
#  'TRJPITA128F4254E65': ['brianfreeassurance ifeelliketravellingon'],
#  'TRJPICE128F92D280B': ['winter', 'my best', 'music to fall asleep to'],
#  'TRJPIOZ128F14649A5': ['funk'],
#  'TRJPTTK128F932F45C': ['salsa', 'tengo un amor', 'la guerra'],
#  'TRJPTGQ128F42A2187': ['dancehall',
#   'mavado',
#   'jamaica',
#   "don't cry",
#   'gangsta for life'],
#  'TRJPTFH12903CD9CFA': ['blues',
#   'hard rock',
#   'singer songwriter',
#   'blues rock',
#   'favorite',
#   'candidate'],
#  'TRJPTXK128F1452585': ['electronic'],
#  'TRJPTMZ128F425A065': ['guitar virtuoso', 'instrumental'],
#  'TRJPTJF12903CED258': ['bluegrass', 'bluegrass gospel'],
#  'TRJPTMJ128F92CB197': ['french',
#   'electronic',
#   'female vocalists',
#   'trip hop'],
#  'TRJPTIZ128F933BD36': ['my rock'],
#  'TRJPTRP128F1480A5B': ['mike', 'patrice r'],
#  'TRJPTHR128F4294F13': ['soundtrack'],
#  'TRJPTQW128F933552D': ['british i like'],
#  'TRJPTPV12903CE03BE': ['77davez all tracks'],
#  'TRJPTQP128F934FE7E': ['linedance 2011', 'country'],
#  'TRJPTBH12903CFEA3A': ['christian rock',
#   'diggin it',
#   'cross rhythms',
#   'be good evy'],
#  'TRJPTIV128F4227F3F': ['easy listening', 'alternative', 'humos rock rally'],
#  'TRJPTEY128F14586E5': ['reggae'],
#  'TRJPTZQ128F4276572': ['spanish rock'],
#  'TRJPTSK128F92D543D': ['blues'],
#  'TRJPTYK128F423F8E6': ['blues', 'jug band'],
#  'TRJPTTM128EF35F3E4': ['rock', 'spanish rock'],
#  'TRJPTHU12903CC6347': ['country', 'honky tonk'],
#  'TRJPTXQ128F932A027': ['indietronica'],
#  'TRJPTGB128F14A1502': ['power metal'],
#  'TRJPCXN128F146D774': ['funk', 'rock', 'alternative'],
#  'TRJPCFE128F424C926': ['pop',
#   'house',
#   'dance',
#   'female vocalists',
#   'freestyle'],
#  'TRJPCNC128F149235F': ['classic rock', '70s', 'rock', 'peter frampton'],
#  'TRJPCDI128F9321553': ['motown', 'soul', '70s', 'pop', 'funk'],
#  'TRJPCUV128F1487769': ['samba', 'latin', 'deusa'],
#  'TRJPCDN128F42396A9': ['minimal techno'],
#  'TRJPCLU128F428D7FF': ['canadian',
#   'singer songwriter',
#   'female vocalists',
#   'folk rock',
#   'folk rock',
#   'joni mitchell',
#   'joni'],
#  'TRJPCSJ128F92F0EEB': ['blues', 'other', 'the word strange'],
#  'TRJPCGS128F934B668': ['metalcore'],
#  'TRJPCRB128F428D7D3': ['ostrock', 'german', 'deutsch', 'rock'],
#  'TRJPCBS128E07863AE': ['rock', 'garage rock', 'indie rock'],
#  'TRJPCGB128F9342029': ['rock',
#   'garage rock',
#   'stoner rock',
#   'power pop',
#   'hard rock',
#   '00s',
#   'glam rock'],
#  'TRJPCMH128F4292936': ['female vocalists', 'piano'],
#  'TRJPCQN128F4287D8C': ['easy listening',
#   '70s',
#   'barry manilow',
#   'pop',
#   'singer songwriter'],
#  'TRJPCJB128F9344CDD': ['forro', 'mpb'],
#  'TRJPCSY12903CCC9BA': ['rock', 'alternative', '90s'],
#  'TRJPCIZ128F933ABC2': ['rap'],
#  'TRJPCIM128F92D234D': ['chillout', 'downtempo', 'down tempo'],
#  'TRJPCWP12903CFA651': ['reggae'],
#  'TRJPCSO12903CF7E5A': ['cover'],
#  'TRJPCTR128F422C1D9': ['jay sean', 'rnb', 'r&b'],
#  'TRJPCTJ128F426640F': ['electronic', 'techno'],
#  'TRJPCTP128F425DF65': ['indie rock', 'the dykeenies', 'indie'],
#  'TRJPCDK128F42A2286': ['funk',
#   'sexy',
#   'rnb',
#   'beat',
#   'james brown',
#   'deep soul',
#   'sample',
#   'class struggle',
#   'chadmccolgin plays the funk and rb',
#   'soulbrother number 1'],
#  'TRJPCHB128F1475FE6': ['jewel',
#   'singer songwriter',
#   'relaxing',
#   'female vocalists',
#   'melancholy'],
#  'TRJPCGG12903CF5720': ['grief', 'pre and post punk'],
#  'TRJPCIO128F4244B4B': ['swing'],
#  'TRJPCKB128F934F986': ['dark ambient',
#   'death industrial',
#   'black industrial'],
#  'TRJPKCJ128F42AF492': ['70s'],
#  'TRJPKNS12903CE716E': ['5', 'oh my fucking amazing'],
#  'TRJPKVV128F930C97E': ['smooth jazz', 'jazz piano'],
#  'TRJPKPZ128F92FA050': ['electro', 'dance', 'synthpop'],
#  'TRJPKLK128F425AE1F': ['dont worry'],
#  'TRJPKAK12903CEA27A': ['contemporary gospel tag'],
#  'TRJPKNN128F9342729': ['vinicio capossela', 'italian', 'folk'],
#  'TRJPKOT128F92EA257': ['rock'],
#  'TRJPKOH12903CF14F0': ['doom', 'black metal'],
#  'TRJPKRI128E0791288': ['90s', 'rock', 'alternative rock'],
#  'TRJPKOD128F92F5223': ['trance',
#   'electronic',
#   'dance',
#   'progressive trance',
#   'argentine',
#   'a state of trance',
#   'played on asot'],
#  'TRJPKFT12903CD8434': ['drum and bass', 'darkstep'],
#  'TRJPKXR128F427CEAC': ['electronic', 'chill'],
#  'TRJPKHJ128F9318999': ['americana'],
#  'TRJPKFH128F147A2A8': ['baroque pop'],
#  'TRJPKIY12903CB0C6F': ['dance',
#   'really annoying long silence before hidden track'],
#  'TRJPKIE12903CC9278': ['electro'],
#  'TRJPKCB128F92FBE5B': ['favourites', 'pronk', 'rude', 'off kilter'],
#  'TRJPKPV128F4276324': ['hip hop', 'political', 'poetry'],
#  'TRJPKVZ128F932BEDB': ['pop', 'electropop', 'synthpop'],
#  'TRJPKEV128F92E728F': ['comedy'],
#  'TRJPKSA128F93130F9': ['jazz', 'female vocalists', 'chicas jazz'],
#  'TRJPKNI128E07937CA': ['grunge'],
#  ...}

# %% [markdown]
# ## Compare low-level features between FMA & LASTFM

# %%
# LOAD LASTFM ONE-HOT & GET TRACKS W/ GENRES
one_hot_genres = pd.read_csv(paths.TEMP_D + 'LASTFM_one_hot_genres.tsv', sep='\t').set_index('Unnamed: 0')
tracks_w_genres = one_hot_genres.index
print(f"We have {len(tracks_w_genres)} tracks with genres")
# Out:
# We have 328933 tracks with genres

# %%
# GET MSD LOW LEVEL FEATURES - DOWNLOADED FROM https://www.ifs.tuwien.ac.at/mir/msd/download.html#groundtruth
def read_arff(filepath):
    '''Read an .arff file and return a pandas dataframe'''
    
    # Get the column names
    colnames = []
    with open(filepath, 'r') as f:
        for line in f:
            if not line.startswith('@'):
                break
            if line.lower().startswith('@attribute'):
                colnames.append(line.split(' ')[1])

    # Return a pandas dataframe
    return pd.read_csv(filepath, skiprows=len(colnames)+3, names=colnames)

def get_msd_features(tracks_w_genres):
    '''
    Join the different files with MSD features
    Only keep tracks with genres
    Downloaded from https://www.ifs.tuwien.ac.at/mir/msd/download.html#groundtruth
    '''


    # Paths for LASTFM features
    mfcc_filepath = paths.MSD_D + 'msd-jmir-mfcc-all-v1.0.arff'
    all_f_filepath = paths.MSD_D + 'msd-jmir-spectral-all-all-v1.0.arff'
    all_f_derivatives_filepath = paths.MSD_D + 'msd-jmir-spectral-all-derivatives-all-v1.0.arff'
    timbral_f_filepath = paths.MSD_D + 'msd-marsyas-timbral-v1.0.arff'

    # Tracks are within ''. Change index to match
    tracks_w_genres_set = set(f"'{track}'" for track in tracks_w_genres)


    # Read the MSD feature files & only keep tracks with genres
    combined_df = []
    for path in [mfcc_filepath, all_f_filepath, all_f_derivatives_filepath]:
        # Read the file from the .arff
        df = read_arff(path)

        # Keep only tracks with genres
        df = df[df['MSD_TRACKID'].isin(tracks_w_genres_set)]

        # Add to combined df
        combined_df.append(df)


    # Get the final combined dataframe
    msd_features = pd.merge(combined_df[0], combined_df[1], on='MSD_TRACKID')
    msd_features = pd.merge(msd_features, combined_df[2], on='MSD_TRACKID')

    # Remove '' from TRACKID
    msd_features['MSD_TRACKID'] = msd_features['MSD_TRACKID'].apply(lambda x: x.strip("'"))

    # Add timbral features
    timbral_df = read_arff(timbral_f_filepath)
    timbral_df = timbral_df[timbral_df['track_id'].isin(tracks_w_genres)]
    msd_features = pd.merge(msd_features, timbral_df, left_on='MSD_TRACKID', right_on='track_id')    

    # Make trackid the index
    msd_features = msd_features.set_index('MSD_TRACKID')

    return msd_features

msd_features = get_msd_features(tracks_w_genres)

# Save the features
msd_features.to_csv(paths.TEMP_D + 'msd_features.tsv', sep='\t')

msd_features.head()
# Out:
#                     MFCC_Overall_Standard_Deviation_1  \
# MSD_TRACKID
# TRMMMYQ128F932D901                              37.50
# TRMMMKI128F931D80D                              54.71
# TRMMMQY128F92F0EA3                              43.22
# TRMMMPN128F426610E                              41.74
# TRMMMNO128F93539AA                              35.43
#
#                     MFCC_Overall_Standard_Deviation_2  \
# MSD_TRACKID
# TRMMMYQ128F932D901                              4.198
# TRMMMKI128F931D80D                              4.207
# TRMMMQY128F92F0EA3                              3.611
# TRMMMPN128F426610E                              4.314
# TRMMMNO128F93539AA                              4.673
#
#                     MFCC_Overall_Standard_Deviation_3  \
# MSD_TRACKID
# TRMMMYQ128F932D901                              3.025
# TRMMMKI128F931D80D                              4.952
# TRMMMQY128F92F0EA3                              3.689
# TRMMMPN128F426610E                              3.029
# TRMMMNO128F93539AA                              3.725
#
#                     MFCC_Overall_Standard_Deviation_4  \
# MSD_TRACKID
# TRMMMYQ128F932D901                              2.923
# TRMMMKI128F931D80D                              3.718
# TRMMMQY128F92F0EA3                              2.899
# TRMMMPN128F426610E                              2.502
# TRMMMNO128F93539AA                              2.962
#
#                     MFCC_Overall_Standard_Deviation_5  \
# MSD_TRACKID
# TRMMMYQ128F932D901                              2.200
# TRMMMKI128F931D80D                              2.461
# TRMMMQY128F92F0EA3                              2.259
# TRMMMPN128F426610E                              2.222
# TRMMMNO128F93539AA                              2.311
#
#                     MFCC_Overall_Standard_Deviation_6  \
# MSD_TRACKID
# TRMMMYQ128F932D901                              2.063
# TRMMMKI128F931D80D                              2.497
# TRMMMQY128F92F0EA3                              2.107
# TRMMMPN128F426610E                              2.113
# TRMMMNO128F93539AA                              2.282
#
#                     MFCC_Overall_Standard_Deviation_7  \
# MSD_TRACKID
# TRMMMYQ128F932D901                              1.981
# TRMMMKI128F931D80D                              2.309
# TRMMMQY128F92F0EA3                              1.930
# TRMMMPN128F426610E                              1.631
# TRMMMNO128F93539AA                              2.023
#
#                     MFCC_Overall_Standard_Deviation_8  \
# MSD_TRACKID
# TRMMMYQ128F932D901                              1.916
# TRMMMKI128F931D80D                              2.001
# TRMMMQY128F92F0EA3                              1.607
# TRMMMPN128F426610E                              1.497
# TRMMMNO128F93539AA                              1.674
#
#                     MFCC_Overall_Standard_Deviation_9  \
# MSD_TRACKID
# TRMMMYQ128F932D901                              1.566
# TRMMMKI128F931D80D                              1.768
# TRMMMQY128F92F0EA3                              1.583
# TRMMMPN128F426610E                              1.379
# TRMMMNO128F93539AA                              1.712
#
#                     MFCC_Overall_Standard_Deviation_10  ...  \
# MSD_TRACKID                                             ...
# TRMMMYQ128F932D901                               1.645  ...
# TRMMMKI128F931D80D                               1.707  ...
# TRMMMQY128F92F0EA3                               1.503  ...
# TRMMMPN128F426610E                               1.374  ...
# TRMMMNO128F93539AA                               1.948  ...
#
#                     Std_Acc5_Std_Mem20_PeakRatio_Chroma_D_Power_powerFFT_WinHamming_HopSize512_WinSize512_Sum_AudioCh0  \
# MSD_TRACKID
# TRMMMYQ128F932D901                                           0.000700
# TRMMMKI128F931D80D                                           0.001112
# TRMMMQY128F92F0EA3                                           0.000404
# TRMMMPN128F426610E                                           0.001056
# TRMMMNO128F93539AA                                           0.000996
#
#                     Std_Acc5_Std_Mem20_PeakRatio_Chroma_D#_Power_powerFFT_WinHamming_HopSize512_WinSize512_Sum_AudioCh0  \
# MSD_TRACKID
# TRMMMYQ128F932D901                                           0.000714
# TRMMMKI128F931D80D                                           0.001176
# TRMMMQY128F92F0EA3                                           0.000406
# TRMMMPN128F426610E                                           0.001039
# TRMMMNO128F93539AA                                           0.001047
#
#                     Std_Acc5_Std_Mem20_PeakRatio_Chroma_E_Power_powerFFT_WinHamming_HopSize512_WinSize512_Sum_AudioCh0  \
# MSD_TRACKID
# TRMMMYQ128F932D901                                           0.000740
# TRMMMKI128F931D80D                                           0.001186
# TRMMMQY128F92F0EA3                                           0.000407
# TRMMMPN128F426610E                                           0.001018
# TRMMMNO128F93539AA                                           0.001156
#
#                     Std_Acc5_Std_Mem20_PeakRatio_Chroma_F_Power_powerFFT_WinHamming_HopSize512_WinSize512_Sum_AudioCh0  \
# MSD_TRACKID
# TRMMMYQ128F932D901                                           0.000722
# TRMMMKI128F931D80D                                           0.001245
# TRMMMQY128F92F0EA3                                           0.000390
# TRMMMPN128F426610E                                           0.001010
# TRMMMNO128F93539AA                                           0.001097
#
#                     Std_Acc5_Std_Mem20_PeakRatio_Chroma_F#_Power_powerFFT_WinHamming_HopSize512_WinSize512_Sum_AudioCh0  \
# MSD_TRACKID
# TRMMMYQ128F932D901                                           0.000673
# TRMMMKI128F931D80D                                           0.001222
# TRMMMQY128F92F0EA3                                           0.000357
# TRMMMPN128F426610E                                           0.001039
# TRMMMNO128F93539AA                                           0.001072
#
#                     Std_Acc5_Std_Mem20_PeakRatio_Chroma_G_Power_powerFFT_WinHamming_HopSize512_WinSize512_Sum_AudioCh0  \
# MSD_TRACKID
# TRMMMYQ128F932D901                                           0.000654
# TRMMMKI128F931D80D                                           0.001198
# TRMMMQY128F92F0EA3                                           0.000353
# TRMMMPN128F426610E                                           0.001050
# TRMMMNO128F93539AA                                           0.000982
#
#                     Std_Acc5_Std_Mem20_PeakRatio_Chroma_G#_Power_powerFFT_WinHamming_HopSize512_WinSize512_Sum_AudioCh0  \
# MSD_TRACKID
# TRMMMYQ128F932D901                                           0.000666
# TRMMMKI128F931D80D                                           0.001080
# TRMMMQY128F92F0EA3                                           0.000412
# TRMMMPN128F426610E                                           0.001048
# TRMMMNO128F93539AA                                           0.000800
#
#                     Std_Acc5_Std_Mem20_PeakRatio_Average_Chroma_A_Power_powerFFT_WinHamming_HopSize512_WinSize512_Sum_AudioCh0  \
# MSD_TRACKID
# TRMMMYQ128F932D901                                           0.113672
# TRMMMKI128F931D80D                                           0.286647
# TRMMMQY128F92F0EA3                                           0.068049
# TRMMMPN128F426610E                                           0.119544
# TRMMMNO128F93539AA                                           0.206609
#
#                     Std_Acc5_Std_Mem20_PeakRatio_Minimum_Chroma_A_Power_powerFFT_WinHamming_HopSize512_WinSize512_Sum_AudioCh0  \
# MSD_TRACKID
# TRMMMYQ128F932D901                                           0.248798
# TRMMMKI128F931D80D                                           3.282206
# TRMMMQY128F92F0EA3                                           0.206265
# TRMMMPN128F426610E                                           0.424948
# TRMMMNO128F93539AA                                           1.085369
#
#                               track_id
# MSD_TRACKID
# TRMMMYQ128F932D901  TRMMMYQ128F932D901
# TRMMMKI128F931D80D  TRMMMKI128F931D80D
# TRMMMQY128F92F0EA3  TRMMMQY128F92F0EA3
# TRMMMPN128F426610E  TRMMMPN128F426610E
# TRMMMNO128F93539AA  TRMMMNO128F93539AA
#
# [5 rows x 263 columns]

# %%
# GET MOST SIMILAR MSD FEATURES TO FMA FEATURES
def get_most_similar_string(target, words, num_similar: int) -> list:
    return difflib.get_close_matches(target, words, n=num_similar, cutoff=0.0)

# Get index 0 of FMA columns
FMA_feature_cols = set(' '.join(col[:1]) for col in FMA_features.columns)

# Reduce the name of the feature columns
MSD_patterns = [
        # Timbral features
        (r'(Std|Mean)_Acc5_(Std|Mean)_Mem20_', ''),       # Remove Acc5_Mem20 prefix
        (r'_HopSize512_WinSize512_Sum_AudioCh0', ''),      # Remove audio channel suffix
        (r'MFCC\d+', 'MFCC'),                              # Standardize MFCC names
        (r'Chroma_\w#?', 'Chroma'),                         # Standardize Chroma names

        # Other features
        (r'_\d+(_[xy])?$', ''),                            # Remove the _# or _#_x suffix
        (r'^(Derivative_of_)?(Standard_Deviation_of_)?(Running_Mean_of_)?', ''),  # Remove prefixes
        (r'(_Overall)?(_Average)?(_Standard_Deviation)?', '')  # Remove suffixes
]
MSD_cols = msd_features.columns
for pattern, replacement in MSD_patterns:
    MSD_cols = set(re.sub(pattern, replacement, col) for col in MSD_cols)

for col in MSD_cols:
    most_similar_FMA_col = get_most_similar_string(col, FMA_feature_cols, 2)
    print(f"{col:<80}{most_similar_FMA_col}")
# Out:
# Flux_Power_powerFFT_WinHamming                                                  ['spectral_contrast', 'spectral_centroid']
# track_id                                                                        ['spectral_centroid', 'spectral_bandwidth']
# PeakRatio_Chroma_Power_powerFFT_WinHamming                                      ['chroma_cens', 'chroma_cqt']
# Spectral_Rolloff_Point                                                          ['spectral_rolloff', 'spectral_contrast']
# Rolloff_Power_powerFFT_WinHamming                                               ['spectral_rolloff', 'spectral_contrast']
# Spectral_Variability                                                            ['spectral_bandwidth', 'spectral_rolloff']
# Root_Mean_Square                                                                ['tonnetz', 'rmse']
# ZeroCrossings                                                                   ['chroma_cens', 'spectral_rolloff']
# Fraction_Of_Low_Energy_Windows                                                  ['spectral_bandwidth', 'tonnetz']
# PeakRatio_Minimum_Chroma_Power_powerFFT_WinHamming                              ['chroma_cens', 'spectral_centroid']
# Zero_Crossings                                                                  ['chroma_cens', 'chroma_stft']
# MFCC                                                                            ['zcr', 'tonnetz']
# Compactness                                                                     ['chroma_cens', 'chroma_cqt']
# Centroid_Power_powerFFT_WinHamming                                              ['spectral_centroid', 'spectral_contrast']
# Spectral_Centroid                                                               ['spectral_centroid', 'spectral_contrast']
# MFCC_Power_powerFFT_WinHamming                                                  ['spectral_contrast', 'spectral_centroid']
# Spectral_Flux                                                                   ['spectral_rolloff', 'spectral_contrast']

# %%
print([col for col in FMA_features.columns])
FMA_feature_cols

# Obtained from MSD features:
# MFCC  - MFCC
# RMSE - Root_mean_square
# Spectral centroid/rolloff - Spectral centroid/rolloff
# ZCR - zero-crossing rate

# From MSD timbral features:
# Chroma - Some chroma features


# Spectral bandwidth - NONE
# Spectral contrast - NONE
# Tonnetz - NONE
# Out:
# [('chroma_cens', 'kurtosis', '01'), ('chroma_cens', 'kurtosis', '02'), ('chroma_cens', 'kurtosis', '03'), ('chroma_cens', 'kurtosis', '04'), ('chroma_cens', 'kurtosis', '05'), ('chroma_cens', 'kurtosis', '06'), ('chroma_cens', 'kurtosis', '07'), ('chroma_cens', 'kurtosis', '08'), ('chroma_cens', 'kurtosis', '09'), ('chroma_cens', 'kurtosis', '10'), ('chroma_cens', 'kurtosis', '11'), ('chroma_cens', 'kurtosis', '12'), ('chroma_cens', 'max', '01'), ('chroma_cens', 'max', '02'), ('chroma_cens', 'max', '03'), ('chroma_cens', 'max', '04'), ('chroma_cens', 'max', '05'), ('chroma_cens', 'max', '06'), ('chroma_cens', 'max', '07'), ('chroma_cens', 'max', '08'), ('chroma_cens', 'max', '09'), ('chroma_cens', 'max', '10'), ('chroma_cens', 'max', '11'), ('chroma_cens', 'max', '12'), ('chroma_cens', 'mean', '01'), ('chroma_cens', 'mean', '02'), ('chroma_cens', 'mean', '03'), ('chroma_cens', 'mean', '04'), ('chroma_cens', 'mean', '05'), ('chroma_cens', 'mean', '06'), ('chroma_cens', 'mean', '07'), ('chroma_cens', 'mean', '08'), ('chroma_cens', 'mean', '09'), ('chroma_cens', 'mean', '10'), ('chroma_cens', 'mean', '11'), ('chroma_cens', 'mean', '12'), ('chroma_cens', 'median', '01'), ('chroma_cens', 'median', '02'), ('chroma_cens', 'median', '03'), ('chroma_cens', 'median', '04'), ('chroma_cens', 'median', '05'), ('chroma_cens', 'median', '06'), ('chroma_cens', 'median', '07'), ('chroma_cens', 'median', '08'), ('chroma_cens', 'median', '09'), ('chroma_cens', 'median', '10'), ('chroma_cens', 'median', '11'), ('chroma_cens', 'median', '12'), ('chroma_cens', 'min', '01'), ('chroma_cens', 'min', '02'), ('chroma_cens', 'min', '03'), ('chroma_cens', 'min', '04'), ('chroma_cens', 'min', '05'), ('chroma_cens', 'min', '06'), ('chroma_cens', 'min', '07'), ('chroma_cens', 'min', '08'), ('chroma_cens', 'min', '09'), ('chroma_cens', 'min', '10'), ('chroma_cens', 'min', '11'), ('chroma_cens', 'min', '12'), ('chroma_cens', 'skew', '01'), ('chroma_cens', 'skew', '02'), ('chroma_cens', 'skew', '03'), ('chroma_cens', 'skew', '04'), ('chroma_cens', 'skew', '05'), ('chroma_cens', 'skew', '06'), ('chroma_cens', 'skew', '07'), ('chroma_cens', 'skew', '08'), ('chroma_cens', 'skew', '09'), ('chroma_cens', 'skew', '10'), ('chroma_cens', 'skew', '11'), ('chroma_cens', 'skew', '12'), ('chroma_cens', 'std', '01'), ('chroma_cens', 'std', '02'), ('chroma_cens', 'std', '03'), ('chroma_cens', 'std', '04'), ('chroma_cens', 'std', '05'), ('chroma_cens', 'std', '06'), ('chroma_cens', 'std', '07'), ('chroma_cens', 'std', '08'), ('chroma_cens', 'std', '09'), ('chroma_cens', 'std', '10'), ('chroma_cens', 'std', '11'), ('chroma_cens', 'std', '12'), ('chroma_cqt', 'kurtosis', '01'), ('chroma_cqt', 'kurtosis', '02'), ('chroma_cqt', 'kurtosis', '03'), ('chroma_cqt', 'kurtosis', '04'), ('chroma_cqt', 'kurtosis', '05'), ('chroma_cqt', 'kurtosis', '06'), ('chroma_cqt', 'kurtosis', '07'), ('chroma_cqt', 'kurtosis', '08'), ('chroma_cqt', 'kurtosis', '09'), ('chroma_cqt', 'kurtosis', '10'), ('chroma_cqt', 'kurtosis', '11'), ('chroma_cqt', 'kurtosis', '12'), ('chroma_cqt', 'max', '01'), ('chroma_cqt', 'max', '02'), ('chroma_cqt', 'max', '03'), ('chroma_cqt', 'max', '04'), ('chroma_cqt', 'max', '05'), ('chroma_cqt', 'max', '06'), ('chroma_cqt', 'max', '07'), ('chroma_cqt', 'max', '08'), ('chroma_cqt', 'max', '09'), ('chroma_cqt', 'max', '10'), ('chroma_cqt', 'max', '11'), ('chroma_cqt', 'max', '12'), ('chroma_cqt', 'mean', '01'), ('chroma_cqt', 'mean', '02'), ('chroma_cqt', 'mean', '03'), ('chroma_cqt', 'mean', '04'), ('chroma_cqt', 'mean', '05'), ('chroma_cqt', 'mean', '06'), ('chroma_cqt', 'mean', '07'), ('chroma_cqt', 'mean', '08'), ('chroma_cqt', 'mean', '09'), ('chroma_cqt', 'mean', '10'), ('chroma_cqt', 'mean', '11'), ('chroma_cqt', 'mean', '12'), ('chroma_cqt', 'median', '01'), ('chroma_cqt', 'median', '02'), ('chroma_cqt', 'median', '03'), ('chroma_cqt', 'median', '04'), ('chroma_cqt', 'median', '05'), ('chroma_cqt', 'median', '06'), ('chroma_cqt', 'median', '07'), ('chroma_cqt', 'med ...
# {'chroma_cens',
#  'chroma_cqt',
#  'chroma_stft',
#  'mfcc',
#  'rmse',
#  'spectral_bandwidth',
#  'spectral_centroid',
#  'spectral_contrast',
#  'spectral_rolloff',
#  'tonnetz',
#  'zcr'}

# %%
# COMPARE LASTFM & FMA ON COINCIDING SONGS

# 1. Get list of FMA and LASTFM tracks that coincide
# 2. Check for genre overlap between the two tracks
# 3. Check for feature overlap between the two tracks
#    For that, create a heatmap, comparing the similarity between the features. See whether there is some feature which is very well correlated.
#    Take into consideration that we might get very bad results, as the features have been computed in a different way

# %%
def get_matching_tracks(FMA_tracks, paths):
    """Retrieve matching tracks between FMA and MSD datasets as (LASTFM_track_id, FMA_track_id, artist, title) tuples."""
    
    # Create a mapping from (title, artist) to FMA track ID
    FMA_title_artist_to_id = {
        (title, artist): track_id
        for track_id, title, artist in zip(
            FMA_tracks.index,
            FMA_tracks[('track', 'title')],
            FMA_tracks[('artist', 'name')]
        )
    }

    # Get list of tracks with similar tracks from LASTFM
    with open(paths.LASTFM_SIMILAR_TRACKS) as f:
        tracks_with_similar = f.read().splitlines()

    # List to store the matched tuples
    matched_tracks = []

    for track_id in tracks_with_similar:
        rel_track_path = f'{track_id[2]}/{track_id[3]}/{track_id[4]}/{track_id}.json'

        # Check in both train and test directories
        for supfolder in [paths.LASTFM_TEST_F, paths.LASTFM_TRAIN_f]:
            track_path = supfolder + rel_track_path
            if not os.path.exists(track_path):
                continue

            # Load track metadata
            with open(track_path) as f:
                track_dict = json.load(f)

                title = track_dict['title']
                artist = track_dict['artist']

                # Check if this (title, artist) exists in FMA
                if (title, artist) in FMA_title_artist_to_id:
                    FMA_track_id = FMA_title_artist_to_id[(title, artist)]
                    matched_tracks.append((track_id, FMA_track_id, artist, title))

    print(f"Found {len(matched_tracks)} matching tracks between MSD and FMA.")
    return matched_tracks

# Example call to the function
matched_tracks = get_matching_tracks(FMA_tracks, paths)
# Out:
# Found 453 matching tracks between MSD and FMA.

# %%
# PROVIDED BY CHATGPT

def check_genre_overlap(matched_tracks, FMA_tracks, LASTFM_all_genres_dict):
    """Check for genre overlap between coinciding tracks in FMA and LASTFM datasets."""
    
    id_to_genre = FMA_genres['title'].str.lower().str.replace('-', ' ').to_dict()

    genre_overlaps = []

    for lastfm_id, fma_id, artist, title in matched_tracks:
        # Get FMA genres directly
        fma_genres = set(FMA_tracks.loc[fma_id, ('track', 'genres_all')])

        # Map genres to its name
        fma_genres = set(id_to_genre[genre_id] for genre_id in fma_genres)        

        # Get LASTFM genres directly
        lastfm_genres = set(LASTFM_all_genres_dict.get(lastfm_id, []))

        # Find the intersection of genres
        overlapping_genres = fma_genres & lastfm_genres
        genre_overlaps.append((lastfm_id, fma_id, artist, title, fma_genres, lastfm_genres, overlapping_genres))

    print(f"Checked genre overlap for {len(genre_overlaps)} tracks.")
    return genre_overlaps

# Step 2: Check genre overlap
genre_overlaps = check_genre_overlap(matched_tracks, FMA_tracks, LASTFM_all_genres_dict)
print(genre_overlaps)
# Out:
# Checked genre overlap for 453 tracks.
# [('TRACCYC128F930B379', 18805, 'Chandeliers', 'The Durks', {'electronic'}, set(), set()), ('TRADPJD12903D031C6', 83969, 'Foot Village', 'Reggae War Zone', {'loud rock', 'rock', 'noise rock'}, set(), set()), ('TRAEJYY128F4218203', 126683, 'The Red Thread', "Sailin' On", {'country & western', 'americana', 'country', 'indie rock', 'rock'}, set(), set()), ('TRAGYML128F4286683', 10160, 'Thee Oh Sees', 'It Killed Mom', {'garage', 'rock'}, set(), set()), ('TRAIZBQ128F92F02A7', 33538, 'Calexico', 'Roka', {'rock'}, {'spanish', 'americana', 'country', 'indie rock', 'folk', 'international', 'rock', 'europe'}, {'rock'}), ('TRAJXWL12903D0537F', 129682, 'Holly Golightly & The Brokeoffs', 'When He Comes', {'country', 'folk', 'blues'}, set(), set()), ('TRAKKTI128F42B4F25', 33542, 'Calexico', 'Two Silver Trees', {'rock'}, {'indie rock', 'rock', 'house', 'electronic', 'chill out'}, {'rock'}), ('TRALDEB128F428CE7A', 4804, 'Harvey Milk', 'The Anvil Will Fall', {'rock'}, set(), set()), ('TRALSLF128F421E8FA', 71500, 'The Brought Low', 'Vernon Jackson', {'bluegrass', 'country', 'rock'}, {'rock'}, {'rock'}), ('TRAMUUZ128F933CA08', 6448, 'EPMD', 'Please Listen To My Demo', {'hip hop'}, {'rap', 'hip hop'}, {'hip hop'}), ('TRAODHR128F4280D21', 533, 'Chandeliers', 'Mango Tree', {'electronic'}, set(), set()), ('TRAPJCE128F933EFB6', 47480, 'Higgins', 'OK', {'punk', 'power pop', 'rock', 'psych rock'}, set(), set()), ('TRAQEZO128F9345243', 133388, 'The Real Kids', 'Better Be Good', {'rock'}, {'power pop', 'punk', 'rock'}, {'rock'}), ('TRAUENB128F9302207', 14776, 'Dan Deacon', 'Red F', {'electronic'}, {'electronic'}, {'electronic'}), ('TRAULSR128F933DDA6', 52569, 'The Unsacred Hearts', 'Plug Me In', {'garage', 'indie rock', 'punk', 'post punk', 'rock'}, set(), set()), ('TRAYXFP128F93328B1', 5412, 'Thomas Function', 'Picking Scabs', {'punk', 'power pop', 'rock'}, set(), set()), ('TRAYYKZ128F148F79E', 4801, 'Harvey Milk', 'War', {'rock'}, {'rock'}, {'rock'}), ('TRBBDLJ128F933B13D', 9925, 'Kevin Blechdom', 'You Changed My Life', {'pop', 'experimental pop', 'folk', 'singer songwriter', 'electronic'}, set(), set()), ('TRBBJRH128F92E321D', 573, 'Clockcleaner', 'When My Ship Comes In', {'punk', 'rock'}, set(), set()), ('TRBHZIR128F42B9D3F', 33544, 'Calexico', "Victor Jara's Hands", {'rock'}, {'americana', 'country', 'indie rock', 'folk', 'rock'}, {'rock'}), ('TRBIXYY128F427568E', 108325, 'Matteah Baim', 'River', {'lo fi', 'noise', 'minimal electronic', 'rock', 'experimental', 'electronic'}, {'folk', 'experimental', 'singer songwriter'}, {'experimental'}), ('TRBKXPB128F92FB059', 3654, 'Gary Wilson', 'Forgotten Lovers', {'rock'}, set(), set()), ('TRBNTZP12903CB9C0D', 56844, 'Misty Roses', 'Address Book', {'easy listening', 'folk', 'easy listening: vocal', 'singer songwriter'}, set(), set()), ('TRBNYIW128F932D641', 26721, 'Captain Ahab', 'Feel Anymore', {'experimental pop', 'electronic', 'pop'}, {'punk', 'rock', 'hardcore'}, set()), ('TRBOHGT128F933DDA1', 52566, 'The Unsacred Hearts', '1978', {'garage', 'indie rock', 'punk', 'post punk', 'rock'}, set(), set()), ('TRBRHZB128F4260D0F', 36075, 'Sian Alice Group', 'Motionless', {'post rock', 'rock'}, set(), set()), ('TRBRMXW128F4287365', 3787, 'Larkin Grimm', 'The Most Excruciating Vibe', {'folk'}, set(), set()), ('TRBRRLH128F147F9B8', 38421, 'Ut', 'Canker', {'no wave', 'punk', 'rock'}, {'no wave', 'punk', 'rock', 'experimental'}, {'no wave', 'punk', 'rock'}), ('TRBSGIV128F933EFAE', 47475, 'Higgins', 'Wall of Dumb', {'punk', 'power pop', 'rock', 'psych rock'}, set(), set()), ('TRBSVSB128F93108D6', 14390, 'Clan Destined', 'The Language', {'hip hop'}, set(), set()), ('TRBWOJQ128F933EFAC', 47473, 'Higgins', 'There He Is', {'punk', 'power pop', 'rock', 'psych rock'}, set(), set()), ('TRBXKIE128F425BA78', 49771, 'Mia Doi Todd', 'Bound Feet & Feathered', {'folk', 'singer songwriter'}, set(), set()), ('TRBYHXS128F42720D9', 19466, 'Deerhunter', 'Microcastle', {'rock', 'psych rock'}, {'shoegaze', 'rock'}, {'rock'}), ('TRCBCCT128F93 ...

# %%
import pandas as pd

# Prepare the data from genre_overlaps
overlap_data = [
    {
        "lastfm_id": lastfm_id,
        "fma_id": fma_id,
        "artist": artist,
        "title": title,
        "fma_genres": fma_genres,
        "lastfm_genres": lastfm_genres,
        "overlapping_genres": overlapping_genres,
        "num_fma_genres": len(fma_genres),
        "num_lastfm_genres": len(lastfm_genres),
        "num_overlapping_genres": len(overlapping_genres),
    }
    for lastfm_id, fma_id, artist, title, fma_genres, lastfm_genres, overlapping_genres in genre_overlaps
]

# Convert to DataFrame
overlap_df = pd.DataFrame(overlap_data)

# Calculate some statistics
total_tracks = len(overlap_df)
tracks_with_overlap = overlap_df[overlap_df['num_overlapping_genres'] > 0].shape[0]
average_overlap = overlap_df['num_overlapping_genres'].mean()
average_fma_genres = overlap_df['num_fma_genres'].mean()
average_lastfm_genres = overlap_df['num_lastfm_genres'].mean()
average_overlap_ratio = (overlap_df['num_overlapping_genres'] / overlap_df['num_fma_genres']).mean()

# Create a contingency table
contingency_table = pd.crosstab(
    overlap_df['num_fma_genres'], 
    overlap_df['num_overlapping_genres']
)

# Display the results
summary_stats = {
    "Total Tracks": total_tracks,
    "Tracks with Genre Overlap": tracks_with_overlap,
    "Percentage with Overlap": tracks_with_overlap / total_tracks * 100,
    "Average Number of FMA Genres": average_fma_genres,
    "Average Number of LASTFM Genres": average_lastfm_genres,
    "Average Number of Overlapping Genres": average_overlap,
    "Average Overlap Ratio": average_overlap_ratio,
}

display(contingency_table)

summary_stats
# Out:
# num_overlapping_genres   0   1   2   3  4  5
# num_fma_genres
# 0                        4   0   0   0  0  0
# 1                       77  31   0   0  0  0
# 2                       67  27  19   0  0  0
# 3                       79  23  10  10  0  0
# 4                       34  11  15   2  3  0
# 5                       25   5   3   0  0  0
# 6                        2   1   3   0  0  1
# 7                        0   1   0   0  0  0
# {'Total Tracks': 453,
#  'Tracks with Genre Overlap': 165,
#  'Percentage with Overlap': 36.423841059602644,
#  'Average Number of FMA Genres': np.float64(2.5916114790286975),
#  'Average Number of LASTFM Genres': np.float64(1.0485651214128036),
#  'Average Number of Overlapping Genres': np.float64(0.5562913907284768),
#  'Average Overlap Ratio': np.float64(0.23814296319864248)}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import pairwise_distances
from sklearn.preprocessing import StandardScaler

def standardize_features(FMA_features, MSD_features):
    """Standardize both FMA and MSD features to have mean 0 and standard deviation 1."""
    
    # Initialize the standard scaler
    scaler = StandardScaler()
    
    # Standardize FMA features
    FMA_standardized = pd.DataFrame(
        scaler.fit_transform(FMA_features),
        index=FMA_features.index,
        columns=FMA_features.columns
    )
    
    # Standardize MSD features
    MSD_standardized = pd.DataFrame(
        scaler.fit_transform(MSD_features),
        index=MSD_features.index,
        columns=MSD_features.columns
    )
    
    return FMA_standardized, MSD_standardized

def plot_average_feature_similarity_heatmap(matched_tracks, FMA_features, MSD_features, method='correlation'):
    """Create a heatmap showing the average feature similarity between FMA and MSD datasets across all matched tracks."""

    if not matched_tracks:
        print("No matched tracks available.")
        return

    # Initialize an accumulator for the similarity matrices
    cumulative_similarity_matrix = np.zeros((FMA_features.shape[1], MSD_features.shape[1]))
    valid_track_count = 0

    for lastfm_id, fma_id, artist, title in matched_tracks:
        try:
            # Get FMA and MSD feature vectors for the track
            fma_feature_vector = FMA_features.loc[fma_id].values.reshape(-1, 1)
            msd_feature_vector = MSD_features.loc[lastfm_id].values.reshape(-1, 1)

            # Calculate similarity between features
            if method == 'correlation':
                similarity_matrix = np.corrcoef(fma_feature_vector[:, 0], msd_feature_vector[:, 0])
            else:
                similarity_matrix = -pairwise_distances(fma_feature_vector, msd_feature_vector, metric='euclidean')

            # Handle potential infinite or NaN values by replacing them with a low similarity score
            similarity_matrix = np.nan_to_num(similarity_matrix, nan=-1.0, posinf=-1.0, neginf=-1.0)

            # Accumulate the similarity matrix
            cumulative_similarity_matrix += similarity_matrix
            valid_track_count += 1

        except Exception as e:
            print(f"Error processing track {lastfm_id} and {fma_id}: {e}")
            continue

    # Calculate the average similarity matrix
    if valid_track_count > 0:
        average_similarity_matrix = cumulative_similarity_matrix / valid_track_count
    else:
        print("No valid tracks processed.")
        return

    # Create labels for heatmap
    fma_feature_labels = FMA_features.columns
    msd_feature_labels = MSD_features.columns

    # Create a DataFrame for the heatmap
    similarity_df = pd.DataFrame(average_similarity_matrix, index=fma_feature_labels, columns=msd_feature_labels)

    # Plot the average similarity heatmap with clustering
    sns.clustermap(similarity_df, cmap='coolwarm', method='average', metric='euclidean', figsize=(15, 15))
    plt.title(f'Average Clustered Feature Similarity Heatmap ({method} similarity)')
    plt.xlabel('MSD Features')
    plt.ylabel('FMA Features')
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.show()

# Standardise
FMA_standardized, MSD_standardized = standardize_features(FMA_features, msd_features)

# Plot the average feature similarity heatmap across all matched tracks
plot_average_feature_similarity_heatmap(matched_tracks, FMA_standardized, MSD_standardized, method='cosine')
# Out:
# Error processing track TRAKKTI128F42B4F25 and 33542: 'TRAKKTI128F42B4F25'
# /home/cdt_wsl/wsl_courses/Melody-Match/venv/lib/python3.12/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /home/cdt_wsl/wsl_courses/Melody-Match/venv/lib/python3.12/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
